# %% [markdown]
# sign up and use the following account to access the intra day data for testing

# %%
import os
#from settings import PROJECT_ROOT

# %%
from datetime import datetime
import pandas

# %%
from iexfinance.stocks import get_historical_intraday

# %%
date = datetime(2019, 5, 10)

# %%
os.environ['IEX_TOKEN'] = 'pk_4ea9af9ceb2f42ceb9e34cb3144f9598'

# %%
#supports json or pandas format
df = get_historical_intraday("AAPL", date, output_format='pandas')

# %%
df.head()
# Out:
#                            date     label     high     low  average  volume  \
# 2019-05-10 09:30:00  2019-05-10  09:30 AM  198.455  197.07  197.858   25726
# 2019-05-10 09:31:00  2019-05-10  09:31 AM  198.470  197.96  198.344    9879
# 2019-05-10 09:32:00  2019-05-10  09:32 AM  198.360  197.70  198.115   11305
# 2019-05-10 09:33:00  2019-05-10  09:33 AM  198.740  198.23  198.521   17498
# 2019-05-10 09:34:00  2019-05-10  09:34 AM  198.550  198.17  198.318   12660
#
#                         notional  numberOfTrades  marketHigh  marketLow  \
# 2019-05-10 09:30:00  5090103.395             139     198.480     197.01
# 2019-05-10 09:31:00  1959439.535              71     198.490     197.86
# 2019-05-10 09:32:00  2239691.105              59     198.405     197.66
# 2019-05-10 09:33:00  3473721.785             122     198.740     198.22
# 2019-05-10 09:34:00  2510705.470              81     198.560     198.12
#
#                      marketAverage  marketVolume  marketNotional  \
# ...
