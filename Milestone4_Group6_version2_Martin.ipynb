# %% [markdown]
# # Final project -- milestone 4
#
# Contributor: Martin Jin, Qimei Lin, Yingxue Lu, Yuhan Zhang
#
# Due Date: 12/11/2019

# %%
# import the necessary libraries
import pandas as pd
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
import time
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
import re
from sklearn.model_selection import train_test_split
! pip install pandas-datareader
import pandas_datareader.data as web
import datetime
from sklearn.linear_model import LinearRegression
from pandas.plotting import scatter_matrix
from sklearn.neighbors import KNeighborsRegressor
sns.set(style="whitegrid")
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting pandas-datareader
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/14/52/accb990baebe0063977f26e02df36aa7eb4015ed4e86f828cd76273cd6f1/pandas_datareader-0.8.1-py2.py3-none-any.whl (107kB)
#      |████████████████████████████████| 112kB 221kB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.21 in /anaconda3/envs/tfcs109a/lib/python3.6/site-packages (from pandas-datareader) (0.25.3)
# Requirement already satisfied: requests>=2.3.0 in /anaconda3/envs/tfcs109a/lib/python3.6/site-packages (from pandas-datareader) (2.22.0)
# Collecting lxml
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/50/a4/fb2c4441028bc81d3b50f970a8471ac5b34e64fcc85d5dc304691b0c41ff/lxml-4.4.2-cp36-cp36m-macosx_10_6_intel.macosx_10_9_intel.macosx_10_9_x86_64.macosx_10_10_intel.macosx_10_10_x86_64.whl (8.9MB)
#      |████████████████████████████████| 8.9MB 1.9MB/s eta 0:00:01     |████▍                           | 1.2MB 249kB/s eta 0:00:31     |█████████▏                      | 2.5MB 325kB/s eta 0:00:20
# Requirement already satisfied: python-dateutil>=2.6.1 in /anaconda3/envs/tfcs109a/lib/python3.6/site-packages (from pandas>=0.21->pandas-datareader) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /anaconda3/envs/tfcs109a/lib/python3.6/site-packages (from pandas>=0.21->pandas-datareader) (2019.3)
# Requirement already satisfied: numpy>=1.13.3 in /anaconda3/envs/tfcs109a/lib/python3.6/site-packages (from pandas>=0.21->pandas-datareader) (1.17.3)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /anaconda3/envs/tfcs109a/lib/python3.6/site-packages (from requests>=2.3.0->pandas-datareader) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /anaconda3/envs/tfcs109a/lib/python3.6/site-packages (from requests>=2.3.0->pandas-datareader) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda3/envs/tfcs109a/lib/python3.6/site-packages (from requests>=2.3.0->pandas-datareader) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /anaconda3/envs/tfcs109a/lib/python3.6/site-packages (from requests>=2.3.0->pandas-datareader) (1.24.2)
# Requirement already satisfied: six>=1.5 in /anaconda3/envs/tfcs109a/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas>=0.21->pandas-datareader) (1.13.0)
# Installing collected packages: lxml, pandas-datareader
# Successfully installed lxml-4.4.2 pandas-datareader-0.8.1

# %% [markdown]
# ## Import and Process Tweet data
#
# 1. Import Dataset from 'data/trump-tweets-11-18-2019.csv'
#
# 2. Change the data type of created_at to datetime.date
#
# 3. Restrict the dataset to original tweet only
#
# 4. Group by created_at to aggregate all tweets in a day to a single datum point.
#
# 5. Sort the Tweet data with a descending date order

# %%
df_tweets = pd.read_csv('data/trump-tweets-11-18-2019.csv')
df_tweets.head()
# Out:
#                source                                               text           created_at  retweet_count  favorite_count is_retweet               id_str
# 0  Twitter for iPhone                            https://t.co/Mqj5tXaDAz  11-18-2019 04:38:28          15115           41938      False  1196286528546332672
# 1  Twitter for iPhone  “All they do is bring up witnesses who didn’t ...  11-18-2019 03:39:38          16476           61998      False  1196271720392511489
# 2  Twitter for iPhone  “The Impeachment started before he even became...  11-18-2019 02:40:04          18488           75282      False  1196256729471827968
# 3  Twitter for iPhone                            https://t.co/1Rg66Tn4uP  11-17-2019 22:57:43          16318           51690      False  1196200775560634368
# 4  Twitter for iPhone                            https://t.co/D66PEkuX6d  11-17-2019 22:51:37          12209           38663      False  1196199239715639302

# %%
#get the tweet data from downloaded data
df_tweets['created_at'] = pd.to_datetime(df_tweets['created_at']).dt.date
df_tweets['trump_tweet_cnt'] =[1 if reFlag ==False else 0 for reFlag in df_tweets['is_retweet'].values]
df_tweets['trump_retweet_cnt'] =[0 if  reFlag ==False else 1 for reFlag in df_tweets['is_retweet'].values]
df_tweets_cleaned = df_tweets.groupby('created_at', as_index = False).agg({
    'trump_tweet_cnt': 'sum',
    'trump_retweet_cnt': 'sum',
    'retweet_count': 'sum',
    'favorite_count': 'sum',
    'text':'sum'
})

df_tweets_cleaned= df_tweets_cleaned.sort_values('created_at',ascending=False)
df_tweets_cleaned.head()
# Out:
#       created_at  trump_tweet_cnt  trump_retweet_cnt  retweet_count  favorite_count                                               text
# 1018  2019-11-18                3                  0          50079          179218  https://t.co/Mqj5tXaDAz“All they do is bring u...
# 1017  2019-11-17               36                 15         666343         1668991  https://t.co/1Rg66Tn4uPhttps://t.co/D66PEkuX6d...
# 1016  2019-11-16               14                 11         414895          932464  Louisiana 3 hours left get out and Vote for @E...
# 1015  2019-11-15               19                 24         733886         1313131  https://t.co/8h6ZmdGlPf https://t.co/shaijXMXl...
# 1014  2019-11-14               13                 21         444871          988437  ....We send our deepest condolences to the fam...

# %% [markdown]
# ### Import lexicon polarity data. The polarity file was adopted from vader Sentiment: https://github.com/cjhutto/vaderSentiment.git

# %%
sent = pd.read_csv('data/vader_lexicon.txt', sep='\t', header=None)
sent = sent.drop([2, 3], 1)
sent.index.rename('token', inplace=True)
sent.rename(columns={1: 'polarity'}, inplace=True)
sent.head()
# Out:
#          0  polarity
# token
# 0       $:      -1.5
# 1       %)      -0.4
# 2      %-)      -1.5
# 3      &-:      -0.4
# 4       &:      -0.7

# %% [markdown]
# ### The following section puts polarity and tag information into Trump's sweet data set

# %%
trump_tweets = pd.read_csv('data/trump-tweet-in-office.csv')
trump_tweets['created_at'] =  pd.to_datetime(trump_tweets['created_at']).dt.date

trump = trump_tweets.copy()
trump['id']=trump['id_str']
trump = trump.set_index(['id'])

repl_punc = trump['text'].str.replace(r"[?|,|$|!|&|.|#|^|;|:|/|\"]", ' ')
replacequotes = repl_punc.str.replace(r'^"', '')

# Save your regex in punct_re
punct_re = r"[^\w\s]"
#[?|,|$|!|&|.|#|^|;|:|/|\"]
trump['no_punc'] = trump['text'].str.replace(punct_re, " ")

# %%
trumpcopy = trump.copy()
changed_punc = trumpcopy['no_punc'].str.replace('\s+', ' ')
trumpcopy['no_punc'] = changed_punc
splt = trumpcopy['no_punc'].str.split(expand=True).stack().reset_index().set_index('id')
splt.columns = ['num', 'word']

# %%
splt.head(10)
# Out:
#                      num          word
# id
# 1187551862616141824    0            RT
# 1187551862616141824    1  RepLeeZeldin
# 1187551862616141824    2          This
# 1187551862616141824    3   impeachment
# 1187551862616141824    4       inquiry
# 1187551862616141824    5           has
# 1187551862616141824    6      produced
# 1187551862616141824    7       NOTHING
# 1187551862616141824    8            to
# 1187551862616141824    9       impeach

# %%
tidy_format = splt
newt = tidy_format.reset_index()
newsent = sent.reset_index().rename(columns = {'token': 'word'})
display(newt.head())
display(newsent.head())
# Out:
#                     id  num          word
# 0  1187551862616141824    0            RT
# 1  1187551862616141824    1  RepLeeZeldin
# 2  1187551862616141824    2          This
# 3  1187551862616141824    3   impeachment
# 4  1187551862616141824    4       inquiry
#    word    0  polarity
# 0     0   $:      -1.5
# 1     1   %)      -0.4
# 2     2  %-)      -1.5
# 3     3  &-:      -0.4
# 4     4   &:      -0.7

# %%
newt = tidy_format.reset_index()
#newt = newt.drop('num')
newt1 = newt[['id', 'word']].copy()
newsent = sent.reset_index().rename(columns = {0: 'word'})
newsent1 =newsent[['polarity', 'word']].copy()
display(newt1.head())
display(newsent1.head(10))
# Out:
#                     id          word
# 0  1187551862616141824            RT
# 1  1187551862616141824  RepLeeZeldin
# 2  1187551862616141824          This
# 3  1187551862616141824   impeachment
# 4  1187551862616141824       inquiry
#    polarity      word
# 0      -1.5        $:
# 1      -0.4        %)
# 2      -1.5       %-)
# 3      -0.4       &-:
# 4      -0.7        &:
# 5       1.6  ( '}{' )
# 6      -0.9        (%
# 7       2.2      ('-:
# 8       2.3       (':
# 9       2.1      ((-:

# %%
polar = pd.merge(newt1, newsent1, how='outer', on= 'word')
newpol = polar.groupby('id').sum()
###newpol = newpol.drop('num', 1).fillna(0)
newpol = newpol.fillna(0)

# %%
polarities = newpol
maybpol = polarities.reset_index()
maybtrump = trump.reset_index()

# %%
display(maybpol.head())
display(maybtrump.head())
# Out:
#              id  polarity
# 0  8.222424e+17       1.7
# 1  8.222987e+17       2.7
# 2  8.224214e+17      -1.0
# 3  8.225018e+17       1.7
# 4  8.225019e+17       1.4
#                     id              source                                               text  created_at  retweet_count  favorite_count is_retweet               id_str                                            no_punc
# 0  1187551862616141824  Twitter for iPhone  RT @RepLeeZeldin: This impeachment inquiry has...  2019-10-25           8819               0       True  1187551862616141824  RT  RepLeeZeldin  This impeachment inquiry has...
# 1  1187551461808492544  Twitter for iPhone  RT @RepDougCollins: Democrats have no concern ...  2019-10-25          13713               0       True  1187551461808492544  RT  RepDougCollins  Democrats have no concern ...
# 2  1187551451775750144  Twitter for iPhone  RT @RepGosar: The only reason Adam Schiff is c...  2019-10-25          10961               0       True  1187551451775750144  RT  RepGosar  The only reason Adam Schiff is c...
# 3  1187551305281212416  Twitter for iPhone  RT @RepArrington: Let's call this sham what it...  2019-10-25           4547               0       True  1187551305281212416  RT  RepArrington  Let s call this sham what it...
# 4  1187551256371515392  Twitter for iPhone  RT @RepMattGaetz: Democrats are trying to use ...  2019-10-25          10491               0       True  1187551256371515392  RT  RepMattGaetz  Democrats are trying to use ...

# %%
senti = pd.merge(maybpol, maybtrump, how='outer', on='id').set_index('id')
new_senti= senti.loc[senti['favorite_count']>=0].drop('id_str',axis=1)
print(len(maybtrump),len(new_senti))
display(new_senti.head())
# Out:
# 11568 11568
#               polarity              source                                               text  created_at  retweet_count  favorite_count is_retweet                                            no_punc
# id
# 8.225021e+17       3.7  Twitter for iPhone  What truly matters is not which party controls...  2017-01-20        42790.0        180394.0      False  What truly matters is not which party controls...
# 8.225026e+17       3.9  Twitter for iPhone  We will bring back our jobs. We will bring bac...  2017-01-20        37458.0        173821.0      False  We will bring back our jobs  We will bring bac...
# 8.225029e+17       0.0  Twitter for iPhone  We will follow two simple rules: BUY AMERICAN ...  2017-01-20        38092.0        161358.0      False  We will follow two simple rules  BUY AMERICAN ...
# 8.225041e+17       0.0  Twitter for iPhone  So to all Americans in every city near and far...  2017-01-20        14039.0         86467.0      False  So to all Americans in every city near and far...
# 8.226691e+17       2.7  Twitter for iPhone  THANK YOU for another wonderful evening in Was...  2017-01-21        52468.0        289942.0      False  THANK YOU for another wonderful evening in Was...

# %% [markdown]
# ### The following section focuses on adding keyword tags to the dataset

# %%
keytags_politics_partisans =['crooked hilary|joe biden|obama administration|CORRUPTION','mexican wall','immigration|election medling|gun control','Nancy Pelsi','dem\W','dem party','impeach|impeachment','Russia','Putin'
                             ,'fake news']
keytags_foreign_policys =['ceasefire zones|USA soldiers|ISIS[\W]|Endless Wars','Nato\W','Middle East','Israel','Saudi\W','iran\W','iraq\W','middel east','missle'
                          ,'japan\W','korean','Mexican[\w\W]+Wall','Syria','Rocket Man','Turkey|Turks[\W|Syria|Kurdish|Kurd[\W]','china\W']
keytags_trade_war =['tpp','currency manipulate|currency manipulation','wto','unfair[\w\W]+trade'
                    ,'trade deficits|trade deficit','trade deal|trade deals','china[\w\W]+trade','trade','china','tariff'
                    ,'american[\w\W]+manufac','american first','free fair|SMART TRADE']
keytags_trade_war_senti =['worst trade deal|STUPID TRADE','currency manipulate|currency manipulation','china[\w\W]+tariff','new tariff|increase tariff','unfair[\w\W]+trade','taken advantage|taking advantage|ripped off']



trade_tags_all = []
sentiments_tags_all = []
trade_tags_score = []
foreign_policys=[]
politics_partisans=[]

foreign_tags_score_set = []
politics_tags_score_set = []

df_tweets = new_senti.copy()
counter =0

#do my own trade key tag point calculation
# regular trade key tag +1
# senti key tag +3

for i in range(len(df_tweets)) :
    #print(i)
    tagscore =0 
    politics_tag_score = 0
    foreign_tag_score = 0
    senti_tag =[]
    trade_tag =[]
    fp_tag =[]
    pp_tag =[]

    tweet_text = df_tweets.iloc[i,2]
    
    #trade tag, plus 2
    counter = 0
    for tag in keytags_trade_war:
        trade_tag = trade_tag + re.findall(tag,tweet_text, re.IGNORECASE)
        if len(trade_tag)>counter:
            counter +=1
            tagscore += 2
            print('trade tag:', i, trade_tag)
    
    #centi trade tag, plus 5
    counter = 0
    for tag in keytags_trade_war_senti:
        senti_tag = senti_tag + re.findall(tag,tweet_text, re.IGNORECASE)
        if len(senti_tag)>counter:
            counter +=1
            tagscore += 5
            print('trade centi:', i, trade_tag)
            #print(tweet_text)
    
    #foreign policy tag, plus 1
    counter = 0
    for tag in keytags_foreign_policys:
        fp_tag = fp_tag + re.findall(tag,tweet_text, re.IGNORECASE)
        if len(fp_tag)>counter:
            counter +=1
            foreign_tag_score +=1
            print('foreign policy:', i, fp_tag)
    
    for tag in keytags_politics_partisans:
        pp_tag = pp_tag + re.findall(tag,tweet_text, re.IGNORECASE)
        if len(pp_tag)>counter:
            counter +=1
            politics_tag_score +=1
            print('politics :', i, pp_tag)
            
    trade_tags_score.append(tagscore)   
    
    trade_tags_all.append(trade_tag)
    sentiments_tags_all.append(senti_tag)
    foreign_policys.append(fp_tag)
    politics_partisans.append(pp_tag)
    foreign_tags_score_set.append(foreign_tag_score)
    politics_tags_score_set.append(politics_tag_score)
print(counter)
# Out:
# politics : 12 ['FAKE NEWS']
# trade tag: 20 ['trade deficit']
# trade tag: 20 ['trade deficit', 'trade']
# trade tag: 24 ['trade deficits']
# trade tag: 24 ['trade deficits', 'trade']
# trade centi: 24 ['trade deficits', 'trade']
# politics : 29 ['FAKE NEWS']
# politics : 32 ['FAKE NEWS']
# foreign policy: 33 ['ISIS ']
# politics : 43 ['Obama Administration']
# foreign policy: 45 ['Iran ']
# foreign policy: 46 ['Iran ', 'Iran ']
# foreign policy: 46 ['Iran ', 'Iran ']
# foreign policy: 47 ['Iran ']
# politics : 48 ['FAKE NEWS']
# politics : 54 ['FAKE NEWS']
# politics : 60 ['fake news']
# foreign policy: 62 ['Iran ']
# politics : 62 ['Russia', 'Putin']
# politics : 70 ['FAKE NEWS']
# trade tag: 74 ['China']
# foreign policy: 74 ['China ']
# politics : 86 ['fake news']
# politics : 87 ['Russia']
# politics : 88 ['Russia']
# politics : 92 ['FAKE NEWS']
# politics : 98 ['FAKE NEWS']
# politics : 100 ['fake news']
# politics : 112 ['FAKE NEWS']
# politics : 127 ['Russia']
# politics : 128 ['Obama Administration']
# politics : 128 ['Obama Administration', 'Russia']
# politics : 129 ['Russia']
# politics : 137 ['Obama Administration']
# politics : 139 ['Russia']
# politics : 141 ['FAKE NEWS']
# trade tag: 165 ['China']
# foreign policy: 165 ['China ']
# foreign policy: 167 ['NATO ']
# politics : 168 ['Russia']
# politics : 168 ['Russia', 'FAKE NEWS']
# politics : 179 ['Russia', 'Russia']
# politics : 179 ['Russia', 'Russia']
# politics : 180 ['Russia', 'Russia', 'Russia', 'Russia']
# politics : 180 ['Russia', 'Russia', 'Russia', 'Russia']
# politics : 180 ['Russia', 'Russia', 'Russia', 'Russia']
# politics : 183 ['Russia', 'Russia']
# politics : 183 ['Russia', 'Russia']
# politics : 183 ['Russia', 'Russia', 'Fake News']
# foreign policy: 185 ['isis.']
# trade tag: 190 ['trade deficits']
# trade tag: 190 ['trade deficits', 'China will be a very difficult one in that we can no longer have massive trade']
# trade tag: 190 ['trade deficits', 'China will be a very difficult one in that we can no longer have massive trade', 'trade']
# trade tag: 190 ['trade deficits', 'China will be a very difficult one in that we can no longer have massive trade', 'trade', 'China']
# foreign policy: 190 ['China ']
# trade tag: 194 ['American Manufac']
# politics : 195 ['Russia']
# politics : 196 ['Russia']
# politics : 196 ['Russia', 'Fake News']
# trade tag: 197 ['trade']
# trade tag: 197 ['trade', 'American manufac']
# trade tag: 208 ['China']
# foreign policy: 208 ['China ']
# foreign policy: 209 ['Syria']
# foreign policy: 212 ['Israel']
# foreign policy: 213 ['Syria', 'Syria']
# foreign policy: 213 ['Syria', 'Syria']
# foreign policy: 216 ['NATO ']
# trade tag: 218 ['China']
# foreign policy: 218 ['China ']
# trade tag: 222 ['China']
# foreign policy: 222 ['Korean']
# foreign policy: 222 ['Korean', 'China ']
# trade tag: 236 ['China']
# foreign policy: 236 ['Korean']
# foreign policy: 236 ['Korean', 'China ']
# foreign policy: 239 ['Israel']
# trade tag: 253 ['Trade deficits']
# trade tag: 253 ['Trade deficits', 'Trade']
# trade tag: 265 ['China']
# foreign policy: 265 ['China ']
# politics : 275 ['Russia']
# politics : 278 ['Fake News']
# politics : 288 ['Fake News']
# politics : 292 ['Obama Administration']
# foreign policy: 293 ['Israel', 'Israel']
# foreign policy: 293 ['Israel', 'Israel']
# politics : 296 ['Russia']
# politics : 298 ['Russia']
# politics : 307 ['Russia']
# trade tag: 311 ['China', 'China']
# trade tag: 311 ['China', 'China']
# foreign policy: 311 ['China ', 'China ']
# politics : 315 ['Russia']
# foreign policy: 316 ['ISIS ']
# foreign policy: 318 ['Turkey']
# politics : 320 ['Obama Administration']
# politics : 322 ['Obama Administration']
# foreign policy: 325 ['Saudi ']
# foreign policy: 332 ['NATO.']
# foreign policy: 332 ['NATO.', 'Middle East']
# foreign policy: 332 ['NATO.', 'Middle East', 'Israel']
# foreign policy: 332 ['NATO.', 'Middle East', 'Israel', 'Saudi ']
# trade tag: 341 ['trade']
# trade tag: 342 ['trade']
# foreign policy: 344 ['Middle East']
# politics : 347 ['fake news']
# politics : 348 ['Fake News']
# politics : 349 ['fake news']
# trade tag: 352 ['trade deficit']
# trade tag: 352 ['trade deficit', 'trade']
# foreign policy: 352 ['NATO ']
# politics : 353 ['Russia']
# politics : 353 ['Russia', 'Fake News']
# politics : 354 ['Russia']
# politics : 356 ['Russia']
# foreign policy: 387 ['ISIS ']
# foreign policy: 389 ['Middle East']
# foreign policy: 390 ['Saudi ']
# politics : 403 ['Russia']
# politics : 404 ['impeach']
# politics : 409 ['Fake News']
# politics : 411 ['Fake News']
# politics : 417 ['Russia']
# politics : 419 ['Russia']
# politics : 422 ['Russia']
# politics : 423 ['Fake News']
# trade tag: 440 ['China', 'China']
# trade tag: 440 ['China', 'China']
# foreign policy: 440 ['China ', 'China ']
# politics : 446 ['Fake News']
# politics : 451 ['Russia']
# politics : 452 ['Russia']
# politics : 453 ['Dem ']
# politics : 465 ['Obama Administration']
# politics : 465 ['Obama Administration', 'Russia']
# politics : 467 ['Obama Administration']
# politics : 467 ['Obama Administration', 'Russia']
# politics : 468 ['Obama Administration']
# politics : 468 ['Obama Administration', 'Russia']
# politics : 474 ['Russia', 'Russia']
# politics : 474 ['Russia', 'Russia']
# politics : 479 ['Russia']
# politics : 482 ['Russia']
# politics : 482 ['Russia', 'Fake News']
# politics : 483 ['Fake News', 'Fake News']
# politics : 484 ['Fake News']
# politics : 485 ['FAKE NEWS']
# politics : 488 ['immigration']
# foreign policy: 496 ['Syria']
# trade tag: 501 ['trade deal']
# trade tag: 501 ['trade deal', 'trade']
# politics : 504 ['FAKE NEWS']
# politics : 520 ['Fake News']
# trade tag: 526 ['Trade']
# trade tag: 526 ['Trade', 'China', 'China']
# trade tag: 526 ['Trade', 'China', 'China']
# foreign policy: 526 ['China ', 'China ']
# foreign policy: 532 ['Japan ']
# politics : 534 ['Putin']
# trade tag: 538 ['trade deal']
# trade tag: 538 ['trade deal', 'trade']
# politics : 539 ['Russia']
# politics : 539 ['Russia', 'Putin']
# foreign policy: 540 ['Syria']
# politics : 542 ['Fake News']
# foreign policy: 543 ['Syria']
# politics : 546 ['Putin']
# foreign policy: 549 ['Japan ']
# politics : 557 ['Russia']
# trade tag: 574 ['trade deal']
# trade tag: 574 ['trade deal', 'trade']
# politics : 576 ['Fake News']
# politics : 586 ['Putin']
# politics : 586 ['Putin', 'Fake News']
# politics : 603 ['Russia', 'Russia']
# politics : 603 ['Russia', 'Russia']
# politics : 604 ['Dem…']
# politics : 604 ['Dem…', 'Russia']
# politics : 605 ['Russia']
# foreign policy: 607 ['Syria']
# politics : 608 ['Fake News']
# politics : 609 ['Fake News']
# politics : 614 ['Russia']
# trade tag: 615 ['Trade Deal']
# trade tag: 615 ['Trade Deal', 'Trade']
# politics : 630 ['Russia']
# politics : 643 ['Russia']
# trade tag: 649 ['China. Our foolish past leaders have allowed them to make hundreds of billions of dollars a year in trade']
# trade tag: 649 ['China. Our foolish past leaders have allowed them to make hundreds of billions of dollars a year in trade', 'trade']
# trade tag: 649 ['China. Our foolish past leaders have allowed them to make hundreds of billions of dollars a year in trade', 'trade', 'China']
# foreign policy: 649 ['China.']
# politics : 657 ['Fake News']
# politics : 660 ['immigration']
# politics : 663 ['Russia']
# politics : 670 ['Dem ']
# foreign policy: 681 ['ISIS ']
# trade tag: 682 ['China']
# foreign policy: 682 ['China ']
# politics : 685 ['Fake News']
# politics : 686 ['Russia']
# politics : 686 ['Russia', 'Fake News']
# politics : 688 ['Fake News']
# politics : 689 ['Russia']
# politics : 691 ['Fake News']
# foreign policy: 696 ['ISIS:']
# foreign policy: 697 ['isis ']
# politics : 699 ['Fake News']
# foreign policy: 702 ['Korean']
# foreign policy: 703 ['Korean']
# trade tag: 729 ['trade deal']
# trade tag: 729 ['trade deal', 'trade']
# trade centi: 729 ['trade deal', 'trade']
# trade tag: 731 ['trade deal']
# trade tag: 731 ['trade deal', 'trade']
# trade tag: 732 ['trade']
# politics : 736 ['Russia', 'Russia']
# politics : 736 ['Russia', 'Russia']
# politics : 752 ['Fake News']
# politics : 766 ['Fake News']
# politics : 772 ['Fake News']
# politics : 796 ['Fake News']
# foreign policy: 797 ['ISIS ']
# trade tag: 813 ['trade deal']
# trade tag: 813 ['trade deal', 'trade']
# trade centi: 813 ['trade deal', 'trade']
# trade tag: 833 ['China']
# foreign policy: 833 ['China ']
# politics : 840 ['immigration']
# politics : 841 ['Obama Administration']
# foreign policy: 857 ['Saudi ']
# politics : 878 ['FAKE NEWS']
# foreign policy: 891 ['ISIS ']
# politics : 893 ['Immigration']
# foreign policy: 901 ['Rocket Man']
# foreign policy: 926 ['Iran ']
# trade tag: 937 ['trade']
# politics : 946 ['Fake News']
# foreign policy: 957 ['Rocket Man']
# politics : 987 ['Fake News']
# politics : 1013 ['Fake News']
# politics : 1015 ['Fake News']
# politics : 1016 ['Fake News']
# politics : 1023 ['FAKE NEWS']
# politics : 1024 ['Fake News']
# foreign policy: 1026 ['Rocket Man']
# politics : 1034 ['Fake News', 'Fake News']
# politics : 1039 ['Fake News']
# politics : 1041 ['Fake News']
# foreign policy: 1050 ['Iran ']
# foreign policy: 1054 ['Iran ']
# politics : 1059 ['immigration']
# politics : 1063 ['Fake News']
# politics : 1065 ['Fake News']
# foreign policy: 1072 ['isis ']
# politics : 1079 ['Fake News']
# trade tag: 1088 ['trade']
# foreign policy: 1088 ['Iran ', 'Iran!']
# foreign policy: 1088 ['Iran ', 'Iran!']
# trade tag: 1099 ['TPP']
# politics : 1106 ['Fake News']
# politics : 1120 ['Russia']
# foreign policy: 1123 ['ISIS ']
# politics : 1124 ['Fake News']
# politics : 1131 ['Fake News']
# politics : 1132 ['Fake News']
# foreign policy: 1133 ['ISIS ']
# politics : 1134 ['Fake News']
# foreign policy: 1138 ['ISIS ']
# politics : 1140 ['FAKE NEWS']
# foreign policy: 1144 ['Iran ']
# politics : 1161 ['Russia']
# politics : 1164 ['Dem ']
# politics : 1164 ['Dem ', 'Russia']
# politics : 1167 ['Russia']
# politics : 1169 ['Fake News']
# politics : 1178 ['Russia', 'Russia']
# politics : 1178 ['Russia', 'Russia']
# politics : 1182 ['Fake News']
# politics : 1184 ['corruption']
# foreign policy: 1188 ['ISIS ']
# foreign policy: 1188 ['ISIS ', 'Middle East']
# foreign policy: 1200 ['ISIS ']
# politics : 1209 ['Dem ']
# foreign policy: 1212 ['ISIS ']
# trade tag: 1214 ['China']
# foreign policy: 1214 ['Japan ']
# foreign policy: 1214 ['Japan ', 'China ']
# foreign policy: 1220 ['Japan!']
# foreign policy: 1221 ['Japan🇯']
# foreign policy: 1222 ['Japan ']
# foreign policy: 1224 ['Saudi ']
# foreign policy: 1226 ['Japan🇯']
# trade tag: 1236 ['China']
# foreign policy: 1236 ['China.']
# trade tag: 1238 ['China']
# foreign policy: 1238 ['China!']
# trade tag: 1241 ['China I blame the incompetence of past Admins for allowing China to take advantage of the U.S. on trade']
# trade tag: 1241 ['China I blame the incompetence of past Admins for allowing China to take advantage of the U.S. on trade', 'trade']
# trade tag: 1241 ['China I blame the incompetence of past Admins for allowing China to take advantage of the U.S. on trade', 'trade', 'China', 'China', 'China']
# trade tag: 1241 ['China I blame the incompetence of past Admins for allowing China to take advantage of the U.S. on trade', 'trade', 'China', 'China', 'China']
# trade tag: 1241 ['China I blame the incompetence of past Admins for allowing China to take advantage of the U.S. on trade', 'trade', 'China', 'China', 'China']
# trade centi: 1241 ['China I blame the incompetence of past Admins for allowing China to take advantage of the U.S. on trade', 'trade', 'China', 'China', 'China']
# foreign policy: 1241 ['China ', 'China ', 'China ']
# trade tag: 1242 ['trade']
# trade tag: 1243 ['China', 'China']
# trade tag: 1243 ['China', 'China']
# foreign policy: 1243 ['China ', 'China ']
# trade tag: 1250 ['China']
# foreign policy: 1250 ['China ']
# trade tag: 1251 ['China']
# foreign policy: 1251 ['isis.']
# foreign policy: 1251 ['isis.', 'Syria']
# foreign policy: 1251 ['isis.', 'Syria', 'China ']
# foreign policy: 1252 ['Syria']
# politics : 1252 ['Russia', 'Russia']
# politics : 1253 ['Russia']
# politics : 1253 ['Russia', 'Putin']
# politics : 1253 ['Russia', 'Putin', 'Fake News']
# trade tag: 1259 ['TRADE deficits']
# trade tag: 1259 ['TRADE deficits', 'TRADE', 'TRADE']
# trade tag: 1259 ['TRADE deficits', 'TRADE', 'TRADE']
# trade tag: 1260 ['TRADE DEAL']
# trade tag: 1260 ['TRADE DEAL', 'TRADE']
# trade tag: 1271 ['China']
# foreign policy: 1271 ['China.']
# trade tag: 1272 ['Trade']
# trade tag: 1276 ['China']
# foreign policy: 1276 ['China ']
# trade tag: 1278 ['China']
# foreign policy: 1278 ['China ']
# trade tag: 1289 ['China', 'China', 'China']
# trade tag: 1289 ['China', 'China', 'China']
# trade tag: 1289 ['China', 'China', 'China']
# foreign policy: 1289 ['China ', 'China ', 'China ']
# foreign policy: 1293 ['Turkey']
# foreign policy: 1300 ['Iraq ']
# foreign policy: 1300 ['Iraq ', 'Turkey']
# foreign policy: 1308 ['Middle East']
# foreign policy: 1308 ['Middle East', 'Turkey']
# foreign policy: 1309 ['Turkey']
# politics : 1330 ['immigration', 'immigration']
# politics : 1330 ['immigration', 'immigration']
# politics : 1335 ['Fake News']
# politics : 1337 ['Fake News']
# politics : 1338 ['Fake News']
# trade tag: 1339 ['China']
# foreign policy: 1339 ['China ']
# trade tag: 1346 ['China']
# foreign policy: 1346 ['Rocket Man']
# foreign policy: 1346 ['Rocket Man', 'China ']
# politics : 1351 ['Immigration']
# politics : 1354 ['FAKE NEWS']
# politics : 1357 ['Russia', 'Russia', 'Russia']
# politics : 1357 ['Russia', 'Russia', 'Russia']
# politics : 1357 ['Russia', 'Russia', 'Russia', 'Fake News']
# politics : 1358 ['Fake News']
# foreign policy: 1360 ['isis ']
# foreign policy: 1370 ['Israel']
# politics : 1386 ['Fake News']
# politics : 1387 ['Fake News']
# politics : 1390 ['FAKE NEWS']
# politics : 1391 ['FAKE NEWS']
# politics : 1395 ['Fake News']
# politics : 1396 ['Fake News']
# politics : 1397 ['Russia']
# politics : 1397 ['Russia', 'FAKE NEWS']
# politics : 1398 ['Immigration']
# politics : 1402 ['Fake News']
# politics : 1426 ['Fake News']
# foreign policy: 1431 ['Middle East']
# foreign policy: 1451 ['ISIS ']
# politics : 1452 ['Immigration']
# politics : 1454 ['Fake News']
# foreign policy: 1455 ['Iran.']
# foreign policy: 1457 ['ISIS ']
# foreign policy: 1460 ['Iran ', 'Iran ']
# foreign policy: 1460 ['Iran ', 'Iran ']
# foreign policy: 1462 ['Iran ']
# foreign policy: 1466 ['Rocket man']
# foreign policy: 1472 ['Israel', 'Israel']
# foreign policy: 1472 ['Israel', 'Israel']
# foreign policy: 1473 ['Korean']
# politics : 1474 ['Fake News']
# foreign policy: 1476 ['Iran ']
# politics : 1483 ['Russia', 'Russia']
# politics : 1483 ['Russia', 'Russia']
# politics : 1483 ['Russia', 'Russia', 'Fake News']
# politics : 1488 ['Fake News']
# politics : 1489 ['Fake News']
# politics : 1490 ['Fake News']
# politics : 1496 ['immigration']
# politics : 1500 ['Russia']
# politics : 1501 ['Russia']
# politics : 1506 ['immigration']
# politics : 1515 ['immigration']
# politics : 1515 ['immigration', 'Dem ']
# politics : 1524 ['Fake News']
# politics : 1527 ['Russia']
# politics : 1538 ['immigration']
# trade tag: 1543 ['trade']
# politics : 1549 ['immigration']
# foreign policy: 1553 ['ISIS ']
# politics : 1558 ['immigration']
# foreign policy: 1570 ['Israel']
# politics : 1575 ['immigration']
# politics : 1584 ['Obama Administration']
# politics : 1587 ['Russia']
# politics : 1588 ['Russia', 'Russia', 'Russia']
# politics : 1588 ['Russia', 'Russia', 'Russia']
# politics : 1588 ['Russia', 'Russia', 'Russia']
# politics : 1598 ['immigration']
# politics : 1600 ['immigration']
# politics : 1601 ['immigration']
# foreign policy: 1606 ['Korean']
# politics : 1610 ['immigration']
# politics : 1613 ['Russia']
# politics : 1614 ['Obama Administration']
# politics : 1616 ['immigration', 'immigration']
# politics : 1616 ['immigration', 'immigration']
# politics : 1617 ['Fake News']
# foreign policy: 1619 ['Middle East']
# politics : 1625 ['Immigration']
# politics : 1627 ['immigration']
# politics : 1633 ['Fake News']
# politics : 1634 ['Russia']
# politics : 1635 ['Obama Administration']
# politics : 1635 ['Obama Administration', 'gun control']
# politics : 1636 ['Russia']
# politics : 1637 ['Russia', 'Russia']
# politics : 1637 ['Russia', 'Russia']
# trade tag: 1638 ['China']
# foreign policy: 1638 ['China ']
# politics : 1638 ['Russia', 'Russia', 'Russia', 'Russia']
# politics : 1638 ['Russia', 'Russia', 'Russia', 'Russia']
# politics : 1638 ['Russia', 'Russia', 'Russia', 'Russia']
# politics : 1639 ['Russia']
# politics : 1641 ['Fake News']
# politics : 1644 ['Russia']
# foreign policy: 1647 ['Syria']
# politics : 1647 ['Obama Administration', 'Russia']
# politics : 1649 ['Russia']
# politics : 1651 ['Russia']
# politics : 1651 ['Russia', 'Fake News']
# politics : 1652 ['Fake News']
# politics : 1655 ['Russia']
# politics : 1655 ['Russia', 'Fake News']
# politics : 1657 ['Obama Administration']
# politics : 1657 ['Obama Administration', 'Dem ']
# politics : 1657 ['Obama Administration', 'Dem ', 'Russia']
# politics : 1658 ['Obama Administration']
# politics : 1658 ['Obama Administration', 'Dem ']
# politics : 1658 ['Obama Administration', 'Dem ', 'Russia']
# politics : 1661 ['Fake News']
# politics : 1665 ['Fake News']
# politics : 1675 ['Russia', 'Russia']
# politics : 1675 ['Russia', 'Russia']
# trade tag: 1687 ['unfair trade and bad policy with countries from around the world. We must not let our country companies and workers be taken advantage of any longer. We want free fair and SMART TRADE']
# trade tag: 1687 ['unfair trade and bad policy with countries from around the world. We must not let our country companies and workers be taken advantage of any longer. We want free fair and SMART TRADE', 'trade', 'TRADE']
# trade tag: 1687 ['unfair trade and bad policy with countries from around the world. We must not let our country companies and workers be taken advantage of any longer. We want free fair and SMART TRADE', 'trade', 'TRADE']
# trade tag: 1687 ['unfair trade and bad policy with countries from around the world. We must not let our country companies and workers be taken advantage of any longer. We want free fair and SMART TRADE', 'trade', 'TRADE', 'free fair', 'SMART TRADE']
# trade centi: 1687 ['unfair trade and bad policy with countries from around the world. We must not let our country companies and workers be taken advantage of any longer. We want free fair and SMART TRADE', 'trade', 'TRADE', 'free fair', 'SMART TRADE']
# trade centi: 1687 ['unfair trade and bad policy with countries from around the world. We must not let our country companies and workers be taken advantage of any longer. We want free fair and SMART TRADE', 'trade', 'TRADE', 'free fair', 'SMART TRADE']
# trade tag: 1696 ['trade']
# trade tag: 1696 ['trade', 'tariff']
# trade tag: 1697 ['trade deficits']
# trade tag: 1697 ['trade deficits', 'trade']
# trade tag: 1697 ['trade deficits', 'trade', 'Tariff']
# trade tag: 1707 ['Trade Deficits', 'Trade Deficit']
# trade tag: 1707 ['Trade Deficits', 'Trade Deficit']
# trade tag: 1707 ['Trade Deficits', 'Trade Deficit', 'Trade', 'Trade']
# trade tag: 1707 ['Trade Deficits', 'Trade Deficit', 'Trade', 'Trade']
# foreign policy: 1711 ['Korean']
# trade tag: 1714 ['trade']
# trade tag: 1714 ['trade', 'tariff']
# trade tag: 1716 ['China']
# foreign policy: 1716 ['China ']
# trade tag: 1717 ['trade']
# trade tag: 1717 ['trade', 'tariff', 'tariff']
# trade tag: 1717 ['trade', 'tariff', 'tariff']
# politics : 1718 ['FAKE NEWS']
# trade tag: 1730 ['unfair trade']
# trade tag: 1730 ['unfair trade', 'trade']
# trade centi: 1730 ['unfair trade', 'trade']
# trade tag: 1734 ['Trade Deficit']
# trade tag: 1734 ['Trade Deficit', 'Trade']
# foreign policy: 1738 ['Iraq-']
# foreign policy: 1738 ['Iraq-', 'Syria']
# politics : 1742 ['corruption']
# politics : 1742 ['corruption', 'Russia']
# foreign policy: 1745 ['isis ']
# politics : 1753 ['Russia', 'Russia']
# politics : 1753 ['Russia', 'Russia', 'Putin']
# politics : 1753 ['Russia', 'Russia', 'Putin', 'Fake News']
# politics : 1754 ['Dem ']
# politics : 1757 ['Obama Administration']
# politics : 1757 ['Obama Administration', 'Russia']
# foreign policy: 1761 ['ISIS ']
# politics : 1764 ['Russia']
# politics : 1764 ['Russia', 'Fake News']
# politics : 1765 ['Russia']
# politics : 1768 ['Fake News']
# foreign policy: 1771 ['Korean']
# trade tag: 1772 ['China']
# foreign policy: 1772 ['China ']
# trade tag: 1773 ['Trade']
# foreign policy: 1773 ['Korean']
# politics : 1786 ['immigration']
# politics : 1787 ['Fake News']
# politics : 1790 ['Fake News']
# trade tag: 1799 ['China Adds Trade Penalties.” WRONG! Should read “Trump Defiant as U.S. Adds Trade']
# trade tag: 1799 ['China Adds Trade Penalties.” WRONG! Should read “Trump Defiant as U.S. Adds Trade', 'Trade', 'Trade']
# trade tag: 1799 ['China Adds Trade Penalties.” WRONG! Should read “Trump Defiant as U.S. Adds Trade', 'Trade', 'Trade', 'China']
# trade tag: 1799 ['China Adds Trade Penalties.” WRONG! Should read “Trump Defiant as U.S. Adds Trade', 'Trade', 'Trade', 'China']
# foreign policy: 1799 ['China ']
# trade tag: 1805 ['unfair trade']
# trade tag: 1805 ['unfair trade', 'China in 40 years. They must end unfair trade']
# trade tag: 1805 ['unfair trade', 'China in 40 years. They must end unfair trade', 'Trade', 'trade']
# trade tag: 1805 ['unfair trade', 'China in 40 years. They must end unfair trade', 'Trade', 'trade', 'China']
# trade tag: 1805 ['unfair trade', 'China in 40 years. They must end unfair trade', 'Trade', 'trade', 'China', 'Tariff']
# trade tag: 1805 ['unfair trade', 'China in 40 years. They must end unfair trade', 'Trade', 'trade', 'China', 'Tariff']
# trade centi: 1805 ['unfair trade', 'China in 40 years. They must end unfair trade', 'Trade', 'trade', 'China', 'Tariff']
# trade centi: 1805 ['unfair trade', 'China in 40 years. They must end unfair trade', 'Trade', 'trade', 'China', 'Tariff']
# foreign policy: 1805 ['China ']
# foreign policy: 1812 ['Iran ']
# foreign policy: 1812 ['Iran ', 'Syria', 'Syria']
# foreign policy: 1812 ['Iran ', 'Syria', 'Syria']
# trade tag: 1815 ['China there is a Tariff to be paid of 2 1/2%. When a car is sent to China from the United States there is a Tariff to be paid of 25%. Does that sound like free or fair trade.  No it sounds like STUPID TRADE']
# trade tag: 1815 ['China there is a Tariff to be paid of 2 1/2%. When a car is sent to China from the United States there is a Tariff to be paid of 25%. Does that sound like free or fair trade.  No it sounds like STUPID TRADE', 'trade', 'TRADE']
# trade tag: 1815 ['China there is a Tariff to be paid of 2 1/2%. When a car is sent to China from the United States there is a Tariff to be paid of 25%. Does that sound like free or fair trade.  No it sounds like STUPID TRADE', 'trade', 'TRADE', 'China', 'China']
# trade tag: 1815 ['China there is a Tariff to be paid of 2 1/2%. When a car is sent to China from the United States there is a Tariff to be paid of 25%. Does that sound like free or fair trade.  No it sounds like STUPID TRADE', 'trade', 'TRADE', 'China', 'China', 'Tariff', 'Tariff']
# trade tag: 1815 ['China there is a Tariff to be paid of 2 1/2%. When a car is sent to China from the United States there is a Tariff to be paid of 25%. Does that sound like free or fair trade.  No it sounds like STUPID TRADE', 'trade', 'TRADE', 'China', 'China', 'Tariff', 'Tariff']
# trade tag: 1815 ['China there is a Tariff to be paid of 2 1/2%. When a car is sent to China from the United States there is a Tariff to be paid of 25%. Does that sound like free or fair trade.  No it sounds like STUPID TRADE', 'trade', 'TRADE', 'China', 'China', 'Tariff', 'Tariff']
# trade tag: 1815 ['China there is a Tariff to be paid of 2 1/2%. When a car is sent to China from the United States there is a Tariff to be paid of 25%. Does that sound like free or fair trade.  No it sounds like STUPID TRADE', 'trade', 'TRADE', 'China', 'China', 'Tariff', 'Tariff']
# trade centi: 1815 ['China there is a Tariff to be paid of 2 1/2%. When a car is sent to China from the United States there is a Tariff to be paid of 25%. Does that sound like free or fair trade.  No it sounds like STUPID TRADE', 'trade', 'TRADE', 'China', 'China', 'Tariff', 'Tariff']
# trade centi: 1815 ['China there is a Tariff to be paid of 2 1/2%. When a car is sent to China from the United States there is a Tariff to be paid of 25%. Does that sound like free or fair trade.  No it sounds like STUPID TRADE', 'trade', 'TRADE', 'China', 'China', 'Tariff', 'Tariff']
# foreign policy: 1815 ['China ', 'China ']
# trade tag: 1819 ['China']
# foreign policy: 1819 ['China’']
# politics : 1821 ['Russia']
# foreign policy: 1822 ['Syria']
# politics : 1822 ['Russia', 'Russia']
# politics : 1823 ['Russia', 'Russia']
# politics : 1823 ['Russia', 'Russia']
# foreign policy: 1829 ['ISIS.']
# foreign policy: 1829 ['ISIS.', 'Syria']
# trade tag: 1834 ['TPP', 'TPP']
# trade tag: 1834 ['TPP', 'TPP']
# trade tag: 1834 ['TPP', 'TPP', 'trade']
# foreign policy: 1834 ['Japan ']
# politics : 1847 ['Fake News']
# foreign policy: 1857 ['Syria']
# foreign policy: 1865 ['Turkey']
# trade tag: 1866 ['TPP']
# trade tag: 1866 ['TPP', 'WTO']
# foreign policy: 1866 ['Japan ']
# politics : 1871 ['Fake News']
# foreign policy: 1873 ['Israel']
# foreign policy: 1874 ['Japan ']
# foreign policy: 1875 ['Japan ']
# politics : 1895 ['Fake News']
# politics : 1902 ['immigration']
# politics : 1905 ['Immigration']
# trade tag: 1911 ['unfairly for many years by many countries on trade']
# trade tag: 1911 ['unfairly for many years by many countries on trade', 'trade']
# trade centi: 1911 ['unfairly for many years by many countries on trade', 'trade']
# politics : 1918 ['Russia', 'Russia']
# politics : 1918 ['Russia', 'Russia']
# politics : 1920 ['Russia']
# politics : 1921 ['Russia']
# politics : 1924 ['Russia']
# politics : 1929 ['Russia']
# trade tag: 1930 ['Trade Deficit']
# trade tag: 1930 ['Trade Deficit', 'China to begin talks on the Massive Trade']
# trade tag: 1930 ['Trade Deficit', 'China to begin talks on the Massive Trade', 'Trade']
# trade tag: 1930 ['Trade Deficit', 'China to begin talks on the Massive Trade', 'Trade', 'China']
# foreign policy: 1930 ['China ']
# trade tag: 1932 ['Trade Deficits']
# trade tag: 1932 ['Trade Deficits', 'China over Trade']
# trade tag: 1932 ['Trade Deficits', 'China over Trade', 'Trade']
# trade tag: 1932 ['Trade Deficits', 'China over Trade', 'Trade', 'China']
# foreign policy: 1932 ['China ']
# trade tag: 1937 ['China trying to negotiate a level playing field on trade']
# trade tag: 1937 ['China trying to negotiate a level playing field on trade', 'trade']
# trade tag: 1937 ['China trying to negotiate a level playing field on trade', 'trade', 'China']
# foreign policy: 1937 ['China ']
# politics : 1943 ['immigration']
# foreign policy: 1953 ['Iran ']
# trade tag: 1955 ['China this morning at 8:30. The primary topics will be Trade']
# trade tag: 1955 ['China this morning at 8:30. The primary topics will be Trade', 'Trade']
# trade tag: 1955 ['China this morning at 8:30. The primary topics will be Trade', 'Trade', 'China']
# foreign policy: 1955 ['China ']
# foreign policy: 1957 ['Iran ']
# politics : 1958 ['Fake News']
# foreign policy: 1964 ['Iran ']
# politics : 1966 ['Fake News']
# foreign policy: 1968 ['Iran’']
# foreign policy: 1970 ['Israel']
# trade tag: 1971 ['trade deal']
# trade tag: 1971 ['trade deal', 'trade']
# trade tag: 1971 ['trade deal', 'trade', 'China']
# foreign policy: 1971 ['China ']
# politics : 1976 ['Russia']
# politics : 1976 ['Russia', 'Fake News']
# trade tag: 1978 ['trade deal']
# trade tag: 1978 ['trade deal', 'China. Nothing has happened with ZTE except as it pertains to the larger trade']
# trade tag: 1978 ['trade deal', 'China. Nothing has happened with ZTE except as it pertains to the larger trade', 'trade', 'trade']
# trade tag: 1978 ['trade deal', 'China. Nothing has happened with ZTE except as it pertains to the larger trade', 'trade', 'trade', 'China', 'China']
# trade tag: 1978 ['trade deal', 'China. Nothing has happened with ZTE except as it pertains to the larger trade', 'trade', 'trade', 'China', 'China']
# trade tag: 1978 ['trade deal', 'China. Nothing has happened with ZTE except as it pertains to the larger trade', 'trade', 'trade', 'China', 'China']
# foreign policy: 1978 ['China.', 'China.']
# trade tag: 1979 ['China', 'China']
# trade tag: 1979 ['China', 'China']
# foreign policy: 1979 ['China’', 'China ']
# trade tag: 1980 ['China']
# foreign policy: 1980 ['China ']
# politics : 1986 ['Fake News']
# trade tag: 1988 ['trade']
# trade tag: 1988 ['trade', 'China']
# foreign policy: 1988 ['China ']
# politics : 1998 ['Russia']
# politics : 1999 ['corruption']
# politics : 1999 ['corruption', 'Russia']
# politics : 2001 ['Russia']
# politics : 2002 ['Corruption']
# politics : 2004 ['Russia']
# trade tag: 2006 ['China including Theft of Intellectual Property etc.? They did NOTHING! With that being said Chuck &amp; I have long agreed on this issue! Fair Trade']
# trade tag: 2006 ['China including Theft of Intellectual Property etc.? They did NOTHING! With that being said Chuck &amp; I have long agreed on this issue! Fair Trade', 'Trade', 'Trade']
# trade tag: 2006 ['China including Theft of Intellectual Property etc.? They did NOTHING! With that being said Chuck &amp; I have long agreed on this issue! Fair Trade', 'Trade', 'Trade', 'China', 'China']
# trade tag: 2006 ['China including Theft of Intellectual Property etc.? They did NOTHING! With that being said Chuck &amp; I have long agreed on this issue! Fair Trade', 'Trade', 'Trade', 'China', 'China']
# trade tag: 2006 ['China including Theft of Intellectual Property etc.? They did NOTHING! With that being said Chuck &amp; I have long agreed on this issue! Fair Trade', 'Trade', 'Trade', 'China', 'China']
# foreign policy: 2006 ['China ', 'China ']
# trade tag: 2007 ['China']
# foreign policy: 2007 ['China ']
# politics : 2014 ['Russia']
# politics : 2027 ['Russia']
# politics : 2032 ['Obama Administration']
# trade tag: 2033 ['Trade Deal']
# trade tag: 2033 ['Trade Deal', 'Trade']
# foreign policy: 2033 ['Iran)']
# politics : 2036 ['Russia']
# politics : 2037 ['Russia']
# politics : 2039 ['Russia']
# politics : 2040 ['Russia']
# politics : 2042 ['Russia']
# politics : 2057 ['Russia']
# politics : 2059 ['Russia']
# politics : 2063 ['Russia']
# politics : 2066 ['Russia']
# trade tag: 2067 ['Trade', 'trade', 'trade']
# trade tag: 2067 ['Trade', 'trade', 'trade']
# trade tag: 2067 ['Trade', 'trade', 'trade']
# trade tag: 2072 ['China']
# foreign policy: 2072 ['China ']
# politics : 2073 ['corruption']
# politics : 2073 ['corruption', 'Russia']
# politics : 2073 ['corruption', 'Russia', 'Fake News']
# trade tag: 2074 ['Tariff', 'Tariff']
# trade tag: 2074 ['Tariff', 'Tariff']
# trade tag: 2075 ['Trade', 'Trade', 'Trade']
# trade tag: 2075 ['Trade', 'Trade', 'Trade']
# trade tag: 2075 ['Trade', 'Trade', 'Trade']
# trade centi: 2075 ['Trade', 'Trade', 'Trade']
# trade tag: 2079 ['trade deal']
# trade tag: 2079 ['trade deal', 'trade']
# politics : 2082 ['Russia']
# politics : 2082 ['Russia', 'Fake News']
# politics : 2089 ['Russia']
# politics : 2098 ['Fake News']
# politics : 2099 ['Fake News']
# politics : 2100 ['Fake News']
# trade tag: 2103 ['trade deal']
# trade tag: 2103 ['trade deal', 'Trade', 'trade']
# trade tag: 2103 ['trade deal', 'Trade', 'trade']
# trade centi: 2103 ['trade deal', 'Trade', 'trade']
# trade tag: 2109 ['Trade']
# foreign policy: 2109 ['Japan ']
# politics : 2110 ['corruption']
# foreign policy: 2112 ['Iran ']
# foreign policy: 2115 ['Japan ']
# trade tag: 2116 ['trade']
# foreign policy: 2116 ['Japan ', 'Japan ']
# foreign policy: 2116 ['Japan ', 'Japan ']
# foreign policy: 2117 ['Japan!']
# trade tag: 2118 ['trade']
# trade tag: 2118 ['trade', 'tariff']
# trade tag: 2119 ['Trade', 'Trade']
# trade tag: 2119 ['Trade', 'Trade']
# trade tag: 2119 ['Trade', 'Trade', 'Tariff', 'tariff']
# trade tag: 2119 ['Trade', 'Trade', 'Tariff', 'tariff']
# foreign policy: 2120 ['Iran ']
# trade tag: 2122 ['unfair trade']
# trade tag: 2122 ['unfair trade', 'trade']
# trade centi: 2122 ['unfair trade', 'trade']
# politics : 2122 ['Russia']
# trade tag: 2128 ['Tariff']
# trade tag: 2129 ['Trade', 'Trade']
# trade tag: 2129 ['Trade', 'Trade']
# trade tag: 2129 ['Trade', 'Trade', 'Tariff']
# trade tag: 2131 ['Tariff', 'Tariff']
# trade tag: 2131 ['Tariff', 'Tariff']
# trade tag: 2132 ['Tariff', 'Tariff']
# trade tag: 2132 ['Tariff', 'Tariff']
# trade tag: 2134 ['Trade', 'Trade', 'Trade']
# trade tag: 2134 ['Trade', 'Trade', 'Trade']
# trade tag: 2134 ['Trade', 'Trade', 'Trade']
# trade tag: 2135 ['Trade']
# foreign policy: 2135 ['NATO-']
# trade tag: 2136 ['unfairly clobbered on Trade']
# trade tag: 2136 ['unfairly clobbered on Trade', 'Trade']
# trade centi: 2136 ['unfairly clobbered on Trade', 'Trade']
# foreign policy: 2136 ['NATO ']
# foreign policy: 2138 ['missle']
# trade tag: 2139 ['trade']
# politics : 2160 ['Fake News', 'Fake News']
# politics : 2163 ['Russia']
# politics : 2163 ['Russia', 'Fake News']
# politics : 2168 ['Russia']
# politics : 2174 ['immigration']
# politics : 2174 ['immigration', 'Dem ']
# politics : 2177 ['Immigration']
# politics : 2178 ['Immigration']
# politics : 2181 ['Immigration', 'Immigration']
# politics : 2181 ['Immigration', 'Immigration']
# trade tag: 2182 ['Trade']
# trade tag: 2182 ['Trade', 'Tariff', 'Tariff', 'Tariff']
# trade tag: 2182 ['Trade', 'Tariff', 'Tariff', 'Tariff']
# trade tag: 2182 ['Trade', 'Tariff', 'Tariff', 'Tariff']
# politics : 2186 ['IMMIGRATION']
# politics : 2188 ['Russia']
# trade tag: 2191 ['trade deal']
# trade tag: 2191 ['trade deal', 'trade', 'trade']
# trade tag: 2191 ['trade deal', 'trade', 'trade']
# politics : 2191 ['immigration']
# politics : 2197 ['Russia']
# trade tag: 2199 ['Trade', 'Trade']
# trade tag: 2199 ['Trade', 'Trade']
# trade tag: 2199 ['Trade', 'Trade', 'Tariff', 'Tariff']
# trade tag: 2199 ['Trade', 'Trade', 'Tariff', 'Tariff']
# trade tag: 2210 ['unfair trade']
# trade tag: 2210 ['unfair trade', 'Trade', 'trade']
# trade tag: 2210 ['unfair trade', 'Trade', 'trade']
# trade tag: 2210 ['unfair trade', 'Trade', 'trade', 'Tariff', 'Tariff']
# trade tag: 2210 ['unfair trade', 'Trade', 'trade', 'Tariff', 'Tariff']
# trade centi: 2210 ['unfair trade', 'Trade', 'trade', 'Tariff', 'Tariff']
# trade tag: 2211 ['trade']
# trade tag: 2211 ['trade', 'tariff', 'tariff']
# trade tag: 2211 ['trade', 'tariff', 'tariff']
# trade tag: 2212 ['tariff']
# trade tag: 2213 ['Trade']
# trade tag: 2213 ['Trade', 'Tariff', 'Tariff']
# trade tag: 2213 ['Trade', 'Tariff', 'Tariff']
# trade centi: 2213 ['Trade', 'Tariff', 'Tariff']
# politics : 2223 ['IMMIGRATION']
# foreign policy: 2251 ['Iran ']
# politics : 2262 ['IMMIGRATION']
# politics : 2268 ['Russia']
# foreign policy: 2275 ['NATO ', 'NATO ']
# foreign policy: 2275 ['NATO ', 'NATO ']
# trade centi: 2276 []
# trade tag: 2282 ['Trade']
# trade tag: 2282 ['Trade', 'Tariff']
# foreign policy: 2282 ['NATO.']
# trade tag: 2283 ['trade deal']
# trade tag: 2283 ['trade deal', 'trade']
# foreign policy: 2284 ['NATO ']
# trade tag: 2287 ['trade deficit']
# trade tag: 2287 ['trade deficit', 'trade']
# foreign policy: 2287 ['NATO ']
# foreign policy: 2288 ['NATO ']
# trade tag: 2289 ['trade']
# trade tag: 2289 ['trade', 'tariff']
# politics : 2291 ['Immigration']
# trade tag: 2295 ['Trade']
# foreign policy: 2295 ['NATO ']
# foreign policy: 2296 ['NATO ']
# politics : 2296 ['Russia', 'Russia']
# politics : 2301 ['Russia']
# politics : 2303 ['Putin']
# trade tag: 2304 ['trade deal']
# trade tag: 2304 ['trade deal', 'trade']
# trade centi: 2304 ['trade deal', 'trade']
# politics : 2305 ['Obama Administration']
# politics : 2305 ['Obama Administration', 'Russia']
# politics : 2307 ['Obama Administration']
# politics : 2307 ['Obama Administration', 'Russia']
# politics : 2308 ['Putin']
# politics : 2308 ['Putin', 'Fake News', 'Fake News']
# politics : 2311 ['Russia']
# politics : 2314 ['Fake News', 'FAKE NEWS']
# politics : 2315 ['Russia']
# politics : 2315 ['Russia', 'Putin']
# politics : 2317 ['Russia']
# politics : 2317 ['Russia', 'Putin']
# foreign policy: 2318 ['NATO ', 'NATO ']
# foreign policy: 2318 ['NATO ', 'NATO ']
# politics : 2322 ['Russia']
# politics : 2325 ['Putin']
# politics : 2325 ['Putin', 'Fake News']
# politics : 2327 ['Putin']
# foreign policy: 2328 ['NATO ']
# politics : 2329 ['Russia']
# trade tag: 2331 ['Trade Deal']
# trade tag: 2331 ['Trade Deal', 'Trade']
# politics : 2335 ['Fake News']
# politics : 2336 ['Russia']
# politics : 2336 ['Russia', 'Putin']
# politics : 2336 ['Russia', 'Putin', 'Fake News']
# politics : 2337 ['Russia']
# politics : 2337 ['Russia', 'Fake News']
# trade centi: 2338 []
# trade tag: 2339 ['trade']
# foreign policy: 2339 ['Middle East']
# trade tag: 2341 ['China']
# foreign policy: 2341 ['China ']
# trade tag: 2342 ['currency manipulation']
# trade tag: 2342 ['currency manipulation', 'Trade Deal']
# trade tag: 2342 ['currency manipulation', 'Trade Deal', 'Trade']
# trade centi: 2342 ['currency manipulation', 'Trade Deal', 'Trade']
# trade tag: 2343 ['Trade Deal']
# trade tag: 2343 ['Trade Deal', 'Trade']
# trade tag: 2343 ['Trade Deal', 'Trade', 'Tariff']
# politics : 2346 ['Russia']
# politics : 2346 ['Russia', 'Fake News']
# politics : 2348 ['Putin']
# politics : 2348 ['Putin', 'Fake News']
# politics : 2354 ['Putin']
# politics : 2354 ['Putin', 'Fake News']
# politics : 2358 ['Russia']
# trade tag: 2363 ['unfairly on Trade']
# trade tag: 2363 ['unfairly on Trade', 'Trade']
# trade tag: 2363 ['unfairly on Trade', 'Trade', 'Tariff', 'Tariff']
# trade tag: 2363 ['unfairly on Trade', 'Trade', 'Tariff', 'Tariff']
# trade centi: 2363 ['unfairly on Trade', 'Trade', 'Tariff', 'Tariff']
# politics : 2370 ['Russia']
# trade tag: 2371 ['unfair Tariffs I wonder what can they be thinking? Are we just going to continue and let our farmers and country get ripped off?  Lost $817 Billion on Trade']
# trade tag: 2371 ['unfair Tariffs I wonder what can they be thinking? Are we just going to continue and let our farmers and country get ripped off?  Lost $817 Billion on Trade', 'Trade', 'Trade']
# trade tag: 2371 ['unfair Tariffs I wonder what can they be thinking? Are we just going to continue and let our farmers and country get ripped off?  Lost $817 Billion on Trade', 'Trade', 'Trade']
# trade tag: 2371 ['unfair Tariffs I wonder what can they be thinking? Are we just going to continue and let our farmers and country get ripped off?  Lost $817 Billion on Trade', 'Trade', 'Trade', 'Tariff', 'Tariff']
# trade tag: 2371 ['unfair Tariffs I wonder what can they be thinking? Are we just going to continue and let our farmers and country get ripped off?  Lost $817 Billion on Trade', 'Trade', 'Trade', 'Tariff', 'Tariff']
# trade centi: 2371 ['unfair Tariffs I wonder what can they be thinking? Are we just going to continue and let our farmers and country get ripped off?  Lost $817 Billion on Trade', 'Trade', 'Trade', 'Tariff', 'Tariff']
# trade centi: 2371 ['unfair Tariffs I wonder what can they be thinking? Are we just going to continue and let our farmers and country get ripped off?  Lost $817 Billion on Trade', 'Trade', 'Trade', 'Tariff', 'Tariff']
# trade tag: 2373 ['China', 'China']
# trade tag: 2373 ['China', 'China']
# foreign policy: 2373 ['China ', 'China ']
# trade tag: 2376 ['trade', 'trade']
# trade tag: 2376 ['trade', 'trade']
# trade tag: 2383 ['trade']
# politics : 2391 ['Russia']
# politics : 2391 ['Russia', 'Fake News']
# politics : 2397 ['Fake News']
# politics : 2402 ['Fake News']
# politics : 2403 ['Fake News']
# politics : 2405 ['Fake News', 'Fake News']
# trade tag: 2406 ['Trade Deficit']
# trade tag: 2406 ['Trade Deficit', 'Trade']
# politics : 2407 ['Immigration']
# politics : 2411 ['Russia']
# politics : 2413 ['Immigration']
# trade tag: 2420 ['Trade']
# politics : 2432 ['Russia']
# politics : 2433 ['Russia', 'Russia']
# politics : 2433 ['Russia', 'Russia']
# foreign policy: 2435 ['Korean']
# politics : 2436 ['Fake News']
# politics : 2440 ['FAKE NEWS']
# politics : 2447 ['RUSSIA']
# politics : 2456 ['Russia']
# trade tag: 2459 ['Trade Deal']
# trade tag: 2459 ['Trade Deal', 'China market has dropped 27% in last 4months and they are talking to us. Our market is stronger than ever and will go up dramatically when these horrible Trade']
# trade tag: 2459 ['Trade Deal', 'China market has dropped 27% in last 4months and they are talking to us. Our market is stronger than ever and will go up dramatically when these horrible Trade', 'Trade']
# trade tag: 2459 ['Trade Deal', 'China market has dropped 27% in last 4months and they are talking to us. Our market is stronger than ever and will go up dramatically when these horrible Trade', 'Trade', 'China']
# trade tag: 2459 ['Trade Deal', 'China market has dropped 27% in last 4months and they are talking to us. Our market is stronger than ever and will go up dramatically when these horrible Trade', 'Trade', 'China', 'Tariff']
# foreign policy: 2459 ['China ']
# trade tag: 2460 ['trade deal']
# trade tag: 2460 ['trade deal', 'trade']
# trade tag: 2460 ['trade deal', 'trade', 'Tariff', 'Tariff']
# trade tag: 2460 ['trade deal', 'trade', 'Tariff', 'Tariff']
# politics : 2463 ['Fake News']
# trade tag: 2464 ['Trade Deal']
# trade tag: 2464 ['Trade Deal', 'Trade']
# trade tag: 2464 ['Trade Deal', 'Trade', 'Tariff']
# politics : 2464 ['Obama Administration']
# politics : 2468 ['Russia', 'Russia', 'Russia']
# politics : 2468 ['Russia', 'Russia', 'Russia']
# politics : 2468 ['Russia', 'Russia', 'Russia']
# politics : 2469 ['Russia']
# trade tag: 2470 ['Trade Deal']
# trade tag: 2470 ['Trade Deal', 'Trade']
# politics : 2470 ['Immigration']
# trade tag: 2478 ['China']
# foreign policy: 2478 ['Iran ']
# foreign policy: 2478 ['Iran ', 'China ']
# politics : 2480 ['Russia']
# politics : 2489 ['Fake News']
# politics : 2491 ['Fake News']
# trade tag: 2500 ['china']
# politics : 2515 ['Russia']
# trade tag: 2517 ['unfair Trade']
# trade tag: 2517 ['unfair Trade', 'Trade Deal', 'Trade Deal']
# trade tag: 2517 ['unfair Trade', 'Trade Deal', 'Trade Deal']
# trade tag: 2517 ['unfair Trade', 'Trade Deal', 'Trade Deal', 'Trade', 'Trade']
# trade tag: 2517 ['unfair Trade', 'Trade Deal', 'Trade Deal', 'Trade', 'Trade']
# trade tag: 2517 ['unfair Trade', 'Trade Deal', 'Trade Deal', 'Trade', 'Trade', 'Tariff', 'Tariff']
# trade tag: 2517 ['unfair Trade', 'Trade Deal', 'Trade Deal', 'Trade', 'Trade', 'Tariff', 'Tariff']
# trade centi: 2517 ['unfair Trade', 'Trade Deal', 'Trade Deal', 'Trade', 'Trade', 'Tariff', 'Tariff']
# politics : 2524 ['FAKE NEWS']
# politics : 2526 ['FAKE NEWS']
# trade centi: 2527 []
# foreign policy: 2527 ['Turkey', 'Turkey']
# foreign policy: 2527 ['Turkey', 'Turkey']
# politics : 2529 ['RUSSIA', 'Russia']
# politics : 2529 ['RUSSIA', 'Russia']
# politics : 2538 ['Russia']
# politics : 2546 ['corruption']
# politics : 2547 ['Fake News']
# politics : 2548 ['Fake News']
# politics : 2549 ['corruption']
# trade tag: 2552 ['China']
# foreign policy: 2552 ['China.']
# politics : 2558 ['Fake News']
# trade tag: 2582 ['Trade Deal']
# trade tag: 2582 ['Trade Deal', 'Trade']
# politics : 2584 ['Russia']
# politics : 2586 ['Fake News']
# foreign policy: 2588 ['Korean']
# trade tag: 2589 ['China']
# foreign policy: 2589 ['China ']
# politics : 2593 ['Fake News']
# politics : 2594 ['corruption']
# politics : 2596 ['corruption']
# trade tag: 2598 ['Trade']
# politics : 2606 ['Fake News']
# trade tag: 2608 ['Trade']
# trade tag: 2613 ['Trade Deal']
# trade tag: 2613 ['Trade Deal', 'trade', 'Trade']
# trade tag: 2613 ['Trade Deal', 'trade', 'Trade']
# trade tag: 2613 ['Trade Deal', 'trade', 'Trade', 'Tariff']
# trade tag: 2619 ['China']
# foreign policy: 2619 ['China.']
# politics : 2623 ['Russia']
# politics : 2624 ['Fake News']
# trade tag: 2628 ['China']
# foreign policy: 2628 ['China’']
# politics : 2629 ['Fake News']
# politics : 2631 ['Russia']
# politics : 2634 ['Fake News']
# politics : 2635 ['Fake News']
# politics : 2636 ['Russia']
# politics : 2637 ['Fake News']
# politics : 2644 ['Fake News']
# trade centi: 2646 []
# politics : 2647 ['corruption']
# trade tag: 2650 ['Trade']
# trade tag: 2652 ['Trade Deal']
# trade tag: 2652 ['Trade Deal', 'Trade']
# politics : 2654 ['Russia']
# politics : 2655 ['Russia']
# trade tag: 2656 ['Trade Deal']
# trade tag: 2656 ['Trade Deal', 'Trade']
# foreign policy: 2658 ['NATO…']
# politics : 2660 ['Dem!']
# trade tag: 2661 ['Trade Deal']
# trade tag: 2661 ['Trade Deal', 'Trade']
# trade centi: 2661 ['Trade Deal', 'Trade']
# politics : 2662 ['Dem!']
# foreign policy: 2665 ['Iran ']
# foreign policy: 2666 ['Syria']
# politics : 2667 ['FAKE NEWS']
# politics : 2673 ['Dem ']
# politics : 2684 ['Corruption']
# politics : 2684 ['Corruption', 'Fake News']
# trade tag: 2708 ['China', 'China']
# trade tag: 2708 ['China', 'China']
# foreign policy: 2708 ['China ', 'China ']
# politics : 2720 ['Russia', 'Russia']
# politics : 2720 ['Russia', 'Russia']
# politics : 2726 ['Russia']
# politics : 2733 ['corruption']
# trade tag: 2736 ['China']
# trade tag: 2736 ['China', 'Tariff']
# trade centi: 2736 ['China', 'Tariff']
# foreign policy: 2736 ['China ']
# politics : 2757 ['Fake News']
# politics : 2765 ['corruption']
# politics : 2765 ['corruption', 'Russia']
# politics : 2766 ['Russia']
# politics : 2766 ['Russia', 'Fake News']
# trade tag: 2780 ['Tariff', 'Tariff']
# trade tag: 2780 ['Tariff', 'Tariff']
# trade tag: 2789 ['China has been taking advantage of the United States on Trade']
# trade tag: 2789 ['China has been taking advantage of the United States on Trade', 'Trade']
# trade tag: 2789 ['China has been taking advantage of the United States on Trade', 'Trade', 'China', 'China']
# trade tag: 2789 ['China has been taking advantage of the United States on Trade', 'Trade', 'China', 'China']
# trade centi: 2789 ['China has been taking advantage of the United States on Trade', 'Trade', 'China', 'China']
# foreign policy: 2789 ['China ', 'China ']
# trade tag: 2829 ['Trade']
# foreign policy: 2829 ['Japan ', 'Japan ']
# foreign policy: 2829 ['Japan ', 'Japan ']
# trade tag: 2846 ['China is actually placing propaganda ads in the Des Moines Register and other papers made to look like news. That’s because we are beating them on Trade']
# trade tag: 2846 ['China is actually placing propaganda ads in the Des Moines Register and other papers made to look like news. That’s because we are beating them on Trade', 'Trade']
# trade tag: 2846 ['China is actually placing propaganda ads in the Des Moines Register and other papers made to look like news. That’s because we are beating them on Trade', 'Trade', 'China']
# foreign policy: 2846 ['China ']
# trade tag: 2856 ['Trade']
# trade tag: 2857 ['Trade']
# politics : 2916 ['FAKE NEWS']
# foreign policy: 2946 ['Saudi ', 'Saudi ']
# foreign policy: 2946 ['Saudi ', 'Saudi ']
# foreign policy: 2946 ['Saudi ', 'Saudi ', 'Turkey']
# politics : 2953 ['Obama Administration']
# politics : 2963 ['FAKE NEWS']
# politics : 2966 ['immigration']
# trade tag: 2984 ['Trade']
# foreign policy: 2984 ['Japan ', 'Japan.']
# foreign policy: 2984 ['Japan ', 'Japan.']
# foreign policy: 3002 ['Middle East']
# politics : 3003 ['Immigration']
# politics : 3006 ['Fake News']
# trade tag: 3014 ['Trade Deal']
# trade tag: 3014 ['Trade Deal', 'Trade']
# trade tag: 3014 ['Trade Deal', 'Trade', 'Tariff', 'Tariff']
# trade tag: 3014 ['Trade Deal', 'Trade', 'Tariff', 'Tariff']
# politics : 3016 ['immigration']
# trade tag: 3024 ['China']
# foreign policy: 3024 ['China)']
# politics : 3024 ['Russia', 'Fake News']
# politics : 3027 ['immigration']
# politics : 3034 ['Immigration']
# politics : 3049 ['Fake News']
# politics : 3050 ['Fake News']
# trade tag: 3051 ['Trade']
# politics : 3053 ['Fake News', 'Fake News']
# politics : 3064 ['Fake News']
# politics : 3066 ['Fake News']
# trade tag: 3075 ['China. We talked about many subjects with a heavy emphasis on Trade']
# trade tag: 3075 ['China. We talked about many subjects with a heavy emphasis on Trade', 'Trade']
# trade tag: 3075 ['China. We talked about many subjects with a heavy emphasis on Trade', 'Trade', 'China']
# foreign policy: 3075 ['China.']
# foreign policy: 3094 ['Israel']
# foreign policy: 3094 ['Israel', 'Iran ']
# politics : 3097 ['Russia']
# politics : 3105 ['immigration', 'Immigration']
# politics : 3105 ['immigration', 'Immigration']
# politics : 3150 ['FAKE NEWS']
# politics : 3153 ['corruption']
# politics : 3156 ['Russia']
# politics : 3156 ['Russia', 'Putin']
# politics : 3162 ['corruption']
# politics : 3163 ['corruption']
# trade tag: 3172 ['trade']
# trade tag: 3173 ['Trade Deficits']
# trade tag: 3173 ['Trade Deficits', 'Trade', 'Trade']
# trade tag: 3173 ['Trade Deficits', 'Trade', 'Trade']
# trade tag: 3179 ['China']
# foreign policy: 3179 ['NATO ']
# foreign policy: 3179 ['NATO ', 'China ']
# trade tag: 3180 ['Trade']
# trade tag: 3180 ['Trade', 'Tariff', 'Tariff']
# trade tag: 3180 ['Trade', 'Tariff', 'Tariff']
# politics : 3182 ['Fake News']
# politics : 3184 ['Fake News']
# politics : 3190 ['FAKE NEWS']
# politics : 3194 ['Russia']
# politics : 3199 ['Fake News']
# trade tag: 3215 ['Trade']
# politics : 3217 ['Fake News']
# foreign policy: 3218 ['Turkey']
# politics : 3225 ['Fake News']
# foreign policy: 3226 ['Middle East']
# politics : 3234 ['FAKE NEWS']
# politics : 3246 ['Russia']
# politics : 3250 ['Fake News']
# trade tag: 3251 ['China']
# foreign policy: 3251 ['China.']
# politics : 3253 ['Fake News']
# trade tag: 3260 ['Tariff']
# trade centi: 3261 []
# trade tag: 3266 ['China']
# trade tag: 3266 ['China', 'Tariff', 'Tariff']
# trade tag: 3266 ['China', 'Tariff', 'Tariff']
# trade centi: 3266 ['China', 'Tariff', 'Tariff']
# foreign policy: 3266 ['China ']
# politics : 3267 ['Russia']
# politics : 3275 ['Russia']
# ...
# politics : 10218 ['immigration']
# politics : 10220 ['Fake News']
# foreign policy: 10222 ['isis.']
# foreign policy: 10224 ['Korean']
# trade tag: 10225 ['China']
# foreign policy: 10225 ['Middle East']
# foreign policy: 10225 ['Middle East', 'China ']
# politics : 10226 ['Russia']
# trade tag: 10227 ['WTo']
# politics : 10231 ['Fake News']
# politics : 10232 ['Fake News']
# politics : 10234 ['immigration']
# politics : 10237 ['FAKE NEWS']
# foreign policy: 10241 ['Japan ']
# politics : 10242 ['Fake News']
# trade tag: 10247 ['China']
# foreign policy: 10247 ['China ']
# foreign policy: 10249 ['KOREAN']
# politics : 10255 ['Immigration']
# politics : 10256 ['Immigration']
# trade tag: 10258 ['Trade']
# foreign policy: 10258 ['Iran ']
# foreign policy: 10258 ['Iran ', 'Syria']
# politics : 10273 ['Fake News']
# trade tag: 10281 ['Trade']
# foreign policy: 10281 ['Japan ']
# politics : 10284 ['Russia']
# foreign policy: 10289 ['isis ']
# politics : 10292 ['Fake News']
# foreign policy: 10293 ['Japan ']
# trade tag: 10294 ['Trade']
# foreign policy: 10294 ['Japan.']
# trade tag: 10298 ['China']
# foreign policy: 10298 ['China ']
# foreign policy: 10299 ['Syria']
# politics : 10307 ['Fake News']
# politics : 10309 ['Russia', 'Russia']
# politics : 10309 ['Russia', 'Russia']
# trade tag: 10310 ['trade']
# trade tag: 10310 ['trade', 'China']
# foreign policy: 10310 ['Syria']
# foreign policy: 10310 ['Syria', 'China ']
# politics : 10311 ['Russia']
# trade tag: 10312 ['China']
# trade tag: 10312 ['China', 'tariff']
# trade centi: 10312 ['China', 'tariff']
# foreign policy: 10312 ['China’']
# foreign policy: 10315 ['Syria', 'Syria']
# foreign policy: 10315 ['Syria', 'Syria']
# foreign policy: 10316 ['Syria']
# trade tag: 10317 ['China will take down its Trade']
# trade tag: 10317 ['China will take down its Trade', 'trade', 'Trade']
# trade tag: 10317 ['China will take down its Trade', 'trade', 'Trade', 'China']
# trade tag: 10317 ['China will take down its Trade', 'trade', 'Trade', 'China']
# foreign policy: 10317 ['China ']
# politics : 10321 ['Fake News']
# trade tag: 10322 ['WTO']
# trade tag: 10322 ['WTO', 'China which is a great economic power is considered a Developing Nation within the World Trade']
# trade tag: 10322 ['WTO', 'China which is a great economic power is considered a Developing Nation within the World Trade', 'Trade']
# trade tag: 10322 ['WTO', 'China which is a great economic power is considered a Developing Nation within the World Trade', 'Trade', 'China']
# foreign policy: 10322 ['China ']
# trade tag: 10323 ['trade']
# trade tag: 10323 ['trade', 'China']
# foreign policy: 10323 ['China ']
# trade tag: 10324 ['Tariff']
# politics : 10325 ['immigration']
# trade tag: 10328 ['Trade Deficit']
# trade tag: 10328 ['Trade Deficit', 'China that war was lost many years ago by the foolish or incompetent people who represented the U.S. Now we have a Trade']
# trade tag: 10328 ['Trade Deficit', 'China that war was lost many years ago by the foolish or incompetent people who represented the U.S. Now we have a Trade', 'trade', 'Trade']
# trade tag: 10328 ['Trade Deficit', 'China that war was lost many years ago by the foolish or incompetent people who represented the U.S. Now we have a Trade', 'trade', 'Trade', 'China']
# trade tag: 10328 ['Trade Deficit', 'China that war was lost many years ago by the foolish or incompetent people who represented the U.S. Now we have a Trade', 'trade', 'Trade', 'China']
# foreign policy: 10328 ['China ']
# politics : 10333 ['IMMIGRATION']
# politics : 10334 ['immigration']
# politics : 10338 ['Dem ']
# politics : 10340 ['immigration']
# foreign policy: 10347 ['isis!']
# trade tag: 10348 ['Trade']
# politics : 10352 ['Obama Administration']
# trade tag: 10356 ['unfair trade']
# trade tag: 10356 ['unfair trade', 'trade']
# trade centi: 10356 ['unfair trade', 'trade']
# politics : 10358 ['Joe Biden']
# foreign policy: 10359 ['ISIS ']
# foreign policy: 10359 ['ISIS ', 'Iran ']
# foreign policy: 10359 ['ISIS ', 'Iran ', 'Syria']
# politics : 10361 ['Dem ']
# politics : 10364 ['Fake News']
# politics : 10365 ['corruption']
# trade tag: 10367 ['trade']
# politics : 10374 ['Immigration']
# politics : 10375 ['RUSSIA']
# trade tag: 10377 ['Tariff']
# politics : 10379 ['Fake News']
# politics : 10380 ['Russia']
# politics : 10381 ['Russia']
# trade tag: 10387 ['Trade Deficit']
# trade tag: 10387 ['Trade Deficit', 'trade', 'Trade']
# trade tag: 10387 ['Trade Deficit', 'trade', 'Trade']
# foreign policy: 10387 ['Japan ', 'Japan ']
# foreign policy: 10387 ['Japan ', 'Japan ']
# trade tag: 10388 ['China']
# foreign policy: 10388 ['China ']
# trade tag: 10394 ['trade']
# trade tag: 10395 ['Trade Deficit']
# trade tag: 10395 ['Trade Deficit', 'China has been asked to develop a plan for the year of a One Billion Dollar reduction in their massive Trade']
# trade tag: 10395 ['Trade Deficit', 'China has been asked to develop a plan for the year of a One Billion Dollar reduction in their massive Trade', 'Trade']
# trade tag: 10395 ['Trade Deficit', 'China has been asked to develop a plan for the year of a One Billion Dollar reduction in their massive Trade', 'Trade', 'China', 'China']
# trade tag: 10395 ['Trade Deficit', 'China has been asked to develop a plan for the year of a One Billion Dollar reduction in their massive Trade', 'Trade', 'China', 'China']
# foreign policy: 10395 ['China ', 'China ']
# trade tag: 10396 ['Trade Deficits', 'Trade Deficit']
# trade tag: 10396 ['Trade Deficits', 'Trade Deficit']
# trade tag: 10396 ['Trade Deficits', 'Trade Deficit', 'Trade', 'Trade']
# trade tag: 10396 ['Trade Deficits', 'Trade Deficit', 'Trade', 'Trade']
# politics : 10400 ['Fake News']
# politics : 10401 ['Obama Administration']
# politics : 10401 ['Obama Administration', 'Russia']
# trade tag: 10402 ['trade deal']
# trade tag: 10402 ['trade deal', 'trade']
# trade centi: 10402 ['trade deal', 'trade']
# trade tag: 10404 ['Trade Deficit']
# trade tag: 10404 ['Trade Deficit', 'trade deal']
# trade tag: 10404 ['Trade Deficit', 'trade deal', 'Trade', 'trade']
# trade tag: 10404 ['Trade Deficit', 'trade deal', 'Trade', 'trade']
# trade centi: 10404 ['Trade Deficit', 'trade deal', 'Trade', 'trade']
# trade tag: 10407 ['Trade Deficit']
# trade tag: 10407 ['Trade Deficit', 'Trade']
# trade tag: 10409 ['trade', 'trade', 'trade']
# trade tag: 10409 ['trade', 'trade', 'trade']
# trade tag: 10409 ['trade', 'trade', 'trade']
# politics : 10426 ['immigration']
# politics : 10427 ['Dem ']
# politics : 10430 ['Dem ']
# politics : 10451 ['Russia']
# politics : 10453 ['Russia']
# politics : 10454 ['Obama Administration']
# politics : 10454 ['Obama Administration', 'Russia']
# foreign policy: 10455 ['Iran ']
# politics : 10456 ['Russia']
# politics : 10456 ['Russia', 'Fake News']
# politics : 10458 ['Russia']
# politics : 10460 ['Russia']
# politics : 10461 ['immigration', 'immigration']
# politics : 10461 ['immigration', 'immigration']
# politics : 10471 ['Dem ']
# politics : 10472 ['Dem ']
# politics : 10474 ['Russia']
# trade tag: 10475 ['China']
# foreign policy: 10475 ['Middle East']
# foreign policy: 10475 ['Middle East', 'China ']
# politics : 10485 ['Immigration']
# politics : 10485 ['Immigration', 'DEM ']
# politics : 10498 ['Fake News']
# politics : 10504 ['immigration']
# foreign policy: 10514 ['ISIS ']
# politics : 10516 ['FAKE NEWS']
# politics : 10525 ['Russia']
# politics : 10525 ['Russia', 'Fake News']
# politics : 10535 ['Fake News']
# politics : 10536 ['FAKE NEWS']
# politics : 10539 ['Obama Administration']
# politics : 10543 ['Russia']
# trade tag: 10554 ['Trade']
# politics : 10555 ['Russia']
# politics : 10555 ['Russia', 'Fake News']
# politics : 10560 ['Fake News']
# politics : 10563 ['immigration', 'immigration']
# politics : 10563 ['immigration', 'immigration']
# politics : 10569 ['Fake News']
# foreign policy: 10570 ['Iran ']
# foreign policy: 10576 ['Iran ', 'Iran’']
# foreign policy: 10576 ['Iran ', 'Iran’']
# politics : 10577 ['corruption']
# politics : 10580 ['Russia']
# politics : 10580 ['Russia', 'Fake News']
# trade tag: 10583 ['China']
# foreign policy: 10583 ['China ']
# foreign policy: 10586 ['ISIS ']
# foreign policy: 10586 ['ISIS ', 'Iraq ']
# foreign policy: 10586 ['ISIS ', 'Iraq ', 'Syria']
# foreign policy: 10588 ['ISIS ']
# foreign policy: 10588 ['ISIS ', 'Iraq ']
# foreign policy: 10588 ['ISIS ', 'Iraq ', 'Syria']
# politics : 10589 ['RUSSIA']
# politics : 10593 ['Fake News']
# politics : 10594 ['Fake News', 'Fake News']
# politics : 10596 ['Fake News']
# politics : 10607 ['Fake News']
# politics : 10608 ['Fake News']
# politics : 10613 ['FAKE NEWS']
# foreign policy: 10619 ['Middle East']
# politics : 10632 ['Fake News']
# politics : 10646 ['immigration']
# politics : 10668 ['Fake News']
# politics : 10678 ['FAKE NEWS']
# politics : 10679 ['Russia', 'Russia', 'Russia']
# politics : 10679 ['Russia', 'Russia', 'Russia']
# politics : 10679 ['Russia', 'Russia', 'Russia']
# politics : 10681 ['Fake News']
# trade tag: 10693 ['China', 'China']
# trade tag: 10693 ['China', 'China']
# foreign policy: 10693 ['China ', 'China.']
# trade tag: 10694 ['China']
# foreign policy: 10694 ['China ']
# trade tag: 10697 ['China']
# foreign policy: 10697 ['China ']
# foreign policy: 10701 ['Syria']
# trade tag: 10710 ['trade']
# trade tag: 10719 ['China']
# foreign policy: 10719 ['China.']
# foreign policy: 10721 ['Korean']
# trade tag: 10723 ['China']
# foreign policy: 10723 ['China ']
# foreign policy: 10731 ['Japan.']
# foreign policy: 10733 ['Japan.']
# foreign policy: 10734 ['Saudi ']
# politics : 10739 ['Dem ']
# politics : 10739 ['Dem ', 'Fake News']
# politics : 10740 ['Dem ']
# foreign policy: 10741 ['ISIS ']
# politics : 10757 ['immigration']
# politics : 10765 ['Fake News']
# politics : 10769 ['Russia']
# foreign policy: 10778 ['isis ']
# trade tag: 10784 ['China']
# foreign policy: 10784 ['China ']
# trade tag: 10785 ['China to congratulate him on his extraordinary elevation. Also discussed NoKo &amp; trade']
# trade tag: 10785 ['China to congratulate him on his extraordinary elevation. Also discussed NoKo &amp; trade', 'trade']
# trade tag: 10785 ['China to congratulate him on his extraordinary elevation. Also discussed NoKo &amp; trade', 'trade', 'China']
# foreign policy: 10785 ['China ']
# politics : 10792 ['Fake News']
# trade centi: 10794 []
# politics : 10808 ['Russia']
# politics : 10809 ['Obama Administration']
# politics : 10809 ['Obama Administration', 'Russia']
# foreign policy: 10811 ['Iran ']
# foreign policy: 10824 ['Israel']
# foreign policy: 10824 ['Israel', 'Iran ']
# politics : 10834 ['Fake News']
# politics : 10842 ['Fake News']
# foreign policy: 10846 ['Israel']
# politics : 10869 ['Fake News']
# foreign policy: 10880 ['Rocket Man']
# politics : 10884 ['Fake News']
# foreign policy: 10922 ['Israel']
# foreign policy: 10922 ['Israel', 'Iran ']
# politics : 10929 ['Russia']
# foreign policy: 10946 ['Israel']
# foreign policy: 10947 ['Middle East']
# trade tag: 10965 ['China']
# foreign policy: 10965 ['China ']
# foreign policy: 10976 ['Japan ']
# trade tag: 10978 ['trade']
# politics : 11004 ['Dem ']
# politics : 11018 ['Fake News']
# politics : 11020 ['Fake News']
# politics : 11025 ['Fake News']
# politics : 11029 ['Fake News']
# politics : 11030 ['Fake News']
# politics : 11049 ['Fake News']
# trade tag: 11052 ['trade']
# foreign policy: 11073 ['ISIS ']
# trade tag: 11082 ['American jobs. A great investment in American manufac']
# politics : 11086 ['Fake News']
# trade tag: 11088 ['China']
# foreign policy: 11088 ['China ']
# politics : 11089 ['Fake News']
# politics : 11096 ['Fake News']
# politics : 11108 ['Dem ']
# politics : 11108 ['Dem ', 'Russia']
# politics : 11109 ['Russia']
# politics : 11110 ['Fake News']
# politics : 11119 ['Russia', 'Russia']
# politics : 11119 ['Russia', 'Russia']
# politics : 11120 ['FAKE NEWS']
# politics : 11121 ['Fake News']
# politics : 11127 ['Fake News']
# trade tag: 11129 ['trade']
# politics : 11131 ['Fake News']
# politics : 11132 ['Russia']
# politics : 11137 ['Russia']
# trade tag: 11139 ['trade']
# trade tag: 11145 ['Trade deal']
# trade tag: 11145 ['Trade deal', 'Trade']
# foreign policy: 11147 ['ISIS ']
# foreign policy: 11147 ['ISIS ', 'Iraq ']
# foreign policy: 11147 ['ISIS ', 'Iraq ', 'Syria']
# foreign policy: 11152 ['ISIS!']
# politics : 11155 ['Fake News']
# foreign policy: 11159 ['Syria']
# politics : 11160 ['Putin']
# trade tag: 11161 ['China’s President Xi where we had an excellent meeting on trade']
# trade tag: 11161 ['China’s President Xi where we had an excellent meeting on trade', 'trade']
# trade tag: 11161 ['China’s President Xi where we had an excellent meeting on trade', 'trade', 'China']
# foreign policy: 11161 ['China’']
# politics : 11165 ['Fake News']
# trade tag: 11167 ['Trade Deal']
# trade tag: 11167 ['Trade Deal', 'Trade']
# trade centi: 11167 ['Trade Deal', 'Trade']
# trade tag: 11169 ['China']
# foreign policy: 11169 ['Japan ']
# foreign policy: 11169 ['Japan ', 'China ']
# foreign policy: 11172 ['ISIS ']
# foreign policy: 11173 ['Saudi ']
# politics : 11186 ['immigration']
# politics : 11187 ['Fake News']
# politics : 11190 ['Dem ']
# politics : 11191 ['Russia']
# politics : 11191 ['Russia', 'FAKE NEWS']
# politics : 11198 ['Russia']
# trade tag: 11203 ['trade']
# foreign policy: 11203 ['Syria']
# politics : 11204 ['Dem ']
# foreign policy: 11205 ['Korean']
# politics : 11215 ['Russia']
# politics : 11240 ['Fake News']
# politics : 11249 ['Obama Administration']
# trade tag: 11253 ['China', 'China']
# trade tag: 11253 ['China', 'China']
# foreign policy: 11253 ['China ', 'China ']
# politics : 11255 ['Fake News']
# politics : 11259 ['Fake News']
# politics : 11260 ['fake news']
# foreign policy: 11263 ['NATO ']
# foreign policy: 11264 ['NATO ', 'NATO ']
# foreign policy: 11264 ['NATO ', 'NATO ']
# foreign policy: 11267 ['NATO ']
# politics : 11283 ['Russia']
# politics : 11284 ['Russia']
# politics : 11286 ['Fake News']
# foreign policy: 11289 ['IRAQ.']
# politics : 11297 ['Obama Administration']
# politics : 11297 ['Obama Administration', 'Fake News']
# politics : 11299 ['Russia']
# politics : 11302 ['Fake News']
# politics : 11317 ['Russia']
# politics : 11336 ['fake news']
# politics : 11350 ['Dem ']
# politics : 11351 ['immigration']
# politics : 11353 ['immigration']
# politics : 11357 ['immigration']
# politics : 11362 ['Russia']
# politics : 11363 ['immigration']
# trade tag: 11366 ['China']
# foreign policy: 11366 ['China ']
# trade tag: 11368 ['China']
# foreign policy: 11368 ['China ']
# trade tag: 11369 ['trade deal']
# trade tag: 11369 ['trade deal', 'China that a trade']
# trade tag: 11369 ['trade deal', 'China that a trade', 'trade']
# trade tag: 11369 ['trade deal', 'China that a trade', 'trade', 'China']
# foreign policy: 11369 ['Korean']
# foreign policy: 11369 ['Korean', 'China ']
# trade tag: 11374 ['trade']
# politics : 11381 ['Russia']
# politics : 11384 ['Fake News']
# politics : 11386 ['Russia']
# politics : 11400 ['Russia']
# politics : 11409 ['Russia']
# politics : 11409 ['Russia', 'fake news']
# politics : 11418 ['Russia']
# politics : 11419 ['Fake News']
# politics : 11421 ['Russia']
# politics : 11423 ['FAKE NEWS']
# politics : 11434 ['FAKE NEWS']
# politics : 11449 ['Russia']
# politics : 11453 ['Russia']
# politics : 11454 ['Russia']
# politics : 11455 ['Russia']
# politics : 11455 ['Russia', 'Putin']
# politics : 11464 ['Russia']
# politics : 11464 ['Russia', 'FAKE NEWS']
# politics : 11472 ['immigration']
# politics : 11472 ['immigration', 'FAKE NEWS']
# politics : 11476 ['FAKE NEWS']
# politics : 11478 ['RUSSIA']
# politics : 11478 ['RUSSIA', 'Fake news']
# foreign policy: 11482 ['Israel']
# politics : 11485 ['Obama Administration']
# politics : 11485 ['Obama Administration', 'Russia', 'Russia']
# politics : 11485 ['Obama Administration', 'Russia', 'Russia']
# politics : 11491 ['FAKE NEWS']
# foreign policy: 11493 ['Japan.']
# politics : 11494 ['FAKE NEWS', 'fake news']
# foreign policy: 11495 ['IRAN ']
# foreign policy: 11495 ['IRAN ', 'IRAQ ']
# foreign policy: 11495 ['IRAN ', 'IRAQ ', 'SYRIA']
# foreign policy: 11497 ['Japan ']
# foreign policy: 11498 ['Japan ', 'Japan ']
# foreign policy: 11498 ['Japan ', 'Japan ']
# foreign policy: 11499 ['Japan ', 'Japan ']
# foreign policy: 11499 ['Japan ', 'Japan ']
# politics : 11508 ['Immigration']
# politics : 11510 ['Fake News']
# foreign policy: 11514 ['Iran ']
# politics : 11514 ['Russia', 'Putin']
# politics : 11519 ['FAKE NEWS']
# trade tag: 11526 ['tariff']
# foreign policy: 11533 ['Iran ']
# foreign policy: 11533 ['Iran ', 'Iraq ']
# politics : 11535 ['Dem ']
# politics : 11535 ['Dem ', 'Dem party']
# politics : 11541 ['immigration']
# 0

# %%
df_tweets_padded = df_tweets.copy()
df_tweets_padded['trade_tags_score']=trade_tags_score
df_tweets_padded['foreign_tags_score']=foreign_tags_score_set
df_tweets_padded['politics_tags_score']=politics_tags_score_set
df_tweets_padded['sentiments_tags_all']=trade_tags_score

df_tweets_padded['tradetag']=trade_tags_all
df_tweets_padded['senti_tradetag']=sentiments_tags_all
df_tweets_padded['foreign_policys_tag']=foreign_policys
df_tweets_padded['politics_partisans_tag']=politics_partisans

df_tweets_padded['trump_tweet_cnt'] =[1 if reFlag ==False else 0 for reFlag in df_tweets_padded['is_retweet'].values]
df_tweets_padded['trump_retweet_cnt'] =[0 if  reFlag ==False else 1 for reFlag in df_tweets_padded['is_retweet'].values]


display(df_tweets_padded.describe())
# Out:
#           polarity  retweet_count  favorite_count  trade_tags_score  foreign_tags_score  politics_tags_score  sentiments_tags_all  trump_tweet_cnt  trump_retweet_cnt
# count  6475.000000   11568.000000    11568.000000      11568.000000        11568.000000         11568.000000         11568.000000     11568.000000       11568.000000
# mean      0.782301   18620.279046    67646.796335          0.269710            0.098634             0.136843             0.269710         0.772649           0.227351
# std       3.542786   12251.542222    52250.446547          1.443753            0.384094             0.408729             1.443753         0.419139           0.419139
# min     -14.900000       2.000000        0.000000          0.000000            0.000000             0.000000             0.000000         0.000000           0.000000
# 25%      -0.600000   11411.000000    31805.000000          0.000000            0.000000             0.000000             0.000000         1.000000           0.000000
# 50%       0.000000   16811.500000    69996.500000          0.000000            0.000000             0.000000             0.000000         1.000000           0.000000
# 75%       2.700000   23262.750000    96769.500000          0.000000            0.000000             0.000000             0.000000         1.000000           0.000000
# max      20.700000  369530.000000   879647.000000         24.000000            6.000000             8.000000            24.000000         1.000000           1.000000

# %%
df_tweets_aggr = df_tweets_padded.groupby('created_at', as_index = False).agg({
    'trump_tweet_cnt': 'sum',
    'trump_retweet_cnt': 'sum',
    'retweet_count': 'sum',
    'favorite_count': 'sum',
    'polarity': 'sum',
    'trade_tags_score': 'sum',
    'politics_tags_score':'sum',
    'foreign_tags_score':'sum'
})
df_tweets_aggr.describe()
# Out:
#        trump_tweet_cnt  trump_retweet_cnt  retweet_count  favorite_count    polarity  trade_tags_score  politics_tags_score  foreign_tags_score
# count       996.000000         996.000000     996.000000    9.960000e+02  996.000000        996.000000           996.000000          996.000000
# mean          8.973896           2.640562  216264.445783    7.856809e+05    5.085743          3.132530             1.589357            1.145582
# std           5.779475           5.852742  141487.975825    4.479941e+05   10.767604          8.300179             2.174555            2.278122
# min           0.000000           0.000000    6868.000000    0.000000e+00  -43.300000          0.000000             0.000000            0.000000
# 25%           4.000000           0.000000  109838.500000    4.434740e+05   -0.900000          0.000000             0.000000            0.000000
# 50%           8.000000           0.000000  192364.000000    7.167870e+05    3.450000          0.000000             1.000000            0.000000
# 75%          12.000000           2.000000  288114.500000    1.076568e+06   10.800000          2.000000             2.000000            1.000000
# max          36.000000          65.000000  833828.000000    2.639593e+06   69.300000        119.000000            19.000000           26.000000

# %% [markdown]
# ## Import and Process Market data
#
# 1. Create a method called ImportData that takes stock code, databse, start_time and end_time and output a dataset that has columns: high,low,open,close,volume,adj_close,percent_change,rise and Date. Details are described in the method
#
# 2. Create SPX dataset

# %%
def ImportData(name = "^DJI",source='yahoo',start =datetime.date(2017,1,20), end = datetime.date(2019,10,25) ):
    '''
    This function takes a ticker symbol from a financial data source (yahoo as default), gathering
    daily data from a range start to end.
    
    #### input variables ####
    
        name: the ticker symbol of the stock/index

        source: financial database

        start: starting time of the stock data that the user requests

        end: ending time of the stock data that the user requests 
    
    #### output ####
    
        df: a data frame includes high,low,open,close,volume,adj close, percent_change
    
    ## Attributes ##
    
        high: highest price during the day

        low: lowest price during the day

        open: opening price at 9:30 am

        close: closing price at 4:00 pm

        volume: amount of trading that day

        adj close: I don't really know

        percent_change: (close-open)/open
        
        Rise (categorical): if percent_change > 0
        
        Date: the date

        Volatile (categorical): whether the stock experiences huge change on that day, (high-low)/((high+low)/2) > 5%
    
    '''

    df = web.DataReader(name,source,start,end)
    df['Percent_change'] = (df.High-df.Low)/df.Open*100
    df['Date'] = df.index
    df['Date'] = pd.to_datetime(df['Date']).dt.date
    
    #Change index name to avoid confusion
    df.index.name = "Index"
    
    #sort df according to Date
    df = df.sort_values('Date',ascending=False)

    ### Define the 'Rise' attribute ###
    rise_array = []
    volatile_array = []
    
    percent_mean = np.mean(df['Percent_change'])
    percent_std = np.std(df['Percent_change'])
    volatility_bar = percent_mean + 2*percent_std
    
    for i in range(len(df)):
        if df.iloc[i]['Percent_change']>0:
            rise_array.append(1)
        else:
            rise_array.append(0)
            
        if np.abs(df.iloc[i]['Percent_change'])>volatility_bar:
            volatile_array.append(1)
        else:
            volatile_array.append(0)
            
            
    df['Rise'] = rise_array
    df['Volatile'] = volatile_array
    return df

DJI_data = ImportData('^DJI','yahoo')
AAPL_data = ImportData('AAPL','yahoo')
GOOGL_data = ImportData('GOOGL','yahoo')
df_SPX = ImportData("^GSPC",'yahoo')
FV = ImportData("^FVX",'yahoo')

display(df_SPX.describe())

fig,ax = plt.subplots(1,1,figsize=(12,8))

ax.plot(DJI_data.Date,DJI_data.Percent_change,'o',label = "Dow Jones index",alpha = 0.6)
ax.plot(GOOGL_data.Date,GOOGL_data.Percent_change,'o',label = 'GOOGL',alpha = 0.5)
ax.plot(AAPL_data.Date,AAPL_data.Percent_change,'o',label = 'AAPL',alpha = 0.4)
ax.plot(df_SPX.Date,df_SPX.Percent_change,'o',label = 'SPX',alpha = 0.4)
ax.plot(FV.Date,FV.Percent_change,'o',label = 'Five Year Yields',alpha = 0.4)

ax.set_xlabel("Date")
ax.set_ylabel("Percent_Change")
ax.legend()
plt.xticks(rotation = 30)
plt.show()
# Out:
#               High          Low         Open        Close        Volume    Adj Close  Percent_change   Rise    Volatile
# count   697.000000   697.000000   697.000000   697.000000  6.970000e+02   697.000000      697.000000  697.0  697.000000
# mean   2693.957344  2670.310731  2682.767102  2682.893888  3.521506e+09  2682.893888        0.876506    1.0    0.053085
# std     202.313275   199.377846   201.000998   200.660956  5.920275e+08   200.660956        0.681055    0.0    0.224363
# min    2271.780029  2257.020020  2267.780029  2265.199951  1.349780e+09  2265.199951        0.145747    1.0    0.000000
# 25%    2507.159912  2490.370117  2497.260010  2500.229980  3.192510e+09  2500.229980        0.451209    1.0    0.000000
# 50%    2730.600098  2698.750000  2714.989990  2712.969971  3.437620e+09  2712.969971        0.659689    1.0    0.000000
# 75%    2858.679932  2830.939941  2846.199951  2847.110107  3.770520e+09  2847.110107        1.053383    1.0    0.000000
# max    3027.979980  3014.300049  3024.469971  3025.860107  7.609010e+09  3025.860107        5.127963    1.0    1.000000

# %%
np.mean(df_cbm.Percent_change)
np.std(df_cbm.Percent_change)
# Out:
# 0.7010255779904415

# %%
fig,ax = plt.subplots(1,1,figsize=(12,8))
ax.hist(df_SPX.Percent_change,bins=20,label = 'SPX',alpha=0.7)
ax.hist(DJI_data.Percent_change,bins=20,label = 'Dow Jones',alpha=0.5)

ax.hist(AAPL_data.Percent_change,bins=20,label = 'Apple',alpha = 0.4)

ax.hist(GOOGL_data.Percent_change,bins=20,label = 'Google',alpha = 0.3)

ax.set_xlabel('percent_change')
ax.set_ylabel('counts')
ax.legend()
ax.set_title('Histogram of percent_change')
plt.show()

# %% [markdown]
# ## Combine Tweet and Market Data into a Single Dataset
#
# 1. Create a column named trade_date_flag in tweet dataset to indicate whether the date is a trade-day or not
#
# 2. Create a combined dataset df_cbm based on df_SPX and add three columns:`trump_tweet_cnt`,`retweet_count`, and `favorite_count`, which indicate the number of tweets Trump tweeted, the number of retweets of Trump's tweets and the number of likes in a particular day

# %%
df_tweets_aggr['trade_date_flag'] = [1 if dt in df_SPX['Date'].values else 0 for dt in df_tweets_aggr['created_at']]

df_cbm = df_SPX.copy()
df_cbm['trump_tweet_cnt'] = [df_tweets_aggr.loc[df_tweets_aggr['created_at']==dt]['trump_tweet_cnt'].values[0] if dt in (df_tweets_aggr['created_at'].values) else 0 for dt in df_SPX['Date'].values]
df_cbm['retweet_count'] = [df_tweets_aggr.loc[df_tweets_aggr['created_at']==dt]['retweet_count'].values[0] if dt in (df_tweets_aggr['created_at'].values) else 0 for dt in df_SPX['Date'].values]
df_cbm['favorite_count'] = [df_tweets_aggr.loc[df_tweets_aggr['created_at']==dt]['favorite_count'].values[0] if dt in (df_tweets_aggr['created_at'].values) else 0 for dt in df_SPX['Date'].values]
df_cbm['polarity'] = [df_tweets_aggr.loc[df_tweets_aggr['created_at']==dt]['polarity'].values[0] if dt in (df_tweets_aggr['created_at'].values) else 0 for dt in df_SPX['Date'].values]
df_cbm['trade_tags_score'] = [df_tweets_aggr.loc[df_tweets_aggr['created_at']==dt]['trade_tags_score'].values[0] if dt in (df_tweets_aggr['created_at'].values) else 0 for dt in df_SPX['Date'].values]
df_cbm['politics_tags_score'] = [df_tweets_aggr.loc[df_tweets_aggr['created_at']==dt]['politics_tags_score'].values[0] if dt in (df_tweets_aggr['created_at'].values) else 0 for dt in df_SPX['Date'].values]
df_cbm['foreign_tags_score'] = [df_tweets_aggr.loc[df_tweets_aggr['created_at']==dt]['foreign_tags_score'].values[0] if dt in (df_tweets_aggr['created_at'].values) else 0 for dt in df_SPX['Date'].values]

display(df_cbm.head())
display(df_cbm.describe())
# Out:
#                    High          Low         Open        Close      Volume    Adj Close  Percent_change        Date  Rise  Volatile  trump_tweet_cnt  retweet_count  favorite_count  polarity  trade_tags_score  politics_tags_score  foreign_tags_score
# Index
# 2019-10-25  3027.389893  3001.939941  3003.320068  3022.550049  3370370000  3022.550049        0.847394  2019-10-25     1         0                1        74119.0         76475.0       3.1                 0                    4                   0
# 2019-10-24  3016.070068  3000.419922  3014.780029  3010.290039  3692600000  3010.290039        0.519114  2019-10-24     1         0                9       203529.0        518594.0       1.6                 0                    1                   3
# 2019-10-23  3004.780029  2991.209961  2994.010010  3004.520020  3392870000  3004.520020        0.453241  2019-10-23     1         0               22       604261.0       1292485.0      21.1                 4                   11                   5
# 2019-10-22  3014.570068  2995.040039  3010.729980  2995.989990  3523890000  2995.989990        0.648681  2019-10-22     1         0               14       504930.0       1022161.0      -1.2                 2                    9                   3
# 2019-10-21  3007.330078  2995.350098  2996.479980  3006.719971  3271620000  3006.719971        0.399802  2019-10-21     1         0               12       251644.0        645387.0      10.9                 0                    2                   0
#               High          Low         Open        Close        Volume    Adj Close  Percent_change   Rise    Volatile  trump_tweet_cnt  retweet_count  favorite_count    polarity  trade_tags_score  politics_tags_score  foreign_tags_score
# count   697.000000   697.000000   697.000000   697.000000  6.970000e+02   697.000000      697.000000  697.0  697.000000       697.000000     697.000000    6.970000e+02  697.000000        697.000000           697.000000          697.000000
# mean   2693.957344  2670.310731  2682.767102  2682.893888  3.521506e+09  2682.893888        0.876506    1.0    0.053085         9.423242  215300.238164    7.999754e+05    5.574462          3.251076             1.548063            1.179340
# std     202.313275   199.377846   201.000998   200.660956  5.920275e+08   200.660956        0.681055    0.0    0.224363         6.008871  139979.556020    4.639871e+05   10.739617          8.715743             2.086024            2.389688
# min    2271.780029  2257.020020  2267.780029  2265.199951  1.349780e+09  2265.199951        0.145747    1.0    0.000000         0.000000       0.000000    0.000000e+00  -43.300000          0.000000             0.000000            0.000000
# 25%    2507.159912  2490.370117  2497.260010  2500.229980  3.192510e+09  2500.229980        0.451209    1.0    0.000000         5.000000  110053.000000    4.484820e+05   -0.400000          0.000000             0.000000            0.000000
# 50%    2730.600098  2698.750000  2714.989990  2712.969971  3.437620e+09  2712.969971        0.659689    1.0    0.000000         8.000000  193206.000000    7.269610e+05    4.200000          0.000000             1.000000            0.000000
# 75%    2858.679932  2830.939941  2846.199951  2847.110107  3.770520e+09  2847.110107        1.053383    1.0    0.000000        13.000000  286056.000000    1.077062e+06   11.500000          2.000000             2.000000            1.000000
# max    3027.979980  3014.300049  3024.469971  3025.860107  7.609010e+09  3025.860107        5.127963    1.0    1.000000        36.000000  789785.000000    2.639593e+06   59.600000        119.000000            15.000000           26.000000

# %% [markdown]
# # EDA and Baseline Model
#
# 1. We first perform a scatter plot on all the columns of the combined data frame. At first glance, `high`,`low`,`open`,`close`and `adj close` have some linear relationship with `trump_tweet_cnt`,`retweet_count`, and `favorite_count`. Other columns that are not directly reflecting the price, such as `volume` and `percent_change` seem to be unrelated to `trump_tweet_cnt`,`retweet_count`, or `favorite_count`.
#
#
# 2. Therefore, we performed a simple linear regression model using `trump_tweet_cnt`, `retweet_count`, and `favorite_count` as predictors and `high` as response variable and calculated the score. The score for the training set is 0.310 and the score for the test set is 0.340. These are pretty bad scores, so we will further process the data and then do the fitting. Lasso regularization can be implemented in the future, too.
#
#
# 3. Then we perform a series of k-NN model using `trump_tweet_cnt`,`retweet_count`, and `favorite_count` as predictors and `high` as response variable and calculate the score. The best scores we get is when number of neighbors is 20. The training set_score is  0.350. The test set score is 0.346.

# %%
scatter_matrix(df_cbm,figsize=(30,30))
plt.savefig('./scatter_pair.png')
plt.show()
# Out:
# /Users/shijianjin/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/misc.py:80: UserWarning: Attempting to set identical left == right == 1.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[j])
# /Users/shijianjin/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/misc.py:81: UserWarning: Attempting to set identical bottom == top == 1.0 results in singular transformations; automatically expanding.
#   ax.set_ylim(boundaries_list[i])
# /Users/shijianjin/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/misc.py:71: UserWarning: Attempting to set identical left == right == 1.0 results in singular transformations; automatically expanding.
#   ax.set_xlim(boundaries_list[i])

# %%
# Out:
# Index
# 2019-11-19    False
# 2019-11-18    False
# 2019-11-15    False
# 2019-11-14    False
# 2019-11-13    False
#               ...
# 2017-01-26    False
# 2017-01-25    False
# 2017-01-24    False
# 2017-01-23    False
# 2017-01-20    False
# Name: Volatile, Length: 714, dtype: bool

# %%
combined_df = pd.merge(left=df_tweets_aggr, right=df_SPX, how='left', left_on='created_at', right_on='Date')
combined_df.head()
# Out:
#    created_at  trump_tweet_cnt  trump_retweet_cnt  retweet_count  favorite_count  polarity  trade_tags_score  politics_tags_score  foreign_tags_score  trade_date_flag         High          Low         Open        Close        Volume    Adj Close  Percent_change        Date  Rise  Volatile
# 0  2017-01-20               13                  0       417567.0       1867501.0       7.6                 0                    0                   0                1  2276.959961  2265.010010  2269.959961  2271.310059  3.524970e+09  2271.310059        0.059477  2017-01-20   1.0       0.0
# 1  2017-01-21                2                  1       103818.0        467521.0       5.3                 0                    0                   0                0          NaN          NaN          NaN          NaN           NaN          NaN             NaN         NaN   NaN       NaN
# 2  2017-01-22                4                  0       184236.0        949408.0       6.6                 0                    0                   0                0          NaN          NaN          NaN          NaN           NaN          NaN             NaN         NaN   NaN       NaN
# 3  2017-01-23                1                  0        26750.0        177839.0       1.4                 0                    0                   0                1  2271.780029  2257.020020  2267.780029  2265.199951  3.152710e+09  2265.199951       -0.113771  2017-01-23   0.0       0.0
# 4  2017-01-24                4                  0        86707.0        495813.0      -1.2                 0                    0                   0                1  2284.629883  2266.679932  2267.879883  2280.070068  3.810960e+09  2280.070068        0.537515  2017-01-24   1.0       0.0

# %%
fig, ax1 = plt.subplots(figsize=(16,6))
ax1.plot(combined_df['created_at'],combined_df['trump_tweet_cnt'] + combined_df['trump_retweet_cnt'], color='blue', label='Total number of tweets/retweets Trump posted')
ax1.set_xlabel("Date")
ax1.set_ylabel("Total Number of Tweets")
plt.legend()
ax2 = ax1.twinx()
ax2.set_ylabel("Percent Change in Price")
ax2.plot(combined_df['created_at'], combined_df['Percent_change'], color='orange', label='Percent change of SPX financial')
fig.tight_layout() 

plt.title('Total number of tweets/retweets Trump posted VS Percent change of SPX financial data', fontsize=16)
plt.legend()
plt.show()

# %%
sns.boxplot(x = 'trade_date_flag', y = 'trump_tweet_cnt', data = combined_df)
plt.title('Trade day or Non-Trade day VS number of Trumps tweets', fontsize=14)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,6))
ax.scatter(combined_df['created_at'], combined_df['trump_tweet_cnt'], color='b',alpha=0.7, label='Original tweets')
#ax.scatter(combined_df['created_at'], combined_df['trump_retweet_cnt'], color='r', alpha=0.7, label='Retweets by Trump')
#ax.scatter(combined_df['created_at'], combined_df['retweet_count'], color = 'orange', label = 'Retweets from Trump')
ax.set_xlabel("Date", fontsize = 15)
ax.set_ylabel("Counts",fontsize = 15 )
plt.title('Number of Trump\'s tweets', fontsize=18)
plt.legend(fontsize = 15)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,6))
ax.scatter(combined_df['created_at'], combined_df['retweet_count'], color='b',alpha=0.7, label='Retweets of Trump\'s words')
ax.scatter(combined_df['created_at'], combined_df['favorite_count'], color='r', alpha=0.7, label='Favorites')
#ax.scatter(combined_df['created_at'], combined_df['retweet_count'], color = 'orange', label = 'Retweets from Trump')
ax.set_xlabel("Date", fontsize = 15)
ax.set_ylabel("Counts",fontsize = 15 )
plt.title('Retweet of Trump\'s words VS Favorites', fontsize=18)
plt.legend(fontsize = 15)
plt.savefig('/Users/YuhanZhang/Desktop/tweet_2.png')
plt.show()

# %%
# used in the result analysis part
fig, ax = plt.subplots(figsize=(20,6))
ax.scatter(combined_df['trump_tweet_cnt'] + combined_df['trump_retweet_cnt'], combined_df['retweet_count'], label="Total retweets")
ax.scatter(combined_df['trump_tweet_cnt'], combined_df['favorite_count'], label="Total favorites")
ax.set_xlabel("The number of tweets",fontsize = 15)
ax.set_ylabel("Counts",fontsize = 15)
plt.title('Total number of tweets/retweets that Trump posted VS number of users who retweet/favorite his tweets', fontsize=18)
plt.legend(fontsize = 15)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20,6))
ax.scatter(combined_df['created_at'], combined_df['retweet_count'], color='b',alpha=0.7, label='Retweets of Trump\'s words')
ax.scatter(combined_df['created_at'], combined_df['favorite_count'], color='r', alpha=0.7, label='Favorites')
ax.set_xlabel("Date", fontsize = 15)
ax.set_ylabel("Counts",fontsize = 15 )
plt.title('Retweet of Trump\'s words VS Favorites', fontsize=18)
plt.legend(fontsize = 15)
#plt.savefig('/Users/YuhanZhang/Desktop/tweet_2.png')
plt.show()

# %%
#2019-12-10 New

fig, ax1 = plt.subplots(figsize=(16,6))
ax1.plot(df_cbm['Date'],df_cbm['polarity'], color='blue', label='Polarity')
ax1.set_xlabel("Date",fontsize=14)
ax1.set_ylabel("Polarity",fontsize=14)
ax1.tick_params(axis='both', labelsize=14)
plt.title('Polarity of Trump\'s tweets over time' , fontsize=16)
plt.legend(fontsize = 15)
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(16,6))
ax1.plot(df_cbm['Date'],df_cbm['trade_tags_score'], color='blue', label='Trade tag score')
ax1.plot(df_cbm['Date'],df_cbm['politics_tags_score'],color='orange',  label='Politics tag score')
ax1.plot(df_cbm['Date'],df_cbm['foreign_tags_score'],color='red', label='Foreign tag score')

ax1.set_xlabel("Date",fontsize=14)
ax1.set_ylabel("Polarity",fontsize=14)
ax1.tick_params(axis='both', labelsize=14)
plt.title('Trade, politics and foreign scores of Trump\'s daily tweets ', fontsize=16)
plt.legend(fontsize = 15)
plt.show()

# %% [markdown]
# ## Basic modelling

# %%
#df_cbm = df_cbm.iloc[17:] #only run once to drop the row of zeros

display(df_cbm.describe())

x = df_cbm[['trump_tweet_cnt','retweet_count','favorite_count','polarity','trade_tags_score','politics_tags_score','foreign_tags_score']]

y = df_cbm['High']

X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

reg = LinearRegression().fit(X_train,y_train)
train_score = reg.score(X_train,y_train)
test_score = reg.score(X_test,y_test)
print("The training set_score is ",train_score,". The test set score is",test_score)

display(X_train.head())
# Out:
#               High          Low         Open        Close        Volume    Adj Close  Percent_change   Rise    Volatile  trump_tweet_cnt  retweet_count  favorite_count    polarity  trade_tags_score  politics_tags_score  foreign_tags_score
# count   697.000000   697.000000   697.000000   697.000000  6.970000e+02   697.000000      697.000000  697.0  697.000000       697.000000     697.000000    6.970000e+02  697.000000        697.000000           697.000000          697.000000
# mean   2693.957344  2670.310731  2682.767102  2682.893888  3.521506e+09  2682.893888        0.876506    1.0    0.053085         9.423242  215300.238164    7.999754e+05    5.574462          3.251076             1.548063            1.179340
# std     202.313275   199.377846   201.000998   200.660956  5.920275e+08   200.660956        0.681055    0.0    0.224363         6.008871  139979.556020    4.639871e+05   10.739617          8.715743             2.086024            2.389688
# min    2271.780029  2257.020020  2267.780029  2265.199951  1.349780e+09  2265.199951        0.145747    1.0    0.000000         0.000000       0.000000    0.000000e+00  -43.300000          0.000000             0.000000            0.000000
# 25%    2507.159912  2490.370117  2497.260010  2500.229980  3.192510e+09  2500.229980        0.451209    1.0    0.000000         5.000000  110053.000000    4.484820e+05   -0.400000          0.000000             0.000000            0.000000
# 50%    2730.600098  2698.750000  2714.989990  2712.969971  3.437620e+09  2712.969971        0.659689    1.0    0.000000         8.000000  193206.000000    7.269610e+05    4.200000          0.000000             1.000000            0.000000
# 75%    2858.679932  2830.939941  2846.199951  2847.110107  3.770520e+09  2847.110107        1.053383    1.0    0.000000        13.000000  286056.000000    1.077062e+06   11.500000          2.000000             2.000000            1.000000
# max    3027.979980  3014.300049  3024.469971  3025.860107  7.609010e+09  3025.860107        5.127963    1.0    1.000000        36.000000  789785.000000    2.639593e+06   59.600000        119.000000            15.000000           26.000000
# The training set_score is  0.3055479428994057 . The test set score is 0.2621202224564284
#             trump_tweet_cnt  retweet_count  favorite_count  polarity  trade_tags_score  politics_tags_score  foreign_tags_score
# Index
# 2019-07-01               19       308622.0       1472199.0      12.0                 0                    0                   4
# 2019-08-14               17       384068.0       1231423.0      16.3                30                    1                   4
# 2018-12-11               13       266889.0       1165368.0      13.8                 2                    2                   1
# 2017-08-08                4       125388.0        380389.0      -7.9                 0                    1                   2
# 2018-01-10               10       188835.0        821099.0       6.0                 0                    2                   0

# %% [markdown]
# ### Normalize Data

# %%
from sklearn import preprocessing

# fit the scaler on the X_train
scaler = preprocessing.MinMaxScaler().fit(X_train)

# Scale X_train and X_test
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Making the numpy scaled matrices pandas dataframes
X_train_scaled_df = pd.DataFrame(X_train_scaled, index=X_train.index, columns=X_train.columns)
X_test_scaled_df = pd.DataFrame(X_test_scaled, index=X_test.index, columns=X_test.columns)

X_train_scaled_df.head()
# Out:
#    trump_tweet_cnt  retweet_count  favorite_count  polarity  trade_tags_score  politics_tags_score  foreign_tags_score
# 0         0.222222       0.202212        0.236367  0.511843          0.032258             0.090909            0.263158
# 1         0.055556       0.019301        0.027864  0.473738          0.000000             0.000000            0.000000
# 2         0.055556       0.045782        0.063869  0.488157          0.000000             0.000000            0.000000
# 3         0.555556       0.508052        0.545550  0.334706          0.064516             0.545455            0.842105
# 4         0.194444       0.153257        0.219874  0.445932          0.064516             0.000000            0.157895

# %% [markdown]
# #### Update model with normalized data

# %%
reg_scaled = LinearRegression().fit(X_train_scaled_df,y_train)
train_score_scaled = reg.score(X_train_scaled_df,y_train)
test_score_scaled = reg.score(X_test_scaled_df,y_test)
print("The training set score is ",train_score_scaled,". The test set score is",test_score_scaled)
# Out:
# The training set score is  -0.0730839296824517 . The test set score is -0.14545236774538628

# %%
fig, ax = plt.subplots(1,3, figsize = (20,6))
predictor = list(['trump_tweet_cnt','retweet_count','favorite_count'])
name = ['Trump\'s original tweets', 'Number of retweets', 'Number of favorite']
for i, item in enumerate(predictor):
    ax[i].scatter(df_cbm[item], y)
    ax[i].set_title('Highest price during the day & {}'.format(name[i]), fontsize = 15)
    ax[i].set_xlabel('Number')
    ax[i].set_ylabel('Number')

# %%
k_list = [1,2,3,5,6,7,8,10,20,25]
train_score_set = []
test_score_set = []
for k in k_list:
    kNN = KNeighborsRegressor(n_neighbors = k).fit(X_train,y_train)

    train_score = kNN.score(X_train,y_train)
    test_score = kNN.score(X_test,y_test)
    train_score_set.append(train_score)
    test_score_set.append(test_score)
    print("The number of neighbors is",k,"The training set_score is ",train_score,". The test set score is",test_score)
    
fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(k_list,train_score_set, color='blue', label='Training Set')
ax1.plot(k_list,test_score_set,color='red',  label='Test Set')

ax1.set_xlabel("Number of nearest neighbors",fontsize=14)
ax1.set_ylabel("Score",fontsize=14)
ax1.tick_params(axis='both', labelsize=14)
plt.title('Model scoring with kNN models ', fontsize=16)
plt.legend(fontsize = 15)
plt.show()
# Out:
# The number of neighbors is 1 The training set_score is  0.9867709397706813 . The test set score is -0.423347016620073
# The number of neighbors is 2 The training set_score is  0.7023025553252018 . The test set score is 0.030451099410673917
# The number of neighbors is 3 The training set_score is  0.5885100128545917 . The test set score is 0.15291238659357276
# The number of neighbors is 5 The training set_score is  0.474554773512725 . The test set score is 0.20218153304656494
# The number of neighbors is 6 The training set_score is  0.4551624558756089 . The test set score is 0.23168312467101237
# The number of neighbors is 7 The training set_score is  0.4411205824111237 . The test set score is 0.2412945126522704
# The number of neighbors is 8 The training set_score is  0.4183815227032589 . The test set score is 0.2567931752506959
# The number of neighbors is 10 The training set_score is  0.3852110585550283 . The test set score is 0.253274077099936
# The number of neighbors is 20 The training set_score is  0.3380317656527677 . The test set score is 0.23339338131227094
# The number of neighbors is 25 The training set_score is  0.3243913634077704 . The test set score is 0.23230960071253748

# %% [markdown]
# # Tree Model Fitting

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import tree
from sklearn.model_selection import cross_val_score
from sklearn.metrics import roc_auc_score,accuracy_score

max_depth = [1,2,3,4,5,10,20,30]
tree_models = []
tree_train_score = []
tree_cross_score = []
tree_test_score = []
for depth in max_depth:
    
    dtree = DecisionTreeRegressor(max_depth=depth)
    dtree.fit(X_train,y_train)
    train_score = dtree.score(X_train,y_train)
    cross_scores = np.mean(cross_val_score(dtree,X_train,y_train,cv=5))
    tree_models.append(dtree)
    tree_train_score.append(train_score)
    tree_cross_score.append(cross_scores)
    tree_test_score.append(dtree.score(X_test,y_test))

fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(max_depth,tree_train_score, color='blue', label='Training Set')
ax1.plot(max_depth,tree_test_score,color='red',  label='Test Set')

ax1.set_xlabel("Max depth of trees",fontsize=14)
ax1.set_ylabel("Score",fontsize=14)
ax1.tick_params(axis='both', labelsize=14)
plt.title('Model scoring with descision tree models ', fontsize=16)
plt.legend(fontsize = 15)
plt.show()

# %%
fig,ax = plt.subplots(1,1,figsize=(10,6))

ax.bar(['Linear Regression Model','kNN Model','Decision Tree Model'],[train_score,train_score_set[6],tree_train_score[1]],label='Training Set',width=0.7)
ax.bar(['Linear Regression Model','kNN Model','Decision Tree Model'],[test_score,test_score_set[6],tree_test_score[1]],label='Test Set',width=0.5)
ax.legend(fontsize=15)
ax.set_ylabel("Score",fontsize=14)
ax.tick_params(axis='both', labelsize=14)
ax.set_ylim(0,0.5)
ax.set_title('Comparison of Regression Models on Fitting Daily Trump Tweet Data vs. SPX High',fontsize=16)
plt.show()

# %% [markdown]
# ### ANN

# %%
import tensorflow as tf

# %%
input_dimension = X_train.shape[1]
output_dimension = 1
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10,input_dim = input_dimension,kernel_initializer = 'normal'),
    tf.keras.layers.Dense(20,activation = 'relu',kernel_initializer = 'normal'),
    tf.keras.layers.Dense(15,activation = 'relu',kernel_initializer = 'normal'),
    tf.keras.layers.Dense(20,activation = 'relu',kernel_initializer = 'normal'),
    tf.keras.layers.Dense(10,activation = 'relu',kernel_initializer = 'normal'),

    tf.keras.layers.Dense(output_dimension,activation = 'linear'),

])

model.compile(optimizer = 'adam',loss='mean_absolute_error',metrics=['accuracy'])
model.summary()

history = model.fit(X_train,y_train,validation_split=0.2,epochs=500,batch_size=32)
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_72 (Dense)             (None, 10)                80
# _________________________________________________________________
# dense_73 (Dense)             (None, 20)                220
# _________________________________________________________________
# dense_74 (Dense)             (None, 15)                315
# _________________________________________________________________
# dense_75 (Dense)             (None, 20)                320
# _________________________________________________________________
# dense_76 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_77 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 1,156
# Trainable params: 1,156
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 445 samples, validate on 112 samples
# Epoch 1/500
# 445/445 [==============================] - 0s 401us/sample - loss: 2616.6224 - accuracy: 0.0000e+00 - val_loss: 2506.6036 - val_accuracy: 0.0000e+00
# Epoch 2/500
# 445/445 [==============================] - 0s 40us/sample - loss: 2147.8888 - accuracy: 0.0000e+00 - val_loss: 1403.4528 - val_accuracy: 0.0000e+00
# Epoch 3/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1220.9700 - accuracy: 0.0000e+00 - val_loss: 1151.6193 - val_accuracy: 0.0000e+00
# Epoch 4/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1152.3776 - accuracy: 0.0000e+00 - val_loss: 1077.8100 - val_accuracy: 0.0000e+00
# Epoch 5/500
# 445/445 [==============================] - 0s 61us/sample - loss: 1127.0144 - accuracy: 0.0000e+00 - val_loss: 1077.3295 - val_accuracy: 0.0000e+00
# Epoch 6/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1118.2342 - accuracy: 0.0000e+00 - val_loss: 1076.1626 - val_accuracy: 0.0000e+00
# Epoch 7/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1122.3506 - accuracy: 0.0000e+00 - val_loss: 1075.5661 - val_accuracy: 0.0000e+00
# Epoch 8/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1119.5983 - accuracy: 0.0000e+00 - val_loss: 1076.5511 - val_accuracy: 0.0000e+00
# Epoch 9/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1126.1140 - accuracy: 0.0000e+00 - val_loss: 1075.9674 - val_accuracy: 0.0000e+00
# Epoch 10/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1118.5467 - accuracy: 0.0000e+00 - val_loss: 1075.3616 - val_accuracy: 0.0000e+00
# Epoch 11/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1131.1342 - accuracy: 0.0000e+00 - val_loss: 1076.0452 - val_accuracy: 0.0000e+00
# Epoch 12/500
# 445/445 [==============================] - 0s 40us/sample - loss: 1127.4758 - accuracy: 0.0000e+00 - val_loss: 1077.6885 - val_accuracy: 0.0000e+00
# Epoch 13/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1123.2191 - accuracy: 0.0000e+00 - val_loss: 1076.5968 - val_accuracy: 0.0000e+00
# Epoch 14/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1126.3872 - accuracy: 0.0000e+00 - val_loss: 1077.7407 - val_accuracy: 0.0000e+00
# Epoch 15/500
# 445/445 [==============================] - 0s 52us/sample - loss: 1123.8792 - accuracy: 0.0000e+00 - val_loss: 1076.1662 - val_accuracy: 0.0000e+00
# Epoch 16/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1120.9106 - accuracy: 0.0000e+00 - val_loss: 1078.4994 - val_accuracy: 0.0000e+00
# Epoch 17/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1116.7563 - accuracy: 0.0000e+00 - val_loss: 1076.2699 - val_accuracy: 0.0000e+00
# Epoch 18/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1123.3426 - accuracy: 0.0000e+00 - val_loss: 1075.3636 - val_accuracy: 0.0000e+00
# Epoch 19/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1120.7328 - accuracy: 0.0000e+00 - val_loss: 1075.4585 - val_accuracy: 0.0000e+00
# Epoch 20/500
# 445/445 [==============================] - 0s 57us/sample - loss: 1119.9925 - accuracy: 0.0000e+00 - val_loss: 1075.0523 - val_accuracy: 0.0000e+00
# Epoch 21/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1125.0413 - accuracy: 0.0000e+00 - val_loss: 1075.0526 - val_accuracy: 0.0000e+00
# Epoch 22/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1125.0129 - accuracy: 0.0000e+00 - val_loss: 1083.2924 - val_accuracy: 0.0000e+00
# Epoch 23/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1122.5863 - accuracy: 0.0000e+00 - val_loss: 1075.1003 - val_accuracy: 0.0000e+00
# Epoch 24/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1121.3151 - accuracy: 0.0000e+00 - val_loss: 1080.7370 - val_accuracy: 0.0000e+00
# Epoch 25/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1132.4994 - accuracy: 0.0000e+00 - val_loss: 1075.0729 - val_accuracy: 0.0000e+00
# Epoch 26/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1138.5565 - accuracy: 0.0000e+00 - val_loss: 1077.2110 - val_accuracy: 0.0000e+00
# Epoch 27/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1131.3968 - accuracy: 0.0000e+00 - val_loss: 1088.0772 - val_accuracy: 0.0000e+00
# Epoch 28/500
# 445/445 [==============================] - 0s 55us/sample - loss: 1123.8985 - accuracy: 0.0000e+00 - val_loss: 1074.2666 - val_accuracy: 0.0000e+00
# Epoch 29/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1121.0883 - accuracy: 0.0000e+00 - val_loss: 1073.9691 - val_accuracy: 0.0000e+00
# Epoch 30/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1123.6838 - accuracy: 0.0000e+00 - val_loss: 1078.0103 - val_accuracy: 0.0000e+00
# Epoch 31/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1123.3411 - accuracy: 0.0000e+00 - val_loss: 1078.4376 - val_accuracy: 0.0000e+00
# Epoch 32/500
# 445/445 [==============================] - 0s 104us/sample - loss: 1142.0873 - accuracy: 0.0000e+00 - val_loss: 1100.2824 - val_accuracy: 0.0000e+00
# Epoch 33/500
# 445/445 [==============================] - 0s 97us/sample - loss: 1133.4613 - accuracy: 0.0000e+00 - val_loss: 1073.5683 - val_accuracy: 0.0000e+00
# Epoch 34/500
# 445/445 [==============================] - 0s 106us/sample - loss: 1116.8961 - accuracy: 0.0000e+00 - val_loss: 1080.1571 - val_accuracy: 0.0000e+00
# Epoch 35/500
# 445/445 [==============================] - 0s 114us/sample - loss: 1126.6560 - accuracy: 0.0000e+00 - val_loss: 1073.9519 - val_accuracy: 0.0000e+00
# Epoch 36/500
# 445/445 [==============================] - 0s 96us/sample - loss: 1119.5010 - accuracy: 0.0000e+00 - val_loss: 1077.4299 - val_accuracy: 0.0000e+00
# Epoch 37/500
# 445/445 [==============================] - 0s 102us/sample - loss: 1130.5057 - accuracy: 0.0000e+00 - val_loss: 1073.0249 - val_accuracy: 0.0000e+00
# Epoch 38/500
# 445/445 [==============================] - 0s 94us/sample - loss: 1146.4173 - accuracy: 0.0000e+00 - val_loss: 1075.1409 - val_accuracy: 0.0000e+00
# Epoch 39/500
# 445/445 [==============================] - 0s 86us/sample - loss: 1148.7296 - accuracy: 0.0000e+00 - val_loss: 1074.5675 - val_accuracy: 0.0000e+00
# Epoch 40/500
# 445/445 [==============================] - 0s 65us/sample - loss: 1118.0812 - accuracy: 0.0000e+00 - val_loss: 1072.0743 - val_accuracy: 0.0000e+00
# Epoch 41/500
# 445/445 [==============================] - 0s 68us/sample - loss: 1115.5433 - accuracy: 0.0000e+00 - val_loss: 1076.2799 - val_accuracy: 0.0000e+00
# Epoch 42/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1127.8967 - accuracy: 0.0000e+00 - val_loss: 1075.8192 - val_accuracy: 0.0000e+00
# Epoch 43/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1125.0857 - accuracy: 0.0000e+00 - val_loss: 1072.3339 - val_accuracy: 0.0000e+00
# Epoch 44/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1134.9778 - accuracy: 0.0000e+00 - val_loss: 1103.5139 - val_accuracy: 0.0000e+00
# Epoch 45/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1134.9431 - accuracy: 0.0000e+00 - val_loss: 1075.6042 - val_accuracy: 0.0000e+00
# Epoch 46/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1127.4681 - accuracy: 0.0000e+00 - val_loss: 1096.7800 - val_accuracy: 0.0000e+00
# Epoch 47/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1114.9043 - accuracy: 0.0000e+00 - val_loss: 1075.6786 - val_accuracy: 0.0000e+00
# Epoch 48/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1119.3598 - accuracy: 0.0000e+00 - val_loss: 1093.4247 - val_accuracy: 0.0000e+00
# Epoch 49/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1121.3632 - accuracy: 0.0000e+00 - val_loss: 1072.9913 - val_accuracy: 0.0000e+00
# Epoch 50/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1114.5093 - accuracy: 0.0000e+00 - val_loss: 1116.7866 - val_accuracy: 0.0000e+00
# Epoch 51/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1131.0887 - accuracy: 0.0000e+00 - val_loss: 1069.4504 - val_accuracy: 0.0000e+00
# Epoch 52/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1116.1182 - accuracy: 0.0000e+00 - val_loss: 1069.6591 - val_accuracy: 0.0000e+00
# Epoch 53/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1119.3502 - accuracy: 0.0000e+00 - val_loss: 1082.0564 - val_accuracy: 0.0000e+00
# Epoch 54/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1124.7263 - accuracy: 0.0000e+00 - val_loss: 1075.6714 - val_accuracy: 0.0000e+00
# Epoch 55/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1121.3961 - accuracy: 0.0000e+00 - val_loss: 1080.5649 - val_accuracy: 0.0000e+00
# Epoch 56/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1114.3952 - accuracy: 0.0000e+00 - val_loss: 1086.1887 - val_accuracy: 0.0000e+00
# Epoch 57/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1133.2681 - accuracy: 0.0000e+00 - val_loss: 1071.3975 - val_accuracy: 0.0000e+00
# Epoch 58/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1120.0882 - accuracy: 0.0000e+00 - val_loss: 1093.4409 - val_accuracy: 0.0000e+00
# Epoch 59/500
# 445/445 [==============================] - 0s 38us/sample - loss: 1120.3004 - accuracy: 0.0000e+00 - val_loss: 1102.6014 - val_accuracy: 0.0000e+00
# Epoch 60/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1131.8116 - accuracy: 0.0000e+00 - val_loss: 1099.9832 - val_accuracy: 0.0000e+00
# Epoch 61/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1122.2934 - accuracy: 0.0000e+00 - val_loss: 1092.8375 - val_accuracy: 0.0000e+00
# Epoch 62/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1114.9772 - accuracy: 0.0000e+00 - val_loss: 1087.9230 - val_accuracy: 0.0000e+00
# Epoch 63/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1114.2162 - accuracy: 0.0000e+00 - val_loss: 1093.8364 - val_accuracy: 0.0000e+00
# Epoch 64/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1124.1403 - accuracy: 0.0000e+00 - val_loss: 1105.3718 - val_accuracy: 0.0000e+00
# Epoch 65/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1107.7972 - accuracy: 0.0000e+00 - val_loss: 1097.9883 - val_accuracy: 0.0000e+00
# Epoch 66/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1131.7367 - accuracy: 0.0000e+00 - val_loss: 1069.8418 - val_accuracy: 0.0000e+00
# Epoch 67/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1118.3293 - accuracy: 0.0000e+00 - val_loss: 1073.3138 - val_accuracy: 0.0000e+00
# Epoch 68/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1117.3280 - accuracy: 0.0000e+00 - val_loss: 1092.5785 - val_accuracy: 0.0000e+00
# Epoch 69/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1122.6053 - accuracy: 0.0000e+00 - val_loss: 1108.7218 - val_accuracy: 0.0000e+00
# Epoch 70/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1118.9980 - accuracy: 0.0000e+00 - val_loss: 1097.8253 - val_accuracy: 0.0000e+00
# Epoch 71/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1116.4925 - accuracy: 0.0000e+00 - val_loss: 1100.9588 - val_accuracy: 0.0000e+00
# Epoch 72/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1105.9806 - accuracy: 0.0000e+00 - val_loss: 1104.4932 - val_accuracy: 0.0000e+00
# Epoch 73/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1105.0874 - accuracy: 0.0000e+00 - val_loss: 1117.4187 - val_accuracy: 0.0000e+00
# Epoch 74/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1122.5546 - accuracy: 0.0000e+00 - val_loss: 1097.7417 - val_accuracy: 0.0000e+00
# Epoch 75/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1118.2656 - accuracy: 0.0000e+00 - val_loss: 1094.5889 - val_accuracy: 0.0000e+00
# Epoch 76/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1103.2411 - accuracy: 0.0000e+00 - val_loss: 1138.0131 - val_accuracy: 0.0000e+00
# Epoch 77/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1118.6155 - accuracy: 0.0000e+00 - val_loss: 1086.7521 - val_accuracy: 0.0000e+00
# Epoch 78/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1113.9253 - accuracy: 0.0000e+00 - val_loss: 1064.7871 - val_accuracy: 0.0000e+00
# Epoch 79/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1124.4239 - accuracy: 0.0000e+00 - val_loss: 1071.8199 - val_accuracy: 0.0000e+00
# Epoch 80/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1109.2692 - accuracy: 0.0000e+00 - val_loss: 1086.2742 - val_accuracy: 0.0000e+00
# Epoch 81/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1106.2210 - accuracy: 0.0000e+00 - val_loss: 1112.8258 - val_accuracy: 0.0000e+00
# Epoch 82/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1108.3119 - accuracy: 0.0000e+00 - val_loss: 1117.9961 - val_accuracy: 0.0000e+00
# Epoch 83/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1106.0041 - accuracy: 0.0000e+00 - val_loss: 1099.8819 - val_accuracy: 0.0000e+00
# Epoch 84/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1112.3106 - accuracy: 0.0000e+00 - val_loss: 1112.7734 - val_accuracy: 0.0000e+00
# Epoch 85/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1102.9116 - accuracy: 0.0000e+00 - val_loss: 1128.7891 - val_accuracy: 0.0000e+00
# Epoch 86/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1107.9888 - accuracy: 0.0000e+00 - val_loss: 1100.4827 - val_accuracy: 0.0000e+00
# Epoch 87/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1104.0311 - accuracy: 0.0000e+00 - val_loss: 1104.1376 - val_accuracy: 0.0000e+00
# Epoch 88/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1104.9216 - accuracy: 0.0000e+00 - val_loss: 1111.0182 - val_accuracy: 0.0000e+00
# Epoch 89/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1104.1911 - accuracy: 0.0000e+00 - val_loss: 1120.0290 - val_accuracy: 0.0000e+00
# Epoch 90/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1108.9045 - accuracy: 0.0000e+00 - val_loss: 1119.2949 - val_accuracy: 0.0000e+00
# Epoch 91/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1107.7600 - accuracy: 0.0000e+00 - val_loss: 1128.7281 - val_accuracy: 0.0000e+00
# Epoch 92/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1104.8504 - accuracy: 0.0000e+00 - val_loss: 1095.6677 - val_accuracy: 0.0000e+00
# Epoch 93/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1105.6844 - accuracy: 0.0000e+00 - val_loss: 1120.9420 - val_accuracy: 0.0000e+00
# Epoch 94/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1108.4954 - accuracy: 0.0000e+00 - val_loss: 1116.8725 - val_accuracy: 0.0000e+00
# Epoch 95/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1099.7929 - accuracy: 0.0000e+00 - val_loss: 1108.6439 - val_accuracy: 0.0000e+00
# Epoch 96/500
# 445/445 [==============================] - 0s 40us/sample - loss: 1100.9232 - accuracy: 0.0000e+00 - val_loss: 1112.7017 - val_accuracy: 0.0000e+00
# Epoch 97/500
# 445/445 [==============================] - 0s 70us/sample - loss: 1108.4891 - accuracy: 0.0000e+00 - val_loss: 1098.8074 - val_accuracy: 0.0000e+00
# Epoch 98/500
# 445/445 [==============================] - 0s 76us/sample - loss: 1100.9399 - accuracy: 0.0000e+00 - val_loss: 1111.9083 - val_accuracy: 0.0000e+00
# Epoch 99/500
# 445/445 [==============================] - 0s 83us/sample - loss: 1104.0001 - accuracy: 0.0000e+00 - val_loss: 1122.6248 - val_accuracy: 0.0000e+00
# Epoch 100/500
# 445/445 [==============================] - 0s 72us/sample - loss: 1100.5134 - accuracy: 0.0000e+00 - val_loss: 1115.0647 - val_accuracy: 0.0000e+00
# Epoch 101/500
# 445/445 [==============================] - 0s 87us/sample - loss: 1102.8510 - accuracy: 0.0000e+00 - val_loss: 1125.8416 - val_accuracy: 0.0000e+00
# Epoch 102/500
# 445/445 [==============================] - 0s 85us/sample - loss: 1099.3439 - accuracy: 0.0000e+00 - val_loss: 1112.4200 - val_accuracy: 0.0000e+00
# Epoch 103/500
# 445/445 [==============================] - 0s 95us/sample - loss: 1102.6352 - accuracy: 0.0000e+00 - val_loss: 1111.7952 - val_accuracy: 0.0000e+00
# Epoch 104/500
# 445/445 [==============================] - 0s 85us/sample - loss: 1107.8088 - accuracy: 0.0000e+00 - val_loss: 1112.1714 - val_accuracy: 0.0000e+00
# Epoch 105/500
# 445/445 [==============================] - 0s 80us/sample - loss: 1095.5888 - accuracy: 0.0000e+00 - val_loss: 1106.5552 - val_accuracy: 0.0000e+00
# Epoch 106/500
# 445/445 [==============================] - 0s 95us/sample - loss: 1101.4802 - accuracy: 0.0000e+00 - val_loss: 1113.6155 - val_accuracy: 0.0000e+00
# Epoch 107/500
# 445/445 [==============================] - 0s 52us/sample - loss: 1099.9915 - accuracy: 0.0000e+00 - val_loss: 1108.4334 - val_accuracy: 0.0000e+00
# Epoch 108/500
# 445/445 [==============================] - 0s 40us/sample - loss: 1103.0942 - accuracy: 0.0000e+00 - val_loss: 1120.3637 - val_accuracy: 0.0000e+00
# Epoch 109/500
# 445/445 [==============================] - 0s 36us/sample - loss: 1101.8623 - accuracy: 0.0000e+00 - val_loss: 1117.2530 - val_accuracy: 0.0000e+00
# Epoch 110/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1100.5249 - accuracy: 0.0000e+00 - val_loss: 1109.5701 - val_accuracy: 0.0000e+00
# Epoch 111/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1101.9099 - accuracy: 0.0000e+00 - val_loss: 1122.0251 - val_accuracy: 0.0000e+00
# Epoch 112/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1097.6611 - accuracy: 0.0000e+00 - val_loss: 1117.5225 - val_accuracy: 0.0000e+00
# Epoch 113/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1098.1242 - accuracy: 0.0000e+00 - val_loss: 1122.7447 - val_accuracy: 0.0000e+00
# Epoch 114/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1101.3326 - accuracy: 0.0000e+00 - val_loss: 1124.4461 - val_accuracy: 0.0000e+00
# Epoch 115/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1096.0972 - accuracy: 0.0000e+00 - val_loss: 1120.6887 - val_accuracy: 0.0000e+00
# Epoch 116/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1094.2341 - accuracy: 0.0000e+00 - val_loss: 1109.6262 - val_accuracy: 0.0000e+00
# Epoch 117/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1101.4264 - accuracy: 0.0000e+00 - val_loss: 1128.0194 - val_accuracy: 0.0000e+00
# Epoch 118/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1115.0882 - accuracy: 0.0000e+00 - val_loss: 1113.7845 - val_accuracy: 0.0000e+00
# Epoch 119/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1107.0648 - accuracy: 0.0000e+00 - val_loss: 1115.4942 - val_accuracy: 0.0000e+00
# Epoch 120/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1099.8801 - accuracy: 0.0000e+00 - val_loss: 1107.9189 - val_accuracy: 0.0000e+00
# Epoch 121/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1097.5992 - accuracy: 0.0000e+00 - val_loss: 1117.8130 - val_accuracy: 0.0000e+00
# Epoch 122/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1099.9736 - accuracy: 0.0000e+00 - val_loss: 1122.8347 - val_accuracy: 0.0000e+00
# Epoch 123/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1101.4141 - accuracy: 0.0000e+00 - val_loss: 1110.2708 - val_accuracy: 0.0000e+00
# Epoch 124/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1097.0999 - accuracy: 0.0000e+00 - val_loss: 1112.2772 - val_accuracy: 0.0000e+00
# Epoch 125/500
# 445/445 [==============================] - 0s 40us/sample - loss: 1101.6897 - accuracy: 0.0000e+00 - val_loss: 1130.6651 - val_accuracy: 0.0000e+00
# Epoch 126/500
# 445/445 [==============================] - 0s 38us/sample - loss: 1109.2824 - accuracy: 0.0000e+00 - val_loss: 1102.1895 - val_accuracy: 0.0000e+00
# Epoch 127/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1102.4058 - accuracy: 0.0000e+00 - val_loss: 1089.1802 - val_accuracy: 0.0000e+00
# Epoch 128/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1109.9563 - accuracy: 0.0000e+00 - val_loss: 1126.7979 - val_accuracy: 0.0000e+00
# Epoch 129/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1118.4648 - accuracy: 0.0000e+00 - val_loss: 1171.4958 - val_accuracy: 0.0000e+00
# Epoch 130/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1109.1172 - accuracy: 0.0000e+00 - val_loss: 1073.2811 - val_accuracy: 0.0000e+00
# Epoch 131/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1103.7449 - accuracy: 0.0000e+00 - val_loss: 1080.6453 - val_accuracy: 0.0000e+00
# Epoch 132/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1109.6731 - accuracy: 0.0000e+00 - val_loss: 1101.5065 - val_accuracy: 0.0000e+00
# Epoch 133/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1102.9428 - accuracy: 0.0000e+00 - val_loss: 1118.3091 - val_accuracy: 0.0000e+00
# Epoch 134/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1102.2818 - accuracy: 0.0000e+00 - val_loss: 1100.3376 - val_accuracy: 0.0000e+00
# Epoch 135/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1096.0422 - accuracy: 0.0000e+00 - val_loss: 1126.3326 - val_accuracy: 0.0000e+00
# Epoch 136/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1108.6671 - accuracy: 0.0000e+00 - val_loss: 1096.0500 - val_accuracy: 0.0000e+00
# Epoch 137/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1105.7684 - accuracy: 0.0000e+00 - val_loss: 1111.8283 - val_accuracy: 0.0000e+00
# Epoch 138/500
# 445/445 [==============================] - 0s 39us/sample - loss: 1094.6623 - accuracy: 0.0000e+00 - val_loss: 1119.8019 - val_accuracy: 0.0000e+00
# Epoch 139/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1096.8875 - accuracy: 0.0000e+00 - val_loss: 1111.6944 - val_accuracy: 0.0000e+00
# Epoch 140/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1093.7348 - accuracy: 0.0000e+00 - val_loss: 1103.4930 - val_accuracy: 0.0000e+00
# Epoch 141/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1096.4217 - accuracy: 0.0000e+00 - val_loss: 1107.2693 - val_accuracy: 0.0000e+00
# Epoch 142/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1106.0619 - accuracy: 0.0000e+00 - val_loss: 1113.1755 - val_accuracy: 0.0000e+00
# Epoch 143/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1103.3416 - accuracy: 0.0000e+00 - val_loss: 1117.8109 - val_accuracy: 0.0000e+00
# Epoch 144/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1106.1267 - accuracy: 0.0000e+00 - val_loss: 1109.1897 - val_accuracy: 0.0000e+00
# Epoch 145/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1106.3281 - accuracy: 0.0000e+00 - val_loss: 1123.5328 - val_accuracy: 0.0000e+00
# Epoch 146/500
# 445/445 [==============================] - 0s 39us/sample - loss: 1090.0737 - accuracy: 0.0000e+00 - val_loss: 1113.5850 - val_accuracy: 0.0000e+00
# Epoch 147/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1094.3212 - accuracy: 0.0000e+00 - val_loss: 1125.9442 - val_accuracy: 0.0000e+00
# Epoch 148/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1119.0626 - accuracy: 0.0000e+00 - val_loss: 1126.3836 - val_accuracy: 0.0000e+00
# Epoch 149/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1092.9327 - accuracy: 0.0000e+00 - val_loss: 1142.4647 - val_accuracy: 0.0000e+00
# Epoch 150/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1091.4143 - accuracy: 0.0000e+00 - val_loss: 1110.0198 - val_accuracy: 0.0000e+00
# Epoch 151/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1129.1655 - accuracy: 0.0000e+00 - val_loss: 1118.6190 - val_accuracy: 0.0000e+00
# Epoch 152/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1099.8514 - accuracy: 0.0000e+00 - val_loss: 1114.8035 - val_accuracy: 0.0000e+00
# Epoch 153/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1095.0319 - accuracy: 0.0000e+00 - val_loss: 1115.9841 - val_accuracy: 0.0000e+00
# Epoch 154/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1093.9561 - accuracy: 0.0000e+00 - val_loss: 1122.7266 - val_accuracy: 0.0000e+00
# Epoch 155/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1095.5382 - accuracy: 0.0000e+00 - val_loss: 1089.7243 - val_accuracy: 0.0000e+00
# Epoch 156/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1100.5023 - accuracy: 0.0000e+00 - val_loss: 1108.4238 - val_accuracy: 0.0000e+00
# Epoch 157/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1094.2781 - accuracy: 0.0000e+00 - val_loss: 1123.9173 - val_accuracy: 0.0000e+00
# Epoch 158/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1095.6352 - accuracy: 0.0000e+00 - val_loss: 1090.5040 - val_accuracy: 0.0000e+00
# Epoch 159/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1098.1004 - accuracy: 0.0000e+00 - val_loss: 1127.0101 - val_accuracy: 0.0000e+00
# Epoch 160/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1100.9030 - accuracy: 0.0000e+00 - val_loss: 1108.5017 - val_accuracy: 0.0000e+00
# Epoch 161/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1098.5768 - accuracy: 0.0000e+00 - val_loss: 1117.9166 - val_accuracy: 0.0000e+00
# Epoch 162/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1092.5048 - accuracy: 0.0000e+00 - val_loss: 1104.3604 - val_accuracy: 0.0000e+00
# Epoch 163/500
# 445/445 [==============================] - 0s 38us/sample - loss: 1095.2477 - accuracy: 0.0000e+00 - val_loss: 1120.1072 - val_accuracy: 0.0000e+00
# Epoch 164/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1090.4862 - accuracy: 0.0000e+00 - val_loss: 1111.7097 - val_accuracy: 0.0000e+00
# Epoch 165/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1092.7111 - accuracy: 0.0000e+00 - val_loss: 1113.6536 - val_accuracy: 0.0000e+00
# Epoch 166/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1104.2804 - accuracy: 0.0000e+00 - val_loss: 1123.8612 - val_accuracy: 0.0000e+00
# Epoch 167/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1093.5524 - accuracy: 0.0000e+00 - val_loss: 1103.2663 - val_accuracy: 0.0000e+00
# Epoch 168/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1093.3197 - accuracy: 0.0000e+00 - val_loss: 1118.6715 - val_accuracy: 0.0000e+00
# Epoch 169/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1100.7319 - accuracy: 0.0000e+00 - val_loss: 1111.8553 - val_accuracy: 0.0000e+00
# Epoch 170/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1091.8745 - accuracy: 0.0000e+00 - val_loss: 1104.0476 - val_accuracy: 0.0000e+00
# Epoch 171/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1093.5113 - accuracy: 0.0000e+00 - val_loss: 1133.4087 - val_accuracy: 0.0000e+00
# Epoch 172/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1091.6590 - accuracy: 0.0000e+00 - val_loss: 1096.6691 - val_accuracy: 0.0000e+00
# Epoch 173/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1097.9464 - accuracy: 0.0000e+00 - val_loss: 1104.3472 - val_accuracy: 0.0000e+00
# Epoch 174/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1101.3783 - accuracy: 0.0000e+00 - val_loss: 1119.9244 - val_accuracy: 0.0000e+00
# Epoch 175/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1092.3887 - accuracy: 0.0000e+00 - val_loss: 1112.3044 - val_accuracy: 0.0000e+00
# Epoch 176/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1098.4373 - accuracy: 0.0000e+00 - val_loss: 1112.6937 - val_accuracy: 0.0000e+00
# Epoch 177/500
# 445/445 [==============================] - 0s 38us/sample - loss: 1096.7115 - accuracy: 0.0000e+00 - val_loss: 1127.3305 - val_accuracy: 0.0000e+00
# Epoch 178/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1134.5957 - accuracy: 0.0000e+00 - val_loss: 1166.1888 - val_accuracy: 0.0000e+00
# Epoch 179/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1119.6114 - accuracy: 0.0000e+00 - val_loss: 1130.0235 - val_accuracy: 0.0000e+00
# Epoch 180/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1090.1003 - accuracy: 0.0000e+00 - val_loss: 1089.6760 - val_accuracy: 0.0000e+00
# Epoch 181/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1098.7201 - accuracy: 0.0000e+00 - val_loss: 1105.7175 - val_accuracy: 0.0000e+00
# Epoch 182/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1091.0605 - accuracy: 0.0000e+00 - val_loss: 1128.4662 - val_accuracy: 0.0000e+00
# Epoch 183/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1096.3690 - accuracy: 0.0000e+00 - val_loss: 1106.1303 - val_accuracy: 0.0000e+00
# Epoch 184/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1093.1929 - accuracy: 0.0000e+00 - val_loss: 1113.8244 - val_accuracy: 0.0000e+00
# Epoch 185/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1090.7163 - accuracy: 0.0000e+00 - val_loss: 1109.3972 - val_accuracy: 0.0000e+00
# Epoch 186/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1091.8399 - accuracy: 0.0000e+00 - val_loss: 1113.5878 - val_accuracy: 0.0000e+00
# Epoch 187/500
# 445/445 [==============================] - 0s 39us/sample - loss: 1127.3890 - accuracy: 0.0000e+00 - val_loss: 1130.5090 - val_accuracy: 0.0000e+00
# Epoch 188/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1098.0472 - accuracy: 0.0000e+00 - val_loss: 1097.1489 - val_accuracy: 0.0000e+00
# Epoch 189/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1096.0421 - accuracy: 0.0000e+00 - val_loss: 1122.1589 - val_accuracy: 0.0000e+00
# Epoch 190/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1089.2394 - accuracy: 0.0000e+00 - val_loss: 1134.4424 - val_accuracy: 0.0000e+00
# Epoch 191/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1102.0084 - accuracy: 0.0000e+00 - val_loss: 1112.2234 - val_accuracy: 0.0000e+00
# Epoch 192/500
# 445/445 [==============================] - 0s 37us/sample - loss: 1092.9809 - accuracy: 0.0000e+00 - val_loss: 1114.6799 - val_accuracy: 0.0000e+00
# Epoch 193/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1090.8246 - accuracy: 0.0000e+00 - val_loss: 1118.7725 - val_accuracy: 0.0000e+00
# Epoch 194/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1087.6649 - accuracy: 0.0000e+00 - val_loss: 1097.8198 - val_accuracy: 0.0000e+00
# Epoch 195/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1084.6573 - accuracy: 0.0000e+00 - val_loss: 1114.2837 - val_accuracy: 0.0000e+00
# Epoch 196/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1088.2399 - accuracy: 0.0000e+00 - val_loss: 1121.9117 - val_accuracy: 0.0000e+00
# Epoch 197/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1090.6101 - accuracy: 0.0000e+00 - val_loss: 1108.2039 - val_accuracy: 0.0000e+00
# Epoch 198/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1092.4554 - accuracy: 0.0000e+00 - val_loss: 1118.2280 - val_accuracy: 0.0000e+00
# Epoch 199/500
# 445/445 [==============================] - 0s 39us/sample - loss: 1089.7400 - accuracy: 0.0000e+00 - val_loss: 1109.2893 - val_accuracy: 0.0000e+00
# Epoch 200/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1087.3672 - accuracy: 0.0000e+00 - val_loss: 1115.9335 - val_accuracy: 0.0000e+00
# Epoch 201/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1093.3730 - accuracy: 0.0000e+00 - val_loss: 1131.4778 - val_accuracy: 0.0000e+00
# Epoch 202/500
# 445/445 [==============================] - 0s 40us/sample - loss: 1088.0871 - accuracy: 0.0000e+00 - val_loss: 1135.5225 - val_accuracy: 0.0000e+00
# Epoch 203/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1110.4112 - accuracy: 0.0000e+00 - val_loss: 1103.9627 - val_accuracy: 0.0000e+00
# Epoch 204/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1086.3915 - accuracy: 0.0000e+00 - val_loss: 1110.9503 - val_accuracy: 0.0000e+00
# Epoch 205/500
# 445/445 [==============================] - 0s 39us/sample - loss: 1109.0463 - accuracy: 0.0000e+00 - val_loss: 1117.7296 - val_accuracy: 0.0000e+00
# Epoch 206/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1094.8515 - accuracy: 0.0000e+00 - val_loss: 1101.0531 - val_accuracy: 0.0000e+00
# Epoch 207/500
# 445/445 [==============================] - 0s 62us/sample - loss: 1088.6705 - accuracy: 0.0000e+00 - val_loss: 1114.1031 - val_accuracy: 0.0000e+00
# Epoch 208/500
# 445/445 [==============================] - 0s 88us/sample - loss: 1097.0825 - accuracy: 0.0000e+00 - val_loss: 1138.7134 - val_accuracy: 0.0000e+00
# Epoch 209/500
# 445/445 [==============================] - 0s 94us/sample - loss: 1100.9276 - accuracy: 0.0000e+00 - val_loss: 1140.9719 - val_accuracy: 0.0000e+00
# Epoch 210/500
# 445/445 [==============================] - 0s 86us/sample - loss: 1087.6987 - accuracy: 0.0000e+00 - val_loss: 1117.1784 - val_accuracy: 0.0000e+00
# Epoch 211/500
# 445/445 [==============================] - 0s 82us/sample - loss: 1113.0085 - accuracy: 0.0000e+00 - val_loss: 1118.8198 - val_accuracy: 0.0000e+00
# Epoch 212/500
# 445/445 [==============================] - 0s 87us/sample - loss: 1095.1190 - accuracy: 0.0000e+00 - val_loss: 1110.1639 - val_accuracy: 0.0000e+00
# Epoch 213/500
# 445/445 [==============================] - 0s 80us/sample - loss: 1101.3201 - accuracy: 0.0000e+00 - val_loss: 1119.7066 - val_accuracy: 0.0000e+00
# Epoch 214/500
# 445/445 [==============================] - 0s 76us/sample - loss: 1101.1247 - accuracy: 0.0000e+00 - val_loss: 1087.7409 - val_accuracy: 0.0000e+00
# Epoch 215/500
# 445/445 [==============================] - 0s 76us/sample - loss: 1096.1286 - accuracy: 0.0000e+00 - val_loss: 1095.1199 - val_accuracy: 0.0000e+00
# Epoch 216/500
# 445/445 [==============================] - 0s 71us/sample - loss: 1087.3250 - accuracy: 0.0000e+00 - val_loss: 1120.6525 - val_accuracy: 0.0000e+00
# Epoch 217/500
# 445/445 [==============================] - 0s 65us/sample - loss: 1086.8133 - accuracy: 0.0000e+00 - val_loss: 1114.8378 - val_accuracy: 0.0000e+00
# Epoch 218/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1089.5153 - accuracy: 0.0000e+00 - val_loss: 1117.9657 - val_accuracy: 0.0000e+00
# Epoch 219/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1083.2597 - accuracy: 0.0000e+00 - val_loss: 1104.2079 - val_accuracy: 0.0000e+00
# Epoch 220/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1092.3142 - accuracy: 0.0000e+00 - val_loss: 1130.3422 - val_accuracy: 0.0000e+00
# Epoch 221/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1093.2026 - accuracy: 0.0000e+00 - val_loss: 1106.0536 - val_accuracy: 0.0000e+00
# Epoch 222/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1089.2286 - accuracy: 0.0000e+00 - val_loss: 1115.7532 - val_accuracy: 0.0000e+00
# Epoch 223/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1094.9801 - accuracy: 0.0000e+00 - val_loss: 1120.2506 - val_accuracy: 0.0000e+00
# Epoch 224/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1095.6835 - accuracy: 0.0000e+00 - val_loss: 1105.5682 - val_accuracy: 0.0000e+00
# Epoch 225/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1083.0932 - accuracy: 0.0000e+00 - val_loss: 1110.7385 - val_accuracy: 0.0000e+00
# Epoch 226/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1085.1843 - accuracy: 0.0000e+00 - val_loss: 1113.8127 - val_accuracy: 0.0000e+00
# Epoch 227/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1093.1505 - accuracy: 0.0000e+00 - val_loss: 1120.3560 - val_accuracy: 0.0000e+00
# Epoch 228/500
# 445/445 [==============================] - 0s 40us/sample - loss: 1080.0059 - accuracy: 0.0000e+00 - val_loss: 1128.1568 - val_accuracy: 0.0000e+00
# Epoch 229/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1082.6348 - accuracy: 0.0000e+00 - val_loss: 1104.7148 - val_accuracy: 0.0000e+00
# Epoch 230/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1097.4143 - accuracy: 0.0000e+00 - val_loss: 1116.0620 - val_accuracy: 0.0000e+00
# Epoch 231/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1085.8181 - accuracy: 0.0000e+00 - val_loss: 1107.6545 - val_accuracy: 0.0000e+00
# Epoch 232/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1095.0111 - accuracy: 0.0000e+00 - val_loss: 1123.0051 - val_accuracy: 0.0000e+00
# Epoch 233/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1091.8695 - accuracy: 0.0000e+00 - val_loss: 1119.5369 - val_accuracy: 0.0000e+00
# Epoch 234/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1090.0224 - accuracy: 0.0000e+00 - val_loss: 1106.0915 - val_accuracy: 0.0000e+00
# Epoch 235/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1083.6748 - accuracy: 0.0000e+00 - val_loss: 1115.5830 - val_accuracy: 0.0000e+00
# Epoch 236/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1083.5436 - accuracy: 0.0000e+00 - val_loss: 1122.3520 - val_accuracy: 0.0000e+00
# Epoch 237/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1088.1334 - accuracy: 0.0000e+00 - val_loss: 1112.9949 - val_accuracy: 0.0000e+00
# Epoch 238/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1086.8073 - accuracy: 0.0000e+00 - val_loss: 1103.9619 - val_accuracy: 0.0000e+00
# Epoch 239/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1084.6853 - accuracy: 0.0000e+00 - val_loss: 1112.6423 - val_accuracy: 0.0000e+00
# Epoch 240/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1080.7372 - accuracy: 0.0000e+00 - val_loss: 1100.0594 - val_accuracy: 0.0000e+00
# Epoch 241/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1096.1768 - accuracy: 0.0000e+00 - val_loss: 1131.3708 - val_accuracy: 0.0000e+00
# Epoch 242/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1084.8747 - accuracy: 0.0000e+00 - val_loss: 1096.7211 - val_accuracy: 0.0000e+00
# Epoch 243/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1083.7835 - accuracy: 0.0000e+00 - val_loss: 1130.6787 - val_accuracy: 0.0000e+00
# Epoch 244/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1094.1322 - accuracy: 0.0000e+00 - val_loss: 1112.4481 - val_accuracy: 0.0000e+00
# Epoch 245/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1095.0381 - accuracy: 0.0000e+00 - val_loss: 1100.3948 - val_accuracy: 0.0000e+00
# Epoch 246/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1095.1588 - accuracy: 0.0000e+00 - val_loss: 1126.6793 - val_accuracy: 0.0000e+00
# Epoch 247/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1089.6416 - accuracy: 0.0000e+00 - val_loss: 1107.2080 - val_accuracy: 0.0000e+00
# Epoch 248/500
# 445/445 [==============================] - 0s 40us/sample - loss: 1082.2117 - accuracy: 0.0000e+00 - val_loss: 1111.3291 - val_accuracy: 0.0000e+00
# Epoch 249/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1081.6347 - accuracy: 0.0000e+00 - val_loss: 1099.8659 - val_accuracy: 0.0000e+00
# Epoch 250/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1083.3076 - accuracy: 0.0000e+00 - val_loss: 1108.2035 - val_accuracy: 0.0000e+00
# Epoch 251/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1075.5728 - accuracy: 0.0000e+00 - val_loss: 1130.0229 - val_accuracy: 0.0000e+00
# Epoch 252/500
# 445/445 [==============================] - 0s 40us/sample - loss: 1084.9121 - accuracy: 0.0000e+00 - val_loss: 1110.4746 - val_accuracy: 0.0000e+00
# Epoch 253/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1100.3258 - accuracy: 0.0000e+00 - val_loss: 1132.3189 - val_accuracy: 0.0000e+00
# Epoch 254/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1088.1140 - accuracy: 0.0000e+00 - val_loss: 1120.0194 - val_accuracy: 0.0000e+00
# Epoch 255/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1098.3265 - accuracy: 0.0000e+00 - val_loss: 1088.8827 - val_accuracy: 0.0000e+00
# Epoch 256/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1098.5564 - accuracy: 0.0000e+00 - val_loss: 1110.7165 - val_accuracy: 0.0000e+00
# Epoch 257/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1087.0055 - accuracy: 0.0000e+00 - val_loss: 1113.6470 - val_accuracy: 0.0000e+00
# Epoch 258/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1083.6813 - accuracy: 0.0000e+00 - val_loss: 1102.0077 - val_accuracy: 0.0000e+00
# Epoch 259/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1084.6967 - accuracy: 0.0000e+00 - val_loss: 1110.5651 - val_accuracy: 0.0000e+00
# Epoch 260/500
# 445/445 [==============================] - 0s 40us/sample - loss: 1078.0332 - accuracy: 0.0000e+00 - val_loss: 1111.7887 - val_accuracy: 0.0000e+00
# Epoch 261/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1088.8671 - accuracy: 0.0000e+00 - val_loss: 1121.6584 - val_accuracy: 0.0000e+00
# Epoch 262/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1099.6292 - accuracy: 0.0000e+00 - val_loss: 1099.0931 - val_accuracy: 0.0000e+00
# Epoch 263/500
# 445/445 [==============================] - 0s 40us/sample - loss: 1086.9537 - accuracy: 0.0000e+00 - val_loss: 1134.4027 - val_accuracy: 0.0000e+00
# Epoch 264/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1078.8068 - accuracy: 0.0000e+00 - val_loss: 1109.4212 - val_accuracy: 0.0000e+00
# Epoch 265/500
# 445/445 [==============================] - 0s 40us/sample - loss: 1088.1621 - accuracy: 0.0000e+00 - val_loss: 1111.9220 - val_accuracy: 0.0000e+00
# Epoch 266/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1090.6204 - accuracy: 0.0000e+00 - val_loss: 1114.8822 - val_accuracy: 0.0000e+00
# Epoch 267/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1079.9069 - accuracy: 0.0000e+00 - val_loss: 1117.0482 - val_accuracy: 0.0000e+00
# Epoch 268/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1084.6271 - accuracy: 0.0000e+00 - val_loss: 1138.5626 - val_accuracy: 0.0000e+00
# Epoch 269/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1092.8960 - accuracy: 0.0000e+00 - val_loss: 1115.8602 - val_accuracy: 0.0000e+00
# Epoch 270/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1079.3776 - accuracy: 0.0000e+00 - val_loss: 1102.8366 - val_accuracy: 0.0000e+00
# Epoch 271/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1086.7668 - accuracy: 0.0000e+00 - val_loss: 1124.0336 - val_accuracy: 0.0000e+00
# Epoch 272/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1106.5083 - accuracy: 0.0000e+00 - val_loss: 1106.7648 - val_accuracy: 0.0000e+00
# Epoch 273/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1103.7905 - accuracy: 0.0000e+00 - val_loss: 1105.4655 - val_accuracy: 0.0000e+00
# Epoch 274/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1094.6677 - accuracy: 0.0000e+00 - val_loss: 1137.9169 - val_accuracy: 0.0000e+00
# Epoch 275/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1087.3312 - accuracy: 0.0000e+00 - val_loss: 1098.0581 - val_accuracy: 0.0000e+00
# Epoch 276/500
# 445/445 [==============================] - 0s 37us/sample - loss: 1091.9191 - accuracy: 0.0000e+00 - val_loss: 1110.2694 - val_accuracy: 0.0000e+00
# Epoch 277/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1080.7370 - accuracy: 0.0000e+00 - val_loss: 1120.1873 - val_accuracy: 0.0000e+00
# Epoch 278/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1085.8307 - accuracy: 0.0000e+00 - val_loss: 1109.8136 - val_accuracy: 0.0000e+00
# Epoch 279/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1079.0164 - accuracy: 0.0000e+00 - val_loss: 1097.3603 - val_accuracy: 0.0000e+00
# Epoch 280/500
# 445/445 [==============================] - 0s 39us/sample - loss: 1078.6323 - accuracy: 0.0000e+00 - val_loss: 1123.5990 - val_accuracy: 0.0000e+00
# Epoch 281/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1079.1624 - accuracy: 0.0000e+00 - val_loss: 1118.8461 - val_accuracy: 0.0000e+00
# Epoch 282/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1074.4186 - accuracy: 0.0000e+00 - val_loss: 1116.8621 - val_accuracy: 0.0000e+00
# Epoch 283/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1084.8991 - accuracy: 0.0000e+00 - val_loss: 1109.9906 - val_accuracy: 0.0000e+00
# Epoch 284/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1078.2169 - accuracy: 0.0000e+00 - val_loss: 1118.1582 - val_accuracy: 0.0000e+00
# Epoch 285/500
# 445/445 [==============================] - 0s 41us/sample - loss: 1102.7319 - accuracy: 0.0000e+00 - val_loss: 1112.7754 - val_accuracy: 0.0000e+00
# Epoch 286/500
# 445/445 [==============================] - 0s 45us/sample - loss: 1092.9053 - accuracy: 0.0000e+00 - val_loss: 1103.6459 - val_accuracy: 0.0000e+00
# Epoch 287/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1077.3796 - accuracy: 0.0000e+00 - val_loss: 1118.7120 - val_accuracy: 0.0000e+00
# Epoch 288/500
# 445/445 [==============================] - 0s 98us/sample - loss: 1075.1720 - accuracy: 0.0000e+00 - val_loss: 1111.4829 - val_accuracy: 0.0000e+00
# Epoch 289/500
# ...
# Epoch 403/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1081.7338 - accuracy: 0.0000e+00 - val_loss: 1100.3399 - val_accuracy: 0.0000e+00
# Epoch 404/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1076.1159 - accuracy: 0.0000e+00 - val_loss: 1093.4987 - val_accuracy: 0.0000e+00
# Epoch 405/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1072.2324 - accuracy: 0.0000e+00 - val_loss: 1108.8908 - val_accuracy: 0.0000e+00
# Epoch 406/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1068.6507 - accuracy: 0.0000e+00 - val_loss: 1099.2577 - val_accuracy: 0.0000e+00
# Epoch 407/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1065.2803 - accuracy: 0.0000e+00 - val_loss: 1104.9443 - val_accuracy: 0.0000e+00
# Epoch 408/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1066.3482 - accuracy: 0.0000e+00 - val_loss: 1126.6623 - val_accuracy: 0.0000e+00
# Epoch 409/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1074.2766 - accuracy: 0.0000e+00 - val_loss: 1092.2921 - val_accuracy: 0.0000e+00
# Epoch 410/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1066.6623 - accuracy: 0.0000e+00 - val_loss: 1121.3695 - val_accuracy: 0.0000e+00
# Epoch 411/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1070.2979 - accuracy: 0.0000e+00 - val_loss: 1147.5941 - val_accuracy: 0.0000e+00
# Epoch 412/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1071.4980 - accuracy: 0.0000e+00 - val_loss: 1118.6764 - val_accuracy: 0.0000e+00
# Epoch 413/500
# 445/445 [==============================] - 0s 52us/sample - loss: 1070.3015 - accuracy: 0.0000e+00 - val_loss: 1122.3616 - val_accuracy: 0.0000e+00
# Epoch 414/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1073.3932 - accuracy: 0.0000e+00 - val_loss: 1102.7356 - val_accuracy: 0.0000e+00
# Epoch 415/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1077.9696 - accuracy: 0.0000e+00 - val_loss: 1128.1444 - val_accuracy: 0.0000e+00
# Epoch 416/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1070.7884 - accuracy: 0.0000e+00 - val_loss: 1098.2565 - val_accuracy: 0.0000e+00
# Epoch 417/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1070.9951 - accuracy: 0.0000e+00 - val_loss: 1113.8835 - val_accuracy: 0.0000e+00
# Epoch 418/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1074.8845 - accuracy: 0.0000e+00 - val_loss: 1095.1642 - val_accuracy: 0.0000e+00
# Epoch 419/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1073.3459 - accuracy: 0.0000e+00 - val_loss: 1103.8715 - val_accuracy: 0.0000e+00
# Epoch 420/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1080.1472 - accuracy: 0.0000e+00 - val_loss: 1168.0004 - val_accuracy: 0.0000e+00
# Epoch 421/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1080.8564 - accuracy: 0.0000e+00 - val_loss: 1202.1583 - val_accuracy: 0.0000e+00
# Epoch 422/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1096.3162 - accuracy: 0.0000e+00 - val_loss: 1113.2555 - val_accuracy: 0.0000e+00
# Epoch 423/500
# 445/445 [==============================] - 0s 54us/sample - loss: 1090.4564 - accuracy: 0.0000e+00 - val_loss: 1050.1061 - val_accuracy: 0.0000e+00
# Epoch 424/500
# 445/445 [==============================] - 0s 52us/sample - loss: 1081.6293 - accuracy: 0.0000e+00 - val_loss: 1058.3858 - val_accuracy: 0.0000e+00
# Epoch 425/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1087.1720 - accuracy: 0.0000e+00 - val_loss: 1087.9577 - val_accuracy: 0.0000e+00
# Epoch 426/500
# 445/445 [==============================] - 0s 44us/sample - loss: 1073.6770 - accuracy: 0.0000e+00 - val_loss: 1130.5163 - val_accuracy: 0.0000e+00
# Epoch 427/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1081.0501 - accuracy: 0.0000e+00 - val_loss: 1120.3652 - val_accuracy: 0.0000e+00
# Epoch 428/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1079.2848 - accuracy: 0.0000e+00 - val_loss: 1083.7704 - val_accuracy: 0.0000e+00
# Epoch 429/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1070.4352 - accuracy: 0.0000e+00 - val_loss: 1078.7023 - val_accuracy: 0.0000e+00
# Epoch 430/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1067.7484 - accuracy: 0.0000e+00 - val_loss: 1105.7225 - val_accuracy: 0.0000e+00
# Epoch 431/500
# 445/445 [==============================] - 0s 52us/sample - loss: 1075.3758 - accuracy: 0.0000e+00 - val_loss: 1109.6033 - val_accuracy: 0.0000e+00
# Epoch 432/500
# 445/445 [==============================] - 0s 53us/sample - loss: 1070.9381 - accuracy: 0.0000e+00 - val_loss: 1121.7542 - val_accuracy: 0.0000e+00
# Epoch 433/500
# 445/445 [==============================] - 0s 52us/sample - loss: 1063.4913 - accuracy: 0.0000e+00 - val_loss: 1104.3921 - val_accuracy: 0.0000e+00
# Epoch 434/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1074.4789 - accuracy: 0.0000e+00 - val_loss: 1148.4434 - val_accuracy: 0.0000e+00
# Epoch 435/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1064.4791 - accuracy: 0.0000e+00 - val_loss: 1107.8269 - val_accuracy: 0.0000e+00
# Epoch 436/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1071.7332 - accuracy: 0.0000e+00 - val_loss: 1092.1181 - val_accuracy: 0.0000e+00
# Epoch 437/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1068.6007 - accuracy: 0.0000e+00 - val_loss: 1071.3712 - val_accuracy: 0.0000e+00
# Epoch 438/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1074.1363 - accuracy: 0.0000e+00 - val_loss: 1135.3902 - val_accuracy: 0.0000e+00
# Epoch 439/500
# 445/445 [==============================] - 0s 42us/sample - loss: 1083.7609 - accuracy: 0.0000e+00 - val_loss: 1078.9877 - val_accuracy: 0.0000e+00
# Epoch 440/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1074.5089 - accuracy: 0.0000e+00 - val_loss: 1086.5133 - val_accuracy: 0.0000e+00
# Epoch 441/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1066.8475 - accuracy: 0.0000e+00 - val_loss: 1160.8953 - val_accuracy: 0.0000e+00
# Epoch 442/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1064.8878 - accuracy: 0.0000e+00 - val_loss: 1146.9026 - val_accuracy: 0.0000e+00
# Epoch 443/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1082.8781 - accuracy: 0.0000e+00 - val_loss: 1109.8082 - val_accuracy: 0.0000e+00
# Epoch 444/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1064.1749 - accuracy: 0.0000e+00 - val_loss: 1083.5347 - val_accuracy: 0.0000e+00
# Epoch 445/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1070.6115 - accuracy: 0.0000e+00 - val_loss: 1091.5052 - val_accuracy: 0.0000e+00
# Epoch 446/500
# 445/445 [==============================] - 0s 101us/sample - loss: 1074.5836 - accuracy: 0.0000e+00 - val_loss: 1128.3641 - val_accuracy: 0.0000e+00
# Epoch 447/500
# 445/445 [==============================] - 0s 81us/sample - loss: 1068.5421 - accuracy: 0.0000e+00 - val_loss: 1144.4443 - val_accuracy: 0.0000e+00
# Epoch 448/500
# 445/445 [==============================] - 0s 100us/sample - loss: 1072.1859 - accuracy: 0.0000e+00 - val_loss: 1103.1834 - val_accuracy: 0.0000e+00
# Epoch 449/500
# 445/445 [==============================] - 0s 84us/sample - loss: 1062.4765 - accuracy: 0.0000e+00 - val_loss: 1089.6172 - val_accuracy: 0.0000e+00
# Epoch 450/500
# 445/445 [==============================] - 0s 111us/sample - loss: 1066.8144 - accuracy: 0.0000e+00 - val_loss: 1092.6156 - val_accuracy: 0.0000e+00
# Epoch 451/500
# 445/445 [==============================] - 0s 89us/sample - loss: 1065.9206 - accuracy: 0.0000e+00 - val_loss: 1088.4885 - val_accuracy: 0.0000e+00
# Epoch 452/500
# 445/445 [==============================] - 0s 84us/sample - loss: 1066.9904 - accuracy: 0.0000e+00 - val_loss: 1098.7442 - val_accuracy: 0.0000e+00
# Epoch 453/500
# 445/445 [==============================] - 0s 81us/sample - loss: 1070.1921 - accuracy: 0.0000e+00 - val_loss: 1090.7344 - val_accuracy: 0.0000e+00
# Epoch 454/500
# 445/445 [==============================] - 0s 107us/sample - loss: 1086.7110 - accuracy: 0.0000e+00 - val_loss: 1092.9148 - val_accuracy: 0.0000e+00
# Epoch 455/500
# 445/445 [==============================] - 0s 91us/sample - loss: 1088.9213 - accuracy: 0.0000e+00 - val_loss: 1144.1351 - val_accuracy: 0.0000e+00
# Epoch 456/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1082.7845 - accuracy: 0.0000e+00 - val_loss: 1109.6471 - val_accuracy: 0.0000e+00
# Epoch 457/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1078.6905 - accuracy: 0.0000e+00 - val_loss: 1110.3557 - val_accuracy: 0.0000e+00
# Epoch 458/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1082.0603 - accuracy: 0.0000e+00 - val_loss: 1095.8542 - val_accuracy: 0.0000e+00
# Epoch 459/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1080.7292 - accuracy: 0.0000e+00 - val_loss: 1127.5750 - val_accuracy: 0.0000e+00
# Epoch 460/500
# 445/445 [==============================] - 0s 53us/sample - loss: 1078.3604 - accuracy: 0.0000e+00 - val_loss: 1086.5321 - val_accuracy: 0.0000e+00
# Epoch 461/500
# 445/445 [==============================] - 0s 53us/sample - loss: 1073.0349 - accuracy: 0.0000e+00 - val_loss: 1111.7629 - val_accuracy: 0.0000e+00
# Epoch 462/500
# 445/445 [==============================] - 0s 53us/sample - loss: 1069.5897 - accuracy: 0.0000e+00 - val_loss: 1120.4062 - val_accuracy: 0.0000e+00
# Epoch 463/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1065.6485 - accuracy: 0.0000e+00 - val_loss: 1089.2051 - val_accuracy: 0.0000e+00
# Epoch 464/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1065.9797 - accuracy: 0.0000e+00 - val_loss: 1093.3921 - val_accuracy: 0.0000e+00
# Epoch 465/500
# 445/445 [==============================] - 0s 53us/sample - loss: 1060.1517 - accuracy: 0.0000e+00 - val_loss: 1125.4563 - val_accuracy: 0.0000e+00
# Epoch 466/500
# 445/445 [==============================] - 0s 53us/sample - loss: 1064.2009 - accuracy: 0.0000e+00 - val_loss: 1143.8598 - val_accuracy: 0.0000e+00
# Epoch 467/500
# 445/445 [==============================] - 0s 55us/sample - loss: 1064.1919 - accuracy: 0.0000e+00 - val_loss: 1130.3441 - val_accuracy: 0.0000e+00
# Epoch 468/500
# 445/445 [==============================] - 0s 55us/sample - loss: 1086.6800 - accuracy: 0.0000e+00 - val_loss: 1099.6270 - val_accuracy: 0.0000e+00
# Epoch 469/500
# 445/445 [==============================] - 0s 55us/sample - loss: 1073.6782 - accuracy: 0.0000e+00 - val_loss: 1067.7690 - val_accuracy: 0.0000e+00
# Epoch 470/500
# 445/445 [==============================] - 0s 56us/sample - loss: 1073.2651 - accuracy: 0.0000e+00 - val_loss: 1093.7900 - val_accuracy: 0.0000e+00
# Epoch 471/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1078.4647 - accuracy: 0.0000e+00 - val_loss: 1085.8243 - val_accuracy: 0.0000e+00
# Epoch 472/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1075.4134 - accuracy: 0.0000e+00 - val_loss: 1074.5670 - val_accuracy: 0.0000e+00
# Epoch 473/500
# 445/445 [==============================] - 0s 56us/sample - loss: 1071.4113 - accuracy: 0.0000e+00 - val_loss: 1106.8439 - val_accuracy: 0.0000e+00
# Epoch 474/500
# 445/445 [==============================] - 0s 54us/sample - loss: 1066.1710 - accuracy: 0.0000e+00 - val_loss: 1131.4615 - val_accuracy: 0.0000e+00
# Epoch 475/500
# 445/445 [==============================] - 0s 61us/sample - loss: 1070.7825 - accuracy: 0.0000e+00 - val_loss: 1123.8254 - val_accuracy: 0.0000e+00
# Epoch 476/500
# 445/445 [==============================] - 0s 48us/sample - loss: 1075.6088 - accuracy: 0.0000e+00 - val_loss: 1078.5559 - val_accuracy: 0.0000e+00
# Epoch 477/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1080.7684 - accuracy: 0.0000e+00 - val_loss: 1105.3506 - val_accuracy: 0.0000e+00
# Epoch 478/500
# 445/445 [==============================] - ETA: 0s - loss: 1026.1886 - accuracy: 0.0000e+0 - 0s 61us/sample - loss: 1078.9472 - accuracy: 0.0000e+00 - val_loss: 1073.4850 - val_accuracy: 0.0000e+00
# Epoch 479/500
# 445/445 [==============================] - 0s 59us/sample - loss: 1101.3034 - accuracy: 0.0000e+00 - val_loss: 1146.5664 - val_accuracy: 0.0000e+00
# Epoch 480/500
# 445/445 [==============================] - 0s 54us/sample - loss: 1081.2467 - accuracy: 0.0000e+00 - val_loss: 1059.0050 - val_accuracy: 0.0000e+00
# Epoch 481/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1081.1723 - accuracy: 0.0000e+00 - val_loss: 1059.0697 - val_accuracy: 0.0000e+00
# Epoch 482/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1070.5514 - accuracy: 0.0000e+00 - val_loss: 1073.2588 - val_accuracy: 0.0000e+00
# Epoch 483/500
# 445/445 [==============================] - 0s 46us/sample - loss: 1067.6693 - accuracy: 0.0000e+00 - val_loss: 1107.7296 - val_accuracy: 0.0000e+00
# Epoch 484/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1058.4203 - accuracy: 0.0000e+00 - val_loss: 1131.7580 - val_accuracy: 0.0000e+00
# Epoch 485/500
# 445/445 [==============================] - 0s 43us/sample - loss: 1074.7602 - accuracy: 0.0000e+00 - val_loss: 1091.3801 - val_accuracy: 0.0000e+00
# Epoch 486/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1095.3661 - accuracy: 0.0000e+00 - val_loss: 1094.5563 - val_accuracy: 0.0000e+00
# Epoch 487/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1071.2350 - accuracy: 0.0000e+00 - val_loss: 1104.2529 - val_accuracy: 0.0000e+00
# Epoch 488/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1071.9779 - accuracy: 0.0000e+00 - val_loss: 1085.4568 - val_accuracy: 0.0000e+00
# Epoch 489/500
# 445/445 [==============================] - 0s 52us/sample - loss: 1061.1766 - accuracy: 0.0000e+00 - val_loss: 1083.1528 - val_accuracy: 0.0000e+00
# Epoch 490/500
# 445/445 [==============================] - 0s 47us/sample - loss: 1063.9226 - accuracy: 0.0000e+00 - val_loss: 1104.7227 - val_accuracy: 0.0000e+00
# Epoch 491/500
# 445/445 [==============================] - 0s 53us/sample - loss: 1057.3291 - accuracy: 0.0000e+00 - val_loss: 1121.1716 - val_accuracy: 0.0000e+00
# Epoch 492/500
# 445/445 [==============================] - 0s 49us/sample - loss: 1082.5777 - accuracy: 0.0000e+00 - val_loss: 1093.6424 - val_accuracy: 0.0000e+00
# Epoch 493/500
# 445/445 [==============================] - 0s 53us/sample - loss: 1081.4563 - accuracy: 0.0000e+00 - val_loss: 1075.0077 - val_accuracy: 0.0000e+00
# Epoch 494/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1066.1188 - accuracy: 0.0000e+00 - val_loss: 1087.8296 - val_accuracy: 0.0000e+00
# Epoch 495/500
# 445/445 [==============================] - 0s 63us/sample - loss: 1060.4743 - accuracy: 0.0000e+00 - val_loss: 1136.9001 - val_accuracy: 0.0000e+00
# Epoch 496/500
# 445/445 [==============================] - 0s 54us/sample - loss: 1074.3180 - accuracy: 0.0000e+00 - val_loss: 1086.7542 - val_accuracy: 0.0000e+00
# Epoch 497/500
# 445/445 [==============================] - 0s 53us/sample - loss: 1079.3207 - accuracy: 0.0000e+00 - val_loss: 1138.6512 - val_accuracy: 0.0000e+00
# Epoch 498/500
# 445/445 [==============================] - 0s 53us/sample - loss: 1077.5155 - accuracy: 0.0000e+00 - val_loss: 1083.7197 - val_accuracy: 0.0000e+00
# Epoch 499/500
# 445/445 [==============================] - 0s 50us/sample - loss: 1064.8141 - accuracy: 0.0000e+00 - val_loss: 1099.9119 - val_accuracy: 0.0000e+00
# Epoch 500/500
# 445/445 [==============================] - 0s 51us/sample - loss: 1063.1603 - accuracy: 0.0000e+00 - val_loss: 1086.7906 - val_accuracy: 0.0000e+00

# %%
from sklearn.metrics import accuracy_score
# Out:
#                    High          Low         Open        Close      Volume    Adj Close  Percent_change        Date  Rise  Volatile  trump_tweet_cnt  retweet_count  favorite_count  polarity  trade_tags_score  politics_tags_score  foreign_tags_score
# Index
# 2019-10-25  3027.389893  3001.939941  3003.320068  3022.550049  3370370000  3022.550049        0.640291  2019-10-25     1         0                1        74119.0         76475.0       3.1                 0                    4                   0
# 2019-10-24  3016.070068  3000.419922  3014.780029  3010.290039  3692600000  3010.290039       -0.148933  2019-10-24     0         0                9       203529.0        518594.0       1.6                 0                    1                   3
# 2019-10-23  3004.780029  2991.209961  2994.010010  3004.520020  3392870000  3004.520020        0.351035  2019-10-23     1         0               22       604261.0       1292485.0      21.1                 4                   11                   5
# 2019-10-22  3014.570068  2995.040039  3010.729980  2995.989990  3523890000  2995.989990       -0.489582  2019-10-22     0         0               14       504930.0       1022161.0      -1.2                 2                    9                   3
# 2019-10-21  3007.330078  2995.350098  2996.479980  3006.719971  3271620000  3006.719971        0.341734  2019-10-21     1         0               12       251644.0        645387.0      10.9                 0                    2                   0
# ...                 ...          ...          ...          ...         ...          ...             ...         ...   ...       ...              ...            ...             ...       ...               ...                  ...                 ...
# 2017-01-26  2300.989990  2294.080078  2298.629883  2296.679932  3610360000  2296.679932       -0.084831  2017-01-26     0         0               11       194173.0        970602.0      -1.7                 4                    0                   0
# 2017-01-25  2299.550049  2288.879883  2288.879883  2298.370117  3846020000  2298.370117        0.414624  2017-01-25     1         0                8       240014.0       1112361.0      -8.6                 0                    1                   0
# 2017-01-24  2284.629883  2266.679932  2267.879883  2280.070068  3810960000  2280.070068        0.537515  2017-01-24     1         0                4        86707.0        495813.0      -1.2                 0                    0                   0
# 2017-01-23  2271.780029  2257.020020  2267.780029  2265.199951  3152710000  2265.199951       -0.113771  2017-01-23     0         0                1        26750.0        177839.0       1.4                 0                    0                   0
# 2017-01-20  2276.959961  2265.010010  2269.959961  2271.310059  3524970000  2271.310059        0.059477  2017-01-20     1         0               13       417567.0       1867501.0       7.6                 0                    0                   0
#
# [697 rows x 17 columns]

# %% [markdown]
# ### Try Classification of Volatility

# %%
volatile_df = df_cbm[df_cbm.Volatile==True]

x = df_cbm[['trump_tweet_cnt','retweet_count','favorite_count','polarity','trade_tags_score','politics_tags_score','foreign_tags_score']]

y = df_cbm['Volatile']


X_train,X_test,y_train2,y_test2 = train_test_split(x,y,test_size=0.5,random_state=42,stratify=y)


#Add duplicates to X
'''
new_training = X_train
new_training['Volatile'] = y


volatile_df = new_training[new_training['Volatile']==1]

new_training = new_training.append([volatile_df]*5,ignore_index=True)
display(volatile_df.head(10))

y_train2 = new_training.Volatile
X_train = new_training.drop(['Volatile'],axis=1)

'''
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing

# fit the scaler on the X_train
scaler = preprocessing.MinMaxScaler().fit(X_train)

# Scale X_train and X_test
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Making the numpy scaled matrices pandas dataframes
X_train_scaled_df = pd.DataFrame(X_train_scaled, index=X_train.index, columns=X_train.columns)
X_test_scaled_df = pd.DataFrame(X_test_scaled, index=X_test.index, columns=X_test.columns)

X_train_scaled_df.head()


logistic_model = LogisticRegression(C=1000000)
logistic_model.fit(X_train_scaled,y_train2)
print("Training set score after normalization",logistic_model.score(X_train_scaled,y_train2))
print("Test set score after normalization",logistic_model.score(X_test_scaled,y_test2))
# Out:
# Training set score after normalization 0.9454022988505747
# Test set score after normalization 0.9426934097421203
# /Users/shijianjin/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# ### Logistic Regression with Regularization

# %%
logistic_model_regularized = LogisticRegression(C=0.1)
logistic_model_regularized.fit(X_train_scaled,y_train2)
print("Training set score",logistic_model_regularized.score(X_train_scaled,y_train2))
print("Test set score",logistic_model_regularized.score(X_test_scaled,y_test2))
# Out:
# Training set score 0.9482758620689655
# Test set score 0.9455587392550143
# /Users/shijianjin/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# ### Try KNN classifier on volatility

# %%
from sklearn.neighbors import KNeighborsClassifier


k_list = [1,2,3,5,6,7,8,10,20,25]
k_cross_scores = []
k_train_scores = []
k_test_scores = []
for k in k_list:
    kNN = KNeighborsClassifier(n_neighbors = k).fit(X_train_scaled,y_train2)

    train_score = kNN.score(X_train_scaled,y_train2)
    cross_score = np.mean(cross_val_score(kNN,X_train_scaled,y_train2,cv=5))
    test_score = kNN.score(X_test_scaled,y_test2)
    k_train_scores.append(train_score)
    k_cross_scores.append(cross_score)
    k_test_scores.append(test_score)
    
    print("The number of neighbors is",k,"The training set_score is ",train_score,". The validation set score is",cross_score,"The test set score is",test_score)
    
    
    
    
fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(k_list,k_train_scores, color='blue', label='Training Set')
ax1.plot(k_list,k_test_scores,color='red',  label='Test Set')

ax1.set_xlabel("Number of nearest neighbors",fontsize=14)
ax1.set_ylabel("Score",fontsize=14)
ax1.tick_params(axis='both', labelsize=14)
plt.title('Trump Tweets vs. Volatility: Model Scoring with kNN Models ', fontsize=16)
plt.legend(fontsize = 15)
plt.show()
# Out:
# The number of neighbors is 1 The training set_score is  1.0 . The validation set score is 0.9138302277432713 The test set score is 0.9197707736389685
# The number of neighbors is 2 The training set_score is  0.9568965517241379 . The validation set score is 0.9454244306418218 The test set score is 0.9455587392550143
# The number of neighbors is 3 The training set_score is  0.9597701149425287 . The validation set score is 0.9368115942028984 The test set score is 0.9398280802292264
# The number of neighbors is 5 The training set_score is  0.9511494252873564 . The validation set score is 0.9483229813664595 The test set score is 0.9455587392550143
# The number of neighbors is 6 The training set_score is  0.9482758620689655 . The validation set score is 0.9483229813664595 The test set score is 0.9455587392550143
# The number of neighbors is 7 The training set_score is  0.9482758620689655 . The validation set score is 0.9483229813664595 The test set score is 0.9455587392550143
# The number of neighbors is 8 The training set_score is  0.9482758620689655 . The validation set score is 0.9483229813664595 The test set score is 0.9455587392550143
# The number of neighbors is 10 The training set_score is  0.9482758620689655 . The validation set score is 0.9483229813664595 The test set score is 0.9455587392550143
# The number of neighbors is 20 The training set_score is  0.9482758620689655 . The validation set score is 0.9483229813664595 The test set score is 0.9455587392550143
# The number of neighbors is 25 The training set_score is  0.9482758620689655 . The validation set score is 0.9483229813664595 The test set score is 0.9455587392550143

# %% [markdown]
# ### Decision Tree Model Classifier

# %%
from sklearn.tree import DecisionTreeClassifier


max_depth = [1,2,3,4,5,10,20,30]
tree_models = []
tree_train_score = []
tree_cross_score = []
tree_test_score = []
for depth in max_depth:
    
    dtree = DecisionTreeClassifier(max_depth=depth)
    dtree.fit(X_train_scaled,y_train2)
    train_score = dtree.score(X_train_scaled,y_train2)
    test_score = dtree.score(X_test_scaled,y_test2)
    cross_score = np.mean(cross_val_score(dtree,X_train_scaled,y_train2,cv=5))
    tree_models.append(dtree)
    tree_train_score.append(train_score)
    tree_cross_score.append(cross_score)
    tree_test_score.append(test_score)
    print("The max depth is",depth,"The training set_score is ",train_score,". The validation set score is",cross_score,"The test set score is",test_score)

fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(max_depth,tree_train_score, color='blue', label='Training Set')
ax1.plot(max_depth,tree_test_score,color='red',  label='Test Set')

ax1.set_xlabel("Max depth of trees",fontsize=14)
ax1.set_ylabel("Score",fontsize=14)
ax1.tick_params(axis='both', labelsize=14)
plt.title('Trump Tweets vs. Volatility: Model Scoring with Decision Tree Models ', fontsize=16)
plt.legend(fontsize = 15)
plt.show()
# Out:
# The max depth is 1 The training set_score is  0.9540229885057471 . The validation set score is 0.9540786749482401 The test set score is 0.9455587392550143
# The max depth is 2 The training set_score is  0.9540229885057471 . The validation set score is 0.9512215320910972 The test set score is 0.9455587392550143
# The max depth is 3 The training set_score is  0.9597701149425287 . The validation set score is 0.9455072463768115 The test set score is 0.9398280802292264
# The max depth is 4 The training set_score is  0.9655172413793104 . The validation set score is 0.9454658385093166 The test set score is 0.9426934097421203
# The max depth is 5 The training set_score is  0.9655172413793104 . The validation set score is 0.9483643892339544 The test set score is 0.9426934097421203
# The max depth is 10 The training set_score is  0.9942528735632183 . The validation set score is 0.9195859213250517 The test set score is 0.9025787965616046
# The max depth is 20 The training set_score is  1.0 . The validation set score is 0.9108488612836438 The test set score is 0.9083094555873925
# The max depth is 30 The training set_score is  1.0 . The validation set score is 0.9253416149068323 The test set score is 0.8939828080229226

# %% [markdown]
# ### ANN Model

# %%
input_dimension = X_train_scaled.shape[1]
output_dimension = 1
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10,input_dim = input_dimension,kernel_initializer = 'normal'),
    tf.keras.layers.Dense(20,activation = 'relu',kernel_initializer = 'normal'),
    tf.keras.layers.Dense(50,activation = 'relu',kernel_initializer = 'normal'),
    tf.keras.layers.Dense(20,activation = 'relu',kernel_initializer = 'normal'),
    tf.keras.layers.Dense(10,activation = 'relu',kernel_initializer = 'normal'),

    tf.keras.layers.Dense(output_dimension,activation = 'sigmoid'),

])

model.compile(optimizer = 'adam',loss='binary_crossentropy',metrics=['accuracy'])
model.summary()

history = model.fit(X_train,y_train2,validation_split=0.2,epochs=100,batch_size=50)
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_90 (Dense)             (None, 10)                80
# _________________________________________________________________
# dense_91 (Dense)             (None, 20)                220
# _________________________________________________________________
# dense_92 (Dense)             (None, 50)                1050
# _________________________________________________________________
# dense_93 (Dense)             (None, 20)                1020
# _________________________________________________________________
# dense_94 (Dense)             (None, 10)                210
# _________________________________________________________________
# dense_95 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 2,591
# Trainable params: 2,591
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 278 samples, validate on 70 samples
# Epoch 1/100
# 278/278 [==============================] - 0s 732us/sample - loss: 2.4796 - accuracy: 0.6511 - val_loss: 0.5375 - val_accuracy: 0.9286
# Epoch 2/100
# 278/278 [==============================] - 0s 40us/sample - loss: 0.5983 - accuracy: 0.9496 - val_loss: 0.5573 - val_accuracy: 0.9286
# Epoch 3/100
# 278/278 [==============================] - 0s 36us/sample - loss: 0.5198 - accuracy: 0.9496 - val_loss: 0.3065 - val_accuracy: 0.9286
# Epoch 4/100
# 278/278 [==============================] - 0s 39us/sample - loss: 0.3242 - accuracy: 0.9496 - val_loss: 0.6303 - val_accuracy: 0.7429
# Epoch 5/100
# 278/278 [==============================] - 0s 49us/sample - loss: 0.3926 - accuracy: 0.9245 - val_loss: 0.5383 - val_accuracy: 0.9286
# Epoch 6/100
# 278/278 [==============================] - 0s 41us/sample - loss: 0.5845 - accuracy: 0.9496 - val_loss: 0.3893 - val_accuracy: 0.9286
# Epoch 7/100
# 278/278 [==============================] - 0s 42us/sample - loss: 0.4715 - accuracy: 0.9317 - val_loss: 0.2819 - val_accuracy: 0.9286
# Epoch 8/100
# 278/278 [==============================] - 0s 50us/sample - loss: 0.4578 - accuracy: 0.9496 - val_loss: 0.3971 - val_accuracy: 0.9286
# Epoch 9/100
# 278/278 [==============================] - 0s 41us/sample - loss: 0.4336 - accuracy: 0.9496 - val_loss: 0.3166 - val_accuracy: 0.9286
# Epoch 10/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.3529 - accuracy: 0.9496 - val_loss: 0.2826 - val_accuracy: 0.9286
# Epoch 11/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.3380 - accuracy: 0.9496 - val_loss: 0.2961 - val_accuracy: 0.9286
# Epoch 12/100
# 278/278 [==============================] - 0s 38us/sample - loss: 0.2849 - accuracy: 0.9496 - val_loss: 0.2740 - val_accuracy: 0.9286
# Epoch 13/100
# 278/278 [==============================] - 0s 51us/sample - loss: 0.3312 - accuracy: 0.9496 - val_loss: 0.2861 - val_accuracy: 0.9429
# Epoch 14/100
# 278/278 [==============================] - 0s 40us/sample - loss: 0.3042 - accuracy: 0.9496 - val_loss: 0.2650 - val_accuracy: 0.9429
# Epoch 15/100
# 278/278 [==============================] - 0s 39us/sample - loss: 0.3663 - accuracy: 0.9496 - val_loss: 0.2760 - val_accuracy: 0.9429
# Epoch 16/100
# 278/278 [==============================] - 0s 47us/sample - loss: 0.3658 - accuracy: 0.9496 - val_loss: 0.2671 - val_accuracy: 0.9429
# Epoch 17/100
# 278/278 [==============================] - 0s 43us/sample - loss: 0.3409 - accuracy: 0.9496 - val_loss: 0.2685 - val_accuracy: 0.9429
# Epoch 18/100
# 278/278 [==============================] - 0s 43us/sample - loss: 0.3126 - accuracy: 0.9496 - val_loss: 0.2933 - val_accuracy: 0.9429
# Epoch 19/100
# 278/278 [==============================] - 0s 46us/sample - loss: 0.2943 - accuracy: 0.9496 - val_loss: 0.2619 - val_accuracy: 0.9429
# Epoch 20/100
# 278/278 [==============================] - 0s 39us/sample - loss: 0.3074 - accuracy: 0.9496 - val_loss: 0.2618 - val_accuracy: 0.9429
# Epoch 21/100
# 278/278 [==============================] - 0s 44us/sample - loss: 0.2984 - accuracy: 0.9496 - val_loss: 0.2571 - val_accuracy: 0.9429
# Epoch 22/100
# 278/278 [==============================] - 0s 43us/sample - loss: 0.2828 - accuracy: 0.9496 - val_loss: 0.2507 - val_accuracy: 0.9429
# Epoch 23/100
# 278/278 [==============================] - 0s 37us/sample - loss: 0.3001 - accuracy: 0.9496 - val_loss: 0.2526 - val_accuracy: 0.9429
# Epoch 24/100
# 278/278 [==============================] - 0s 50us/sample - loss: 0.2887 - accuracy: 0.9496 - val_loss: 0.2505 - val_accuracy: 0.9429
# Epoch 25/100
# 278/278 [==============================] - 0s 43us/sample - loss: 0.2876 - accuracy: 0.9496 - val_loss: 0.2588 - val_accuracy: 0.9429
# Epoch 26/100
# 278/278 [==============================] - 0s 49us/sample - loss: 0.2988 - accuracy: 0.9496 - val_loss: 0.2540 - val_accuracy: 0.9429
# Epoch 27/100
# 278/278 [==============================] - 0s 49us/sample - loss: 0.2887 - accuracy: 0.9496 - val_loss: 0.2510 - val_accuracy: 0.9429
# Epoch 28/100
# 278/278 [==============================] - 0s 48us/sample - loss: 0.2862 - accuracy: 0.9496 - val_loss: 0.2543 - val_accuracy: 0.9429
# Epoch 29/100
# 278/278 [==============================] - 0s 48us/sample - loss: 0.3007 - accuracy: 0.9496 - val_loss: 0.2596 - val_accuracy: 0.9429
# Epoch 30/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.2817 - accuracy: 0.9496 - val_loss: 0.2692 - val_accuracy: 0.9429
# Epoch 31/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.2963 - accuracy: 0.9496 - val_loss: 0.2609 - val_accuracy: 0.9429
# Epoch 32/100
# 278/278 [==============================] - 0s 46us/sample - loss: 0.2885 - accuracy: 0.9496 - val_loss: 0.2535 - val_accuracy: 0.9429
# Epoch 33/100
# 278/278 [==============================] - 0s 47us/sample - loss: 0.3531 - accuracy: 0.9496 - val_loss: 0.2530 - val_accuracy: 0.9429
# Epoch 34/100
# 278/278 [==============================] - 0s 44us/sample - loss: 0.3094 - accuracy: 0.9496 - val_loss: 0.2840 - val_accuracy: 0.9429
# Epoch 35/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.3008 - accuracy: 0.9496 - val_loss: 0.2535 - val_accuracy: 0.9429
# Epoch 36/100
# 278/278 [==============================] - 0s 53us/sample - loss: 0.2926 - accuracy: 0.9496 - val_loss: 0.2536 - val_accuracy: 0.9429
# Epoch 37/100
# 278/278 [==============================] - 0s 49us/sample - loss: 0.2925 - accuracy: 0.9496 - val_loss: 0.2733 - val_accuracy: 0.9429
# Epoch 38/100
# 278/278 [==============================] - 0s 41us/sample - loss: 0.2874 - accuracy: 0.9496 - val_loss: 0.2551 - val_accuracy: 0.9429
# Epoch 39/100
# 278/278 [==============================] - 0s 56us/sample - loss: 0.2872 - accuracy: 0.9496 - val_loss: 0.2523 - val_accuracy: 0.9429
# Epoch 40/100
# 278/278 [==============================] - 0s 51us/sample - loss: 0.2947 - accuracy: 0.9496 - val_loss: 0.2654 - val_accuracy: 0.9429
# Epoch 41/100
# 278/278 [==============================] - 0s 49us/sample - loss: 0.2839 - accuracy: 0.9496 - val_loss: 0.2548 - val_accuracy: 0.9429
# Epoch 42/100
# 278/278 [==============================] - 0s 50us/sample - loss: 0.2809 - accuracy: 0.9496 - val_loss: 0.2519 - val_accuracy: 0.9429
# Epoch 43/100
# 278/278 [==============================] - 0s 48us/sample - loss: 0.3038 - accuracy: 0.9496 - val_loss: 0.2512 - val_accuracy: 0.9429
# Epoch 44/100
# 278/278 [==============================] - 0s 50us/sample - loss: 0.2964 - accuracy: 0.9496 - val_loss: 0.2708 - val_accuracy: 0.9429
# Epoch 45/100
# 278/278 [==============================] - 0s 44us/sample - loss: 0.2838 - accuracy: 0.9496 - val_loss: 0.2519 - val_accuracy: 0.9429
# Epoch 46/100
# 278/278 [==============================] - 0s 39us/sample - loss: 0.2851 - accuracy: 0.9496 - val_loss: 0.2555 - val_accuracy: 0.9429
# Epoch 47/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.2818 - accuracy: 0.9496 - val_loss: 0.2535 - val_accuracy: 0.9429
# Epoch 48/100
# 278/278 [==============================] - 0s 40us/sample - loss: 0.2830 - accuracy: 0.9496 - val_loss: 0.2502 - val_accuracy: 0.9429
# Epoch 49/100
# 278/278 [==============================] - 0s 46us/sample - loss: 0.3010 - accuracy: 0.9496 - val_loss: 0.2659 - val_accuracy: 0.9429
# Epoch 50/100
# 278/278 [==============================] - 0s 43us/sample - loss: 0.2832 - accuracy: 0.9496 - val_loss: 0.2494 - val_accuracy: 0.9429
# Epoch 51/100
# 278/278 [==============================] - 0s 49us/sample - loss: 0.3032 - accuracy: 0.9496 - val_loss: 0.2491 - val_accuracy: 0.9429
# Epoch 52/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.2818 - accuracy: 0.9496 - val_loss: 0.2781 - val_accuracy: 0.9429
# Epoch 53/100
# 278/278 [==============================] - 0s 47us/sample - loss: 0.2802 - accuracy: 0.9496 - val_loss: 0.2495 - val_accuracy: 0.9429
# Epoch 54/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.2898 - accuracy: 0.9496 - val_loss: 0.2492 - val_accuracy: 0.9429
# Epoch 55/100
# 278/278 [==============================] - 0s 44us/sample - loss: 0.2761 - accuracy: 0.9496 - val_loss: 0.2552 - val_accuracy: 0.9429
# Epoch 56/100
# 278/278 [==============================] - 0s 46us/sample - loss: 0.2821 - accuracy: 0.9496 - val_loss: 0.2679 - val_accuracy: 0.9429
# Epoch 57/100
# 278/278 [==============================] - 0s 48us/sample - loss: 0.2775 - accuracy: 0.9496 - val_loss: 0.2485 - val_accuracy: 0.9429
# Epoch 58/100
# 278/278 [==============================] - 0s 47us/sample - loss: 0.2808 - accuracy: 0.9496 - val_loss: 0.2484 - val_accuracy: 0.9429
# Epoch 59/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.2741 - accuracy: 0.9496 - val_loss: 0.2532 - val_accuracy: 0.9429
# Epoch 60/100
# 278/278 [==============================] - 0s 51us/sample - loss: 0.2735 - accuracy: 0.9496 - val_loss: 0.2536 - val_accuracy: 0.9429
# Epoch 61/100
# 278/278 [==============================] - 0s 41us/sample - loss: 0.2726 - accuracy: 0.9496 - val_loss: 0.2495 - val_accuracy: 0.9429
# Epoch 62/100
# 278/278 [==============================] - 0s 43us/sample - loss: 0.2712 - accuracy: 0.9496 - val_loss: 0.2491 - val_accuracy: 0.9429
# Epoch 63/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.2684 - accuracy: 0.9496 - val_loss: 0.2467 - val_accuracy: 0.9429
# Epoch 64/100
# 278/278 [==============================] - 0s 103us/sample - loss: 0.2704 - accuracy: 0.9496 - val_loss: 0.2490 - val_accuracy: 0.9429
# Epoch 65/100
# 278/278 [==============================] - 0s 167us/sample - loss: 0.2671 - accuracy: 0.9496 - val_loss: 0.2422 - val_accuracy: 0.9429
# Epoch 66/100
# 278/278 [==============================] - 0s 94us/sample - loss: 0.2676 - accuracy: 0.9496 - val_loss: 0.2779 - val_accuracy: 0.9429
# Epoch 67/100
# 278/278 [==============================] - 0s 71us/sample - loss: 0.2633 - accuracy: 0.9496 - val_loss: 0.2497 - val_accuracy: 0.9429
# Epoch 68/100
# 278/278 [==============================] - 0s 74us/sample - loss: 0.2843 - accuracy: 0.9496 - val_loss: 0.2571 - val_accuracy: 0.9429
# Epoch 69/100
# 278/278 [==============================] - 0s 80us/sample - loss: 0.2689 - accuracy: 0.9496 - val_loss: 0.2407 - val_accuracy: 0.9429
# Epoch 70/100
# 278/278 [==============================] - 0s 66us/sample - loss: 0.2796 - accuracy: 0.9496 - val_loss: 0.2457 - val_accuracy: 0.9429
# Epoch 71/100
# 278/278 [==============================] - 0s 74us/sample - loss: 0.2705 - accuracy: 0.9496 - val_loss: 0.2485 - val_accuracy: 0.9429
# Epoch 72/100
# 278/278 [==============================] - 0s 73us/sample - loss: 0.2681 - accuracy: 0.9496 - val_loss: 0.2486 - val_accuracy: 0.9429
# Epoch 73/100
# 278/278 [==============================] - 0s 69us/sample - loss: 0.2677 - accuracy: 0.9496 - val_loss: 0.2440 - val_accuracy: 0.9429
# Epoch 74/100
# 278/278 [==============================] - 0s 80us/sample - loss: 0.2637 - accuracy: 0.9496 - val_loss: 0.2445 - val_accuracy: 0.9429
# Epoch 75/100
# 278/278 [==============================] - 0s 86us/sample - loss: 0.2614 - accuracy: 0.9496 - val_loss: 0.2409 - val_accuracy: 0.9429
# Epoch 76/100
# 278/278 [==============================] - 0s 82us/sample - loss: 0.2623 - accuracy: 0.9496 - val_loss: 0.2391 - val_accuracy: 0.9429
# Epoch 77/100
# 278/278 [==============================] - 0s 95us/sample - loss: 0.2633 - accuracy: 0.9496 - val_loss: 0.3454 - val_accuracy: 0.9429
# Epoch 78/100
# 278/278 [==============================] - 0s 88us/sample - loss: 0.2569 - accuracy: 0.9496 - val_loss: 0.2687 - val_accuracy: 0.9429
# Epoch 79/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.2832 - accuracy: 0.9496 - val_loss: 0.3552 - val_accuracy: 0.9429
# Epoch 80/100
# 278/278 [==============================] - 0s 46us/sample - loss: 0.2524 - accuracy: 0.9496 - val_loss: 0.2445 - val_accuracy: 0.9429
# Epoch 81/100
# 278/278 [==============================] - 0s 44us/sample - loss: 0.2827 - accuracy: 0.9496 - val_loss: 0.2440 - val_accuracy: 0.9429
# Epoch 82/100
# 278/278 [==============================] - 0s 43us/sample - loss: 0.2988 - accuracy: 0.9496 - val_loss: 0.2463 - val_accuracy: 0.9429
# Epoch 83/100
# 278/278 [==============================] - 0s 43us/sample - loss: 0.3157 - accuracy: 0.9496 - val_loss: 0.2460 - val_accuracy: 0.9429
# Epoch 84/100
# 278/278 [==============================] - 0s 44us/sample - loss: 0.2681 - accuracy: 0.9496 - val_loss: 0.2622 - val_accuracy: 0.9429
# Epoch 85/100
# 278/278 [==============================] - 0s 44us/sample - loss: 0.2691 - accuracy: 0.9496 - val_loss: 0.2446 - val_accuracy: 0.9429
# Epoch 86/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.2716 - accuracy: 0.9496 - val_loss: 0.2541 - val_accuracy: 0.9429
# Epoch 87/100
# 278/278 [==============================] - 0s 39us/sample - loss: 0.3148 - accuracy: 0.9496 - val_loss: 0.2440 - val_accuracy: 0.9429
# Epoch 88/100
# 278/278 [==============================] - 0s 43us/sample - loss: 0.3113 - accuracy: 0.9496 - val_loss: 0.2634 - val_accuracy: 0.9429
# Epoch 89/100
# 278/278 [==============================] - 0s 44us/sample - loss: 0.2942 - accuracy: 0.9496 - val_loss: 0.2566 - val_accuracy: 0.9429
# Epoch 90/100
# 278/278 [==============================] - 0s 44us/sample - loss: 0.2677 - accuracy: 0.9496 - val_loss: 0.2509 - val_accuracy: 0.9429
# Epoch 91/100
# 278/278 [==============================] - 0s 43us/sample - loss: 0.2625 - accuracy: 0.9496 - val_loss: 0.2444 - val_accuracy: 0.9429
# Epoch 92/100
# 278/278 [==============================] - 0s 46us/sample - loss: 0.2690 - accuracy: 0.9496 - val_loss: 0.2422 - val_accuracy: 0.9429
# Epoch 93/100
# 278/278 [==============================] - 0s 35us/sample - loss: 0.2672 - accuracy: 0.9496 - val_loss: 0.2470 - val_accuracy: 0.9429
# Epoch 94/100
# 278/278 [==============================] - 0s 46us/sample - loss: 0.2657 - accuracy: 0.9496 - val_loss: 0.2501 - val_accuracy: 0.9429
# Epoch 95/100
# 278/278 [==============================] - 0s 47us/sample - loss: 0.2669 - accuracy: 0.9496 - val_loss: 0.2420 - val_accuracy: 0.9429
# Epoch 96/100
# 278/278 [==============================] - 0s 46us/sample - loss: 0.2637 - accuracy: 0.9496 - val_loss: 0.2460 - val_accuracy: 0.9429
# Epoch 97/100
# 278/278 [==============================] - 0s 45us/sample - loss: 0.2662 - accuracy: 0.9496 - val_loss: 0.2472 - val_accuracy: 0.9429
# Epoch 98/100
# 278/278 [==============================] - 0s 44us/sample - loss: 0.2599 - accuracy: 0.9496 - val_loss: 0.2421 - val_accuracy: 0.9429
# Epoch 99/100
# 278/278 [==============================] - 0s 41us/sample - loss: 0.2644 - accuracy: 0.9496 - val_loss: 0.2408 - val_accuracy: 0.9429
# Epoch 100/100
# 278/278 [==============================] - 0s 46us/sample - loss: 0.2618 - accuracy: 0.9496 - val_loss: 0.2434 - val_accuracy: 0.9429

# %%
fig, ax1 = plt.subplots(figsize=(10,6))
ax1.plot(np.array(history.history['accuracy']), color='blue', label='Training Set')
ax1.plot(np.array(history.history['val_accuracy']),color ='red',  label='Test Set')

ax1.set_xlabel("Epoch",fontsize=14)
ax1.set_ylabel("Accuracy",fontsize=14)
ax1.tick_params(axis='both', labelsize=14)
plt.title('Trump Tweets vs. Volatility: Accuracy vs Epoch in ANN Model', fontsize=16)
plt.legend(fontsize = 15)
plt.show()

# %%
print(accuracy_score(y_test2,np.rint(model.predict(X_test_scaled))))

fig,ax = plt.subplots(1,1,figsize=(10,6))

ax.bar(['Linear Regression Model','kNN Model','Decision Tree Model','ANN'],[train_score,k_train_scores[3],tree_train_score[1],np.array(history.history['accuracy'])[-1]],label='Training Set',width=0.7)
ax.bar(['Linear Regression Model','kNN Model','Decision Tree Model','ANN'],[test_score,k_test_scores[3],tree_test_score[1],accuracy_score(y_test2,np.rint(model.predict(X_test_scaled)))],label='Test Set',width=0.5)
ax.legend(fontsize=15)
ax.set_ylabel("Score",fontsize=14)
ax.tick_params(axis='both', labelsize=14)
ax.set_ylim(0,1.2)
ax.set_title('Comparison of Classification Models on Fitting Daily Trump Tweet Data vs. SPX High',fontsize=16)
plt.show()
# Out:
# 0.9455587392550143

# %% [markdown]
# # Future Work
#
# 1. The baseline model clearly gives terrible fitting. The failure is due to the lack of proper predictors. The number of tweets by Trump does not mean much to the market; rather, it's the content in those tweets that matters more. A simple modification on the current dataset is to have a column named ave_retweet or ave_favorite, whose value is `retweet_count`/`trump_tweet_cnt` or `favorite_count`/`trump_tweet_cnt`. This column would reflect the importance of the tweets at a particular day. We expect important tweets have more influence on the market.
#
# 2. An important task to do is to categorize the tweets based on the content. Possible categories are, whether a tweet mentions market(e.g. mentions a company's name or an industry), whether a tweet mentions trade war, whether a tweet expresses positive or negative attitude, whether a tweet uses strong language or not. After categorization, we may use models such as decision tree to find out the most important features that influence the market.
#
# 3. We will find out the most frequent phrases that Trump uses in the tweets and check how the appearance of these phrases influence market behavior.
#
# 4. We can include more features into the market data. For example, we can have a column named big_change, indicating whether the stock/index experiences a change that is way larger than $2*std$.

# %% [markdown]
# # Topic Modeling - Tweets text

# %% [markdown]
# ## Theoretical Overview

# %% [markdown]
# LDA is a generative probabilistic model that assumes each topic is a mixture over an underlying set of words, and each document is a mixture of over a set of topic probabilities.
#
# We can describe the generative process of LDA as, given the M number of documents, N number of words, and prior K number of topics, the model trains to output:
# psi -- the distribution of words for each topic K
# phi -- the distribution of topics for each document i

# %%
print('Total tweets', len(df_tweets))
df_tweets.head()

# %%
def grep_ref_tweet_ids(text):
    ref_tweet_ids=[]
    ref_tweet_ids = re.findall(r'@(\w+)\W',text)
    #clean_text= re.sub(r'@(\w+)\W', r' ', text)
    return ref_tweet_ids, clean_text

# %%
def grep_hash_tags(text):
    ref_hash_tags=[]
    ref_hash_tags = re.findall(r'#([\w]{3,})\W',text)
    clean_text= text #re.sub(r'#([\w]{3,})\W', r' ', text)
    return ref_hash_tags, clean_text

# %%
def grep_ref_https_link(text):
    ref_http_links=[]
    ref_http_links=[]
    ref_http_links = re.findall(r'(https?://[\w\.\/]+)\W',text)
    clean_text=text
    return ref_http_links, clean_text

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english')

# %%
# Load the regular expression library
import re

# Remove punctuation
df_tweets['tweet_text_processed'] = df_tweets['text'].map(lambda x: re.sub('[,\.!?]', '', x))

# Convert the tweets to lowercase
df_tweets['tweet_text_processed'] = df_tweets['tweet_text_processed'].map(lambda x: x.lower())

# Print out the few rows of tweets
df_tweets['tweet_text_processed'].head()

# %% [markdown]
# ### Exploratory Analysis - WordCloud

# %%
# Import the wordcloud library
from wordcloud import WordCloud

# Join the different processed tweets together
long_string = ','.join(list(df_tweets['tweet_text_processed'].values))

# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=1000, contour_width=3, contour_color='steelblue')

# Generate a word cloud
wordcloud.generate(long_string)

# Visualize the word cloud
wordcloud.to_image()

# %% [markdown]
# ### Prepare text for LDA analysis

# %%
# Load the library with the CountVectorizer method
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# Helper function
def plot_10_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:10]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='10 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()

# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')

# Fit and transform the processed tweets
count_data = count_vectorizer.fit_transform(df_tweets['tweet_text_processed'])

# Visualise the 10 most common words
plot_10_most_common_words(count_data, count_vectorizer)

# %% [markdown]
# ### LDA model tranining

# %%
import warnings
warnings.simplefilter("ignore", DeprecationWarning)

# Load the LDA model from sk-learn
from sklearn.decomposition import LatentDirichletAllocation as LDA
 
# Helper function
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        
# Tweak the two parameters below (use int values below 15)
number_topics = 5
number_words = 10

# Create and fit the LDA model
lda = LDA(n_components=number_topics)
lda.fit(count_data)

# Print the topics found by the LDA model
print("Topics found via LDA:")
print_topics(lda, count_vectorizer, number_words)
